# %% [markdown]
# # Boostrapping Document Classification
# Categorizing documents by style is known to be a difficult problem in Machine Learning and Natural Language Processing. However, every bit of success has the potential to reduce the burden of manual labelling.
#
# In this notebook we'll provide a real world example of boostrapping and iterating with document classification.
#
# ## The Problem
# * The corpus documents of the Latin Library
# * Proposed author/era groupings
#     * https://en.wikipedia.org/wiki/Classical_Latin
#     * https://en.wikipedia.org/wiki/Latin_literature
#     * https://en.wikipedia.org/wiki/Latin
#
# ## The Goal
# * Provide a mapping of authors-to-eras so CLTK users can easily load commonly used slices of corpus data
#
# ## Strategy: Supervised Learning
# * Label some documents and authors
# * Train a classifier and predict the era of unknown docs
# * Compare results with human corrections
#
# Often when the task is to classify a large number of documents it is useful to perform several iterations of document classification. Between iterations, one has the opportunity to assess and improve the classifications using semi-supervised learning.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
warnings.simplefilter('ignore') # quiet warnings for presentation purposes only

# %% [markdown]
# ## Imports

# %%
import os
import json
from collections import defaultdict
import random

import joblib
from tqdm import tqdm

from cltk.corpus.readers import FilteredPlaintextCorpusReader, get_corpus_reader, assemble_corpus
from cltk.prosody.latin.string_utils import punctuation_for_spaces_dict
from cltk.stem.latin.j_v import JVReplacer
from cltk.tokenize.sentence import TokenizeSentence
from cltk.prosody.latin.scansion_constants import ScansionConstants
from cltk.tokenize.word import WordTokenizer
import numpy as np
from sklearn.preprocessing.label import LabelEncoder
from sklearn.dummy import DummyClassifier
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression, SGDClassifier
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, RandomForestClassifier

# %% [markdown]
# ### Add parent directory to path so we can access our common code

# %%
import sys
import inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from mlyoucanuse.doc2tokens_transformer import Doc2TokensTransformer
from mlyoucanuse.corpus_fun import get_file_type_list

# %% [markdown]
# ## Load a CorpusReader

# %%
reader = get_corpus_reader(corpus_name='latin_text_latin_library', language='latin')
all_docs = list(reader.fileids())
print(f'{len(all_docs):,} documents in the corpus,  e.g.: {all_docs[:5]}...')
print(f'Random sample: {list(reader.docs(random.sample(all_docs, 1)))[0][200:250]}')
# Out:
# 2,141 documents in the corpus,  e.g.: ['12tables.txt', '1644.txt', 'abbofloracensis.txt', 'abelard/dialogus.txt', 'abelard/epistola.txt']...
# Random sample: ta
# qui canat est clamor, sed qui fera nuntiet arma

# %% [markdown]
# ## Examine the Data
# After gathering counts of file types:
# * `find ~/cltk_data/latin/text/latin_text_latin_library/*/ -type d  | wc -l`
# * `find ~/cltk_data/latin/text/latin_text_latin_library/*.txt -type f | wc -l`
#
# We find the 2,141 corpus files are organized into 79 directories and 537 files in the top level directory.
#
# So for our first pass of labeling we'll try to label directories which will likely include a large number of files.

# %% [markdown]
# ## Determine Label Categories
# after consulting some Wikipedia articles on the subject:
# * https://en.wikipedia.org/wiki/Classical_Latin
# * https://en.wikipedia.org/wiki/Latin_literature
#
# A popular consensus of organizining by era or time periods is apparent.
#
# We will choose these eras:
# * augustan
# * christian
# * early_silver
# * late_silver
# * medieval
# * neo_latin
# * old
# * renaissance
# * republican

# %% [markdown]
# ## Label some data, but not all
#
# We've decided to a dictionary of era category types and a List of file instances:
# * era
#     * author directory
#
# and
#
# * era
#     * file name
#
# e.g.:

# %%
manual_corpus_directories_by_type = {
    'republican': [
        './caesar',
        './lucretius',
        './nepos',
        './cicero'
    ],
    'augustan': [
        './livy',
        './ovid',
        './horace',
        './vergil',
        './hyginus'
    ],
    'early_silver': [
        './martial',
        './juvenal',
        './tacitus',
        './lucan',
        './quintilian',
        './sen',
        './statius',
        './silius',
        './columella'
    ],
    'late_silver': [
        './suetonius',
        './gellius',
        './apuleius'
        './justin',
        './apicius',
        './fulgentius',
        './orosius'
    ],
    'old': [
        './plautus'
    ],
    'christian': [
        './ambrose',
        './abelard',
        './alcuin',
        './augustine',
        './bede',
        './bible',
        './cassiodorus',
        './commodianus',
        './gregorytours',
        './hugo',
        './isidore',
        './jerome',
        './prudentius',
        './tertullian',
        './kempis',
        './leothegreat'
    ],
    'medieval': [
        './boethiusdacia',
        './dante'
    ],
    'renaissance': [
    ],
    'neo_latin': [
        './addison',
        './bacon',
        './bultelius',
        './descartes',
        './erasmus',
        './galileo',
        './kepler',
        './may',
        './melanchthon',
        './xylander',
        './campion'
    ]
}

#### by text

manual_corpus_texts_by_type = {
    'republican': [
        'sall.1.txt',
        'sall.2.txt',
        'sall.cotta.txt',
        'sall.ep1.txt',
        'sall.ep2.txt',
        'sall.frag.txt',
        'sall.invectiva.txt',
        'sall.lep.txt',
        'sall.macer.txt',
        'sall.mithr.txt',
        'sall.phil.txt',
        'sall.pomp.txt',
        'varro.frag.txt',
        'varro.ll10.txt',
        'varro.ll5.txt',
        'varro.ll6.txt',
        'varro.ll7.txt',
        'varro.ll8.txt',
        'varro.ll9.txt',
        'varro.rr1.txt',
        'varro.rr2.txt',
        'varro.rr3.txt',
        'sulpicia.txt'
    ],
    'augustan': [
        'resgestae.txt',
        'resgestae1.txt',
        'manilius1.txt',
        'manilius2.txt',
        'manilius3.txt',
        'manilius4.txt',
        'manilius5.txt',
        'catullus.txt',
        'vitruvius1.txt',
        'vitruvius10.txt',
        'vitruvius2.txt',
        'vitruvius3.txt',
        'vitruvius4.txt',
        'vitruvius5.txt',
        'vitruvius6.txt',
        'vitruvius7.txt',
        'vitruvius8.txt',
        'vitruvius9.txt',
        'propertius1.txt',
        'tibullus1.txt',
        'tibullus2.txt',
        'tibullus3.txt'
    ],
    'early_silver': [
        'pliny.ep1.txt',
        'pliny.ep10.txt',
        'pliny.ep2.txt',
        'pliny.ep3.txt',
        'pliny.ep4.txt',
        'pliny.ep5.txt',
        'pliny.ep6.txt',
        'pliny.ep7.txt',
        'pliny.ep8.txt',
        'pliny.ep9.txt',
        'pliny.nh1.txt',
        'pliny.nh2.txt',
        'pliny.nh3.txt',
        'pliny.nh4.txt',
        'pliny.nh5.txt',
        'pliny.nhpr.txt',
        'pliny.panegyricus.txt',
        'petronius1.txt',
        'petroniusfrag.txt',
        'persius.txt',
        'phaedr1.txt',
        'phaedr2.txt',
        'phaedr3.txt',
        'phaedr4.txt',
        'phaedr5.txt',
        'phaedrapp.txt',
        'seneca.contr1.txt',
        'seneca.contr10.txt',
        'seneca.contr2.txt',
        'seneca.contr3.txt',
        'seneca.contr4.txt',
        'seneca.contr5.txt',
        'seneca.contr6.txt',
        'seneca.contr7.txt',
        'seneca.contr8.txt',
        'seneca.contr9.txt',
        'seneca.fragmenta.txt',
        'seneca.suasoriae.txt',
        'valeriusflaccus1.txt',
        'valeriusflaccus2.txt',
        'valeriusflaccus3.txt',
        'valeriusflaccus4.txt',
        'valeriusflaccus5.txt',
        'valeriusflaccus6.txt',
        'valeriusflaccus7.txt',
        'valeriusflaccus8.txt',
        'valmax1.txt',
        'valmax2.txt',
        'valmax3.txt',
        'valmax4.txt',
        'valmax5.txt',
        'valmax6.txt',
        'valmax7.txt',
        'valmax8.txt',
        'valmax9.txt',
        'vell1.txt',
        'vell2.txt'
    ],
    'late_silver': [
    ],
    'old': [
        '12tables.txt',
        'ter.adel.txt',
        'ter.andria.txt',
        'ter.eunuchus.txt',
        'ter.heauton.txt',
        'ter.hecyra.txt',
        'ter.phormio.txt',
        'andronicus.txt',
        'enn.txt'
    ],
    'medieval': [
        'anselmepistula.txt',
        'anselmproslogion.txt',
        'carm.bur.txt'
    ],
    'christian': [
        'anon.martyrio.txt',
        'benedict.txt',
        'berengar.txt',
        'bernardclairvaux.txt',
        'bernardcluny.txt',
        'bonaventura.itinerarium.txt',
        'creeds.txt',
        'decretum.txt',
        'diesirae.txt',
        'egeria.txt',
        'ennodius.txt',
        'eucherius.txt',
        'eugippius.txt',
        'greg.txt',
        'gregory.txt',
        'gregory7.txt',
        'hydatius.txt',
        'hymni.txt',
        'innocent.txt',
        'hydatius.txt',
        'junillus.txt',
        'lactantius.txt',
        'liberpontificalis.txt',
        'macarius.txt',
        'macarius1.txt',
        'novatian.txt',
        'papal.txt',
        'paulinus.poemata.txt',
        'perp.txt',
        'professio.txt',
        'prosperus.txt',
        'regula.txt',
        'sedulius.txt',
        'sulpiciusseverus.txt',
        'vorag.txt'
    ],
    'renaissance': [
        'petrarch.ep1.txt',
        'petrarch.numa.txt',
        'petrarch.rom.txt'
    ],
    'neo_latin': [
        'spinoza.ethica1.txt',
        'spinoza.ethica2.txt',
        'spinoza.ethica3.txt',
        'spinoza.ethica4.txt',
        'spinoza.ethica5.txt'
    ]
}

# %% [markdown]
# #### The following were directories that weren't obviously divisible into periods based on the web site/file directory layout.
#
# 	./alanus',
# 	'./albertanus',
# 	'./albertofaix',
# 	'./aquinas',
# 	'./ammianus',
# 	'./arnobius',
# 	'./capellanus',
# 	'./cato',
# 	'./claudian',
# 	'./curtius',
# 	'./eutropius',
# 	'./frontinus',
# 	'./gestafrancorum',
# 	'./justinian',
# 	'./lactantius',
# 	'./martinbraga',
# 	'./mirandola',
# 	'./ottofreising',
# 	'./pauldeacon',
# 	'./sha',
# 	'./theodosius',
# 	'./voragine',
# 	'./walter',
# 	'./williamtyre',

# %% [markdown]
# ## Assemble a CorpusReader of our classified docs

# %%
reader = assemble_corpus(reader, manual_corpus_texts_by_type.keys(),
                         manual_corpus_directories_by_type, 
                         manual_corpus_texts_by_type )
files_types = get_file_type_list(reader.fileids(), manual_corpus_texts_by_type, manual_corpus_directories_by_type)
docs_already_classified, categories = zip(*files_types)
reader._fileids = docs_already_classified
docs_to_classify = list(set(all_docs) ^ set(docs_already_classified))
print(f'Docs already classified: {len(docs_already_classified):,}')
print(f'Docs to classify: {len(docs_to_classify):,}')
# Out:
# Docs already classified: 1,278
# Docs to classify: 863

# %% [markdown]
# ## Create a LabelEncoder to convert the label names to integers, later on we'll reverse the process

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform( np.array(categories).ravel())
print(f'Y shape: {y.shape} e.g.: {y}')
print(f'Label encoder classes: {label_encoder.classes_}')
# Out:
# Y shape: (1278,) e.g.: [6 1 1 ... 0 0 5]
# Label encoder classes: ['augustan' 'christian' 'early_silver' 'late_silver' 'medieval'
#  'neo_latin' 'old' 'renaissance' 'republican']

# %% [markdown]
# ## Use a custom transformer to prepare the data matrix

# %%
dummyX = [
    ['The quick brown fox. The lazy dog.'],
    ['Waiting for godot. Looking for the sunshine.']
]

newX = Doc2TokensTransformer().transform(dummyX)
print(list(newX))
# Out:
# [['The', 'quick', 'brow', 'fox', 'The', 'lazy', 'dog'], ['Waiting', 'for', 'godot', 'Looking', 'for', 'the', 'sunshine']]

# %%
X = list(reader.docs(reader.fileids()))
print(f'doc matrix size: {len(X):,}')
# Out:
# doc matrix size: 1,278

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
# With a larger labelled data set our test size would be higher, but lower here is okay
# because we just want to see some differences among classifiers
print(f'X_train size: {len(X_train):,}, X_test size: {len(X_test):,}')
print(f'y_train size: {len(y_train):,}, y_test size: {len(y_test):,}')
# Out:
# X_train size: 1,150, X_test size: 128
# y_train size: 1,150, y_test size: 128

# %% [markdown]
# ### We'll use Tfidf Vectorization
# Tfidf will help cluster similar words into similar eras.
# However it will also tend to cluster documents by subject and theme, which will likely span across eras.
# Later we will investigate the use of other approaches.

# %%
def train(classifier, X_train, X_test, y_train, y_test):
    classifier.fit(X_train, y_train)
    print("Accuracy: %s" % classifier.score(X_test, y_test))
    return classifier

def identity (data):
    """Identity, as in math; you know, do nothing, just be yourself."""
    return data

trial1 = Pipeline([
    ('normalizer', Doc2TokensTransformer()),
    ('vectorizer', TfidfVectorizer(
        analyzer='word',
        tokenizer=identity,
        preprocessor=identity,
        token_pattern=None)),
    ('classifier', MultinomialNB())
])

train(trial1, X_train, X_test, y_train, y_test)
# Out:
# Accuracy: 0.6953125
# Pipeline(memory=None,
#      steps=[('normalizer', Doc2TokensTransformer(drop_regexes=[re.compile('[0-9]+[a-zA-Z]'), re.compile('\\s+')],
#            language=None,
#            valid_chars={'Ȳ', 'ī', 'O', 'w', 'K', 'P', 'Ē', 'j', 'n', 'Ū', 'J', 'T', 'G', 'ū', 'Ā', 'a', 'e', 'A', 'V', 'Ü', 'z', 'ō', 'q', 'X', 'Y', 'C', 'ö', 'ā', '...True, vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %% [markdown]
# ## Train a Dummy classifier to see the baseline we must improve above

# %%
dummy = DummyClassifier(strategy='stratified', random_state=0)
features_train, features_test, target_train, target_test = train_test_split(X, y, random_state=0)
dummy.fit(features_train, target_train)
dummy_score = dummy.score(features_test, target_test)
print(f'Dummy classifier: {dummy_score}')
# Out:
# Dummy classifier: 0.175

# %%
def model_selection(X_train, y_train, X_test, y_test, estimator):
    """
    Test various estimators.
    """

    model = Pipeline([
        ('normalizer', Doc2TokensTransformer()),
        ('vectorizer', TfidfVectorizer(
            analyzer='word',
            tokenizer=identity,
            preprocessor=identity,
            token_pattern=None)),
        ('classifier', estimator())
    ])
    model.fit(X_train, y_train)
    return ("Accuracy: %s" % model.score(X_test, y_test))

# %%
classifiers = [LinearSVC, SVC, KNeighborsClassifier, LogisticRegressionCV, MultinomialNB,
        LogisticRegression, SGDClassifier, BaggingClassifier,
        ExtraTreesClassifier, RandomForestClassifier]

for cls in tqdm(classifiers):
    print(f'Testing {str(cls)}')
    print(model_selection(X_train, y_train, X_test, y_test, cls))
    print(''.ljust(50, '-'))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Testing <class 'sklearn.svm.classes.LinearSVC'>
#  10%|█         | 1/10 [00:02<00:24,  2.75s/it]
# Accuracy: 0.6796875
# --------------------------------------------------
# Testing <class 'sklearn.svm.classes.SVC'>
#  20%|██        | 2/10 [00:05<00:21,  2.75s/it]
# Accuracy: 0.6796875
# --------------------------------------------------
# Testing <class 'sklearn.neighbors.classification.KNeighborsClassifier'>
#  30%|███       | 3/10 [00:08<00:19,  2.74s/it]
# Accuracy: 0.6640625
# --------------------------------------------------
# Testing <class 'sklearn.linear_model.logistic.LogisticRegressionCV'>
#  40%|████      | 4/10 [00:12<00:19,  3.28s/it]
# Accuracy: 0.6796875
# --------------------------------------------------
# Testing <class 'sklearn.naive_bayes.MultinomialNB'>
#  50%|█████     | 5/10 [00:15<00:15,  3.13s/it]
# Accuracy: 0.6953125
# --------------------------------------------------
# Testing <class 'sklearn.linear_model.logistic.LogisticRegression'>
#  60%|██████    | 6/10 [00:18<00:12,  3.01s/it]
# Accuracy: 0.6953125
# --------------------------------------------------
# Testing <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'>
#  70%|███████   | 7/10 [00:20<00:08,  2.93s/it]
# Accuracy: 0.5546875
# --------------------------------------------------
# Testing <class 'sklearn.ensemble.bagging.BaggingClassifier'>
#  80%|████████  | 8/10 [00:23<00:05,  2.87s/it]
# Accuracy: 0.6796875
# --------------------------------------------------
# Testing <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
#  90%|█████████ | 9/10 [00:26<00:02,  2.85s/it]
# Accuracy: 0.6796875
# --------------------------------------------------
# Testing <class 'sklearn.ensemble.forest.RandomForestClassifier'>
# 100%|██████████| 10/10 [00:29<00:00,  2.81s/it]
# Accuracy: 0.6796875
# --------------------------------------------------

# %%
# Train all the data using a reasonable winner
model = Pipeline([
    ('normalizer', Doc2TokensTransformer()),
    ('vectorizer', TfidfVectorizer(
        analyzer='word',
        tokenizer=identity,
        preprocessor=identity,
        token_pattern=None)),
    ('classifier', LogisticRegression())
])

model.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('normalizer', Doc2TokensTransformer(drop_regexes=[re.compile('[0-9]+[a-zA-Z]'), re.compile('\\s+')],
#            language=None,
#            valid_chars={'Ȳ', 'ī', 'O', 'w', 'K', 'P', 'Ē', 'j', 'n', 'Ū', 'J', 'T', 'G', 'ū', 'Ā', 'a', 'e', 'A', 'V', 'Ü', 'z', 'ō', 'q', 'X', 'Y', 'C', 'ö', 'ā', '...penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
unclassified_reader = get_corpus_reader(corpus_name='latin_text_latin_library', language='latin')
unclassified_reader.skip_keywords = None
to_classify_X = list(unclassified_reader.docs(docs_to_classify ))
new_labels = model.predict(to_classify_X)
print (f'Shape new_labels: {new_labels.shape} e.g.: {new_labels[:5]}...')
# Out:
# Shape new_labels: (863,) e.g.: [1 2 8 1 1]...

# %%
new_cats = defaultdict(list)
for idx, filename in enumerate(docs_to_classify):
    new_cats[label_encoder.classes_[new_labels[idx]]].append(filename)
print(new_cats)
# Out:
# defaultdict(<class 'list'>, {'christian': ['sha/30.txt', 'ammianus/27.txt', 'justin/32.txt', 'ilias.txt', 'appverg.aetna.txt', 'gaius3.txt', 'theodosius/theod13.txt', 'andreasbergoma.txt', 'voragine/ambro.txt', 'justin/28.txt', 'walter/walter3.txt', 'justin/42.txt', 'albertofaix/hist12.txt', 'capellanus/capellanus3.txt', 'johannes.txt', 'ammianus/18.txt', 'justin/4.txt', 'voragine/vir.txt', 'williamtyre/14.txt', 'ammianus/24.txt', 'voragine/georgio.txt', 'justin/33.txt', 'venantius.txt', 'justin/18.txt', 'williamtyre/3.txt', 'avienus.periegesis.txt', 'vegetius2.txt', 'walter6.txt', 'avienus.ora.txt', 'justin/15.txt', 'theodosius/theod16.txt', 'iamdulcis.txt', 'walter12.txt', 'dumdiane.txt', 'richerus2.txt', 'williamtyre/11.txt', 'justin/30.txt', 'williamtyre/4.txt', 'valesianus2.txt', 'ammianus/23.txt', 'theodosius/theod04.txt', 'archpoet.txt', 'withof3.txt', 'smarius.txt', 'voragine/jud.txt', 'justin/13.txt', 'justinian/institutes.proem.txt', 'williamtyre/22.txt', 'sha/firmus.txt', 'vegetius1.txt', 'pontano.txt', 'albertanus/albertanus.sermo1.txt', 'arnobius/arnobius4.txt', 'declaratio.txt', 'victor.caes2.txt', 'walter/pastourelles.txt', 'gestafrancorum/gestafrancorum1.txt', 'septsap.txt', 'index.txt', 'theodosius/theod12.txt', 'sha/geta.txt', 'gregdecretals3.txt', 'raoul.txt', 'gaius1.txt', 'justin/9.txt', 'justin/37.txt', 'voragine/septem.txt', 'indices.txt', 'eutropius/eutropius7.txt', 'eutropius/eutropius8.txt', 'arnobius/arnobius7.txt', 'vegetius4.txt', 'malaterra2.txt', 'marx.txt', 'vestiunt.txt', 'appverg.catalepton.txt', 'williamtyre/1.txt', 'williamtyre/10.txt', 'voragine/thom.txt', 'theodosius/theod10.txt', 'malaterra4.txt', 'vegius.txt', 'walter5.txt', 'tempusest.txt', 'gestafrancorum/gestafrancorum9.txt', 'ammianus/29.txt', 'godfrey.epigrammatahist.txt', 'albertofaix/hist11.txt', 'xanten.txt', 'piccolomini.carmen.txt', 'grattius.txt', 'justin/22.txt', 'apuleius/apuleius.deosocratis.txt', 'theodosius/theod09.txt', 'walter9.txt', 'voragine/anast.txt', 'sha/gall.txt', 'justin/11.txt', 'ammianus/31.txt', 'gaius4.txt', 'gestafrancorum/gestafrancorum8.txt', 'rimbaud.txt', 'abbofloracensis.txt', 'sha/avid.txt', 'justin/31.txt', 'apuleius/apuleius.dog1.txt', 'ammianus/15.txt', 'vico.orat6.txt', 'planctus.txt', 'williamtyre/5.txt', 'alanus/alanus2.txt', 'albertanus/albertanus.sermo3.txt', 'ep.priapismo.txt', 'voragine/marc.txt', 'albertofaix/hist6.txt', 'gaud.txt', 'albertofaix/hist2.txt', 'albertofaix/hist7.txt', 'epistaustras.txt', 'withof1.txt', 'justin/14.txt', 'gregdecretals1.txt', 'justin/16.txt', 'justin/1.txt', 'aus.sept.sent.txt', 'ammianus/21.txt', 'voragine/iul.txt', 'justin/36.txt', 'ammianus/26.txt', 'janus2.txt', 'vegetius3.txt', 'justin/38.txt', 'annalesregnifrancorum.txt', 'apuleius/apuleius.dog2.txt', 'justinian/institutes4.txt', 'eutropius/eutropius3.txt', 'williamtyre/13.txt', 'eutropius/eutropius5.txt', 'asserius.txt', 'williamapulia.txt', 'aus.mos.txt', 'apuleius/apuleius.apol.txt', 'ammianus/30.txt', 'epitomecononiana.txt', 'owen.txt', 'justin/43.txt', 'voragine/chris.txt', 'gestafrancorum/gestafrancorum5.txt', 'gaius2.txt', 'richerus1.txt', 'eutropius/eutropius10.txt', 'appvergcomp.txt', 'ein.txt', 'williamtyre/18.txt', 'justin/6.txt', 'williamtyre/21.txt', 'vitacaroli.txt', 'theodosius/theod14.txt', 'terraiam.txt', 'albertanus/albertanus.arsloquendi.txt', 'justin/prologi.txt', 'albertanus/albertanus4.txt', 'mapps1.txt', 'justin/40.txt', 'justin/41.txt', 'vida.txt', 'sha/gord.txt', 'sha/tacitus.txt', 'holberg.txt', 'annalesvedastini.txt', 'theodosius/theod11.txt', 'williamtyre/7.txt', 'justinian/institutes1.txt', 'ammianus/16.txt', 'albertofaix/hist1.txt', 'gestafrancorum/gestafrancorum10.txt', 'justin/25.txt', 'victor.origio.txt', 'capellanus/capellanus2.txt', 'albertanus/albertanus.sermo.txt', 'landor1795.txt', 'iordanes2.txt', 'fortunat.txt', 'exivi.txt', 'justin/44.txt', 'passerat.txt', 'waltarius2.txt', 'williamtyre/17.txt', 'arnobius/arnobius6.txt', 'theganus.txt', 'reposianus.txt', 'albertofai ...

# %%
with open('new_cats.json', mode='w', encoding='utf8') as writer:
    json.dump(new_cats, writer, indent=2)

# %%
with open('latin_text_classifier.mdl.pkl', 'wb') as writer:
    joblib.dump(new_cats, writer)

# %%
predicted_files_cats = [ (item, key ) 
               for key, value in new_cats.items()
              for item in value               ]
predicted_files_cats.sort(key=lambda x: x[0])
print(len(predicted_files_cats))
random.sample(predicted_files_cats, 10)
# Out:
# 863
# [('falcone.txt', 'republican'),
#  ('apuleius/apuleius8.txt', 'early_silver'),
#  ('landor1806.txt', 'early_silver'),
#  ('apuleius/apuleius2.txt', 'early_silver'),
#  ('frontinus/strat2.txt', 'late_silver'),
#  ('ottofreising/epistola.txt', 'augustan'),
#  ('columba2.txt', 'augustan'),
#  ('albertofaix/hist9.txt', 'christian'),
#  ('sha/aurel.txt', 'christian'),
#  ('nemesianus4.txt', 'republican')]

# %% [markdown]
# # Vetting the data
# The mapping files and directories to eras have been manually corrected outside of this notebook, so let's use them to compare how our classifier performed.

# %%
# Load the human corrected labellings, they have been put into the CLTK library
from cltk.corpus.latin.latin_library_corpus_types import corpus_directories_by_type
from cltk.corpus.latin.latin_library_corpus_types import corpus_texts_by_type 

reader = get_corpus_reader(corpus_name='latin_text_latin_library', language='latin')
human_corrected_labels = get_file_type_list(reader.fileids(), 
                                            corpus_texts_by_type, 
                                            corpus_directories_by_type)
print(f'Number of human corrected labels {len(human_corrected_labels):,} Sample:')
human_files, human_labels = zip(*human_corrected_labels)
human_corrected_labels[:10]
# Out:
# Number of human corrected labels 1,747 Sample:
# [('12tables.txt', 'early'),
#  ('abelard/dialogus.txt', 'christian'),
#  ('abelard/epistola.txt', 'christian'),
#  ('abelard/historia.txt', 'christian'),
#  ('addison/barometri.txt', 'neo_latin'),
#  ('addison/burnett.txt', 'neo_latin'),
#  ('addison/hannes.txt', 'neo_latin'),
#  ('addison/machinae.txt', 'neo_latin'),
#  ('addison/pax.txt', 'neo_latin'),
#  ('addison/praelium.txt', 'neo_latin')]

# %% [markdown]
# ### Note
# The number of human corrected labels does not match the total number of files in the corpus,
# because if a file couldn't be reasonably matched to era, then a categorization wasn't posited.
# Often it's better to be clear about what is uncertain, rather than to push a false sense of confidence.

# %%
    
num_good_predictions= sum([1 for prediction in predicted_files_cats
    if prediction in human_corrected_labels])    
print(f'Number of good predictions: {num_good_predictions}')    


for prediction in predicted_files_cats:
        if prediction in human_corrected_labels:
            print(prediction)
# Out:
# Number of good predictions: 1
# ('apuleius/apuleius.florida.txt', 'late_silver')

# %%
human_corrected_labels
# Out:
# [('12tables.txt', 'early'),
#  ('abelard/dialogus.txt', 'christian'),
#  ('abelard/epistola.txt', 'christian'),
#  ('abelard/historia.txt', 'christian'),
#  ('addison/barometri.txt', 'neo_latin'),
#  ('addison/burnett.txt', 'neo_latin'),
#  ('addison/hannes.txt', 'neo_latin'),
#  ('addison/machinae.txt', 'neo_latin'),
#  ('addison/pax.txt', 'neo_latin'),
#  ('addison/praelium.txt', 'neo_latin'),
#  ('addison/preface.txt', 'neo_latin'),
#  ('addison/resurr.txt', 'neo_latin'),
#  ('addison/sphaer.txt', 'neo_latin'),
#  ('alanus/alanus1.txt', 'misc'),
#  ('alanus/alanus2.txt', 'misc'),
#  ('albertanus/albertanus.arsloquendi.txt', 'misc'),
#  ('albertanus/albertanus.liberconsol.txt', 'misc'),
#  ('albertanus/albertanus.sermo.txt', 'misc'),
#  ('albertanus/albertanus.sermo1.txt', 'misc'),
#  ('albertanus/albertanus.sermo2.txt', 'misc'),
#  ('albertanus/albertanus.sermo3.txt', 'misc'),
#  ('albertanus/albertanus.sermo4.txt', 'misc'),
#  ('albertanus/albertanus1.txt', 'misc'),
#  ('albertanus/albertanus2.txt', 'misc'),
#  ('albertanus/albertanus3.txt', 'misc'),
#  ('albertanus/albertanus4.txt', 'misc'),
#  ('albertofaix/hist1.txt', 'misc'),
#  ('albertofaix/hist10.txt', 'misc'),
#  ('albertofaix/hist11.txt', 'misc'),
#  ('albertofaix/hist12.txt', 'misc'),
#  ('albertofaix/hist2.txt', 'misc'),
#  ('albertofaix/hist3.txt', 'misc'),
#  ('albertofaix/hist4.txt', 'misc'),
#  ('albertofaix/hist5.txt', 'misc'),
#  ('albertofaix/hist6.txt', 'misc'),
#  ('albertofaix/hist7.txt', 'misc'),
#  ('albertofaix/hist8.txt', 'misc'),
#  ('albertofaix/hist9.txt', 'misc'),
#  ('alcuin/cella.txt', 'christian'),
#  ('alcuin/conflictus.txt', 'christian'),
#  ('alcuin/epitaphium.txt', 'christian'),
#  ('alcuin/luscinia.txt', 'christian'),
#  ('alcuin/propos.txt', 'christian'),
#  ('alcuin/rec.txt', 'christian'),
#  ('alcuin/rhetorica.txt', 'christian'),
#  ('alcuin/sequentia.txt', 'christian'),
#  ('alcuin/versus.txt', 'christian'),
#  ('ambrose/epist.txt', 'christian'),
#  ('ambrose/epistvaria.txt', 'christian'),
#  ('ambrose/hymns.txt', 'christian'),
#  ('ambrose/mysteriis.txt', 'christian'),
#  ('ammianus/14.txt', 'misc'),
#  ('ammianus/15.txt', 'misc'),
#  ('ammianus/16.txt', 'misc'),
#  ('ammianus/17.txt', 'misc'),
#  ('ammianus/18.txt', 'misc'),
#  ('ammianus/19.txt', 'misc'),
#  ('ammianus/20.txt', 'misc'),
#  ('ammianus/21.txt', 'misc'),
#  ('ammianus/22.txt', 'misc'),
#  ('ammianus/23.txt', 'misc'),
#  ('ammianus/24.txt', 'misc'),
#  ('ammianus/25.txt', 'misc'),
#  ('ammianus/26.txt', 'misc'),
#  ('ammianus/27.txt', 'misc'),
#  ('ammianus/28.txt', 'misc'),
#  ('ammianus/29.txt', 'misc'),
#  ('ammianus/30.txt', 'misc'),
#  ('ammianus/31.txt', 'misc'),
#  ('andronicus.txt', 'old'),
#  ('anon.martyrio.txt', 'christian'),
#  ('anselmepistula.txt', 'medieval'),
#  ('anselmproslogion.txt', 'medieval'),
#  ('apicius/apicius1.txt', 'late_silver'),
#  ('apicius/apicius2.txt', 'late_silver'),
#  ('apicius/apicius3.txt', 'late_silver'),
#  ('apicius/apicius4.txt', 'late_silver'),
#  ('apicius/apicius5.txt', 'late_silver'),
#  ('apuleius/apuleius.apol.txt', 'late_silver'),
#  ('apuleius/apuleius.cupid.txt', 'late_silver'),
#  ('apuleius/apuleius.deosocratis.txt', 'late_silver'),
#  ('apuleius/apuleius.dog1.txt', 'late_silver'),
#  ('apuleius/apuleius.dog2.txt', 'late_silver'),
#  ('apuleius/apuleius.florida.txt', 'late_silver'),
#  ('apuleius/apuleius.mundo.txt', 'late_silver'),
#  ('apuleius/apuleius1.txt', 'late_silver'),
#  ('apuleius/apuleius10.txt', 'late_silver'),
#  ('apuleius/apuleius11.txt', 'late_silver'),
#  ('apuleius/apuleius2.txt', 'late_silver'),
#  ('apuleius/apuleius3.txt', 'late_silver'),
#  ('apuleius/apuleius4.txt', 'late_silver'),
#  ('apuleius/apuleius5.txt', 'late_silver'),
#  ('apuleius/apuleius6.txt', 'late_silver'),
#  ('apuleius/apuleius7.txt', 'late_silver'),
#  ('apuleius/apuleius8.txt', 'late_silver'),
#  ('apuleius/apuleius9.txt', 'late_silver'),
#  ('aquinas/corpuschristi.txt', 'misc'),
#  ('aquinas/ente.txt', 'misc'),
#  ('aquinas/epist.txt', 'misc'),
#  ('aquinas/expositio.txt', 'misc'),
#  ('aquinas/p1.txt', 'misc'),
#  ('aquinas/princ.txt', 'misc'),
#  ('aquinas/prologus.txt', 'misc'),
#  ('aquinas/q1.1.txt', 'misc'),
#  ('aquinas/q1.10.txt', 'misc'),
#  ('aquinas/q1.11.txt', 'misc'),
#  ('aquinas/q1.12.txt', 'misc'),
#  ('aquinas/q1.13.txt', 'misc'),
#  ('aquinas/q1.14.txt', 'misc'),
#  ('aquinas/q1.15.txt', 'misc'),
#  ('aquinas/q1.16.txt', 'misc'),
#  ('aquinas/q1.17.txt', 'misc'),
#  ('aquinas/q1.18.txt', 'misc'),
#  ('aquinas/q1.19.txt', 'misc'),
#  ('aquinas/q1.2.txt', 'misc'),
#  ('aquinas/q1.20.txt', 'misc'),
#  ('aquinas/q1.21.txt', 'misc'),
#  ('aquinas/q1.22.txt', 'misc'),
#  ('aquinas/q1.23.txt', 'misc'),
#  ('aquinas/q1.24.txt', 'misc'),
#  ('aquinas/q1.25.txt', 'misc'),
#  ('aquinas/q1.26.txt', 'misc'),
#  ('aquinas/q1.27.txt', 'misc'),
#  ('aquinas/q1.28.txt', 'misc'),
#  ('aquinas/q1.29.txt', 'misc'),
#  ('aquinas/q1.3.txt', 'misc'),
#  ('aquinas/q1.30.txt', 'misc'),
#  ('aquinas/q1.31.txt', 'misc'),
#  ('aquinas/q1.32.txt', 'misc'),
#  ('aquinas/q1.33.txt', 'misc'),
#  ('aquinas/q1.34.txt', 'misc'),
#  ('aquinas/q1.35.txt', 'misc'),
#  ('aquinas/q1.36.txt', 'misc'),
#  ('aquinas/q1.37.txt', 'misc'),
#  ('aquinas/q1.38.txt', 'misc'),
#  ('aquinas/q1.39.txt', 'misc'),
#  ('aquinas/q1.4.txt', 'misc'),
#  ('aquinas/q1.40.txt', 'misc'),
#  ('aquinas/q1.41.txt', 'misc'),
#  ('aquinas/q1.42.txt', 'misc'),
#  ('aquinas/q1.43.txt', 'misc'),
#  ('aquinas/q1.44.txt', 'misc'),
#  ('aquinas/q1.45.txt', 'misc'),
#  ('aquinas/q1.46.txt', 'misc'),
#  ('aquinas/q1.47.txt', 'misc'),
#  ('aquinas/q1.48.txt', 'misc'),
#  ('aquinas/q1.49.txt', 'misc'),
#  ('aquinas/q1.5.txt', 'misc'),
#  ('aquinas/q1.50.txt', 'misc'),
#  ('aquinas/q1.51.txt', 'misc'),
#  ('aquinas/q1.52.txt', 'misc'),
#  ('aquinas/q1.53.txt', 'misc'),
#  ('aquinas/q1.54.txt', 'misc'),
#  ('aquinas/q1.55.txt', 'misc'),
#  ('aquinas/q1.56.txt', 'misc'),
#  ('aquinas/q1.57.txt', 'misc'),
#  ('aquinas/q1.58.txt', 'misc'),
#  ('aquinas/q1.59.txt', 'misc'),
#  ('aquinas/q1.6.txt', 'misc'),
#  ('aquinas/q1.60.txt', 'misc'),
#  ('aquinas/q1.61.txt', 'misc'),
#  ('aquinas/q1.62.txt', 'misc'),
#  ('aquinas/q1.63.txt', 'misc'),
#  ('aquinas/q1.64.txt', 'misc'),
#  ('aquinas/q1.65.txt', 'misc'),
#  ('aquinas/q1.66.txt', 'misc'),
#  ('aquinas/q1.67.txt', 'misc'),
#  ('aquinas/q1.68.txt', 'misc'),
#  ('aquinas/q1.69.txt', 'misc'),
#  ('aquinas/q1.7.txt', 'misc'),
#  ('aquinas/q1.70.txt', 'misc'),
#  ('aquinas/q1.71.txt', 'misc'),
#  ('aquinas/q1.72.txt', 'misc'),
#  ('aquinas/q1.73.txt', 'misc'),
#  ('aquinas/q1.74.txt', 'misc'),
#  ('aquinas/q1.8.txt', 'misc'),
#  ('aquinas/q1.80.txt', 'misc'),
#  ('aquinas/q1.81.txt', 'misc'),
#  ('aquinas/q1.82.txt', 'misc'),
#  ('aquinas/q1.83.txt', 'misc'),
#  ('aquinas/q1.86.txt', 'misc'),
#  ('aquinas/q1.87.txt', 'misc'),
#  ('aquinas/q1.9.txt', 'misc'),
#  ('arnobius/arnobius1.txt', 'misc'),
#  ('arnobius/arnobius2.txt', 'misc'),
#  ('arnobius/arnobius3.txt', 'misc'),
#  ('arnobius/arnobius4.txt', 'misc'),
#  ('arnobius/arnobius5.txt', 'misc'),
#  ('arnobius/arnobius6.txt', 'misc'),
#  ('arnobius/arnobius7.txt', 'misc'),
#  ('augustine/catechizandis.txt', 'christian'),
#  ('augustine/civ1.txt', 'christian'),
#  ('augustine/civ10.txt', 'christian'),
#  ('augustine/civ11.txt', 'christian'),
#  ('augustine/civ12.txt', 'christian'),
#  ('augustine/civ13.txt', 'christian'),
#  ('augustine/civ14.txt', 'christian'),
#  ('augustine/civ15.txt', 'christian'),
#  ('augustine/civ16.txt', 'christian'),
#  ('augustine/civ17.txt', 'christian'),
#  ('augustine/civ18.txt', 'christian'),
#  ('augustine/civ19.txt', 'christian'),
#  ('augustine/civ2.txt', 'christian'),
#  ('augustine/civ20.txt', 'christian'),
#  ('augustine/civ21.txt', 'christian'),
#  ('augustine/civ22.txt', 'christian'),
#  ('augustine/civ3.txt', 'christian'),
#  ('augustine/civ4.txt', 'christian'),
#  ('augustine/civ5.txt', 'christian'),
#  ('augustine/civ6.txt', 'christian'),
#  ('augustine/civ7.txt', 'christian'),
#  ('augustine/civ8.txt', 'christian'),
#  ('augustine/civ9.txt', 'christian'),
#  ('augustine/conf1.txt', 'christian'),
#  ('augustine/conf10.txt', 'christian'),
#  ('augustine/conf11.txt', 'christian'),
#  ('augustine/conf12.txt', 'christian'),
#  ('augustine/conf13.txt', 'christian'),
#  ('augustine/conf2.txt', 'christian'),
#  ('augustine/conf3.txt', 'christian'),
#  ('augustine/conf4.txt', 'christian'),
#  ('augustine/conf5.txt', 'christian'),
#  ('augustine/conf6.txt', 'christian'),
#  ('augustine/conf7.txt', 'christian'),
#  ('augustine/conf8.txt', 'christian'),
#  ('augustine/conf9.txt', 'christian'),
#  ('augustine/dia.txt', 'christian'),
#  ('augustine/epistula.txt', 'christian'),
#  ('augustine/fide.txt', 'christian'),
#  ('augustine/iulianus1.txt', 'christian'),
#  ('augustine/iulianus2.txt', 'christian'),
#  ('augustine/reg.txt', 'christian'),
#  ('augustine/serm1.txt', 'christian'),
#  ('augustine/serm10.txt', 'christian'),
#  ('augustine/serm11.txt', 'christian'),
#  ('augustine/serm12.txt', 'christian'),
#  ('augustine/serm13.txt', 'christian'),
#  ('augustine/serm14.txt', 'christian'),
#  ('augustine/serm15.txt', 'christian'),
#  ('augustine/serm16.txt', 'christian'),
#  ('augustine/serm17.txt', 'christian'),
#  ('augustine/serm18.txt', 'christian'),
#  ('augustine/serm19.txt', 'christian'),
#  ('augustine/serm2.txt', 'christian'),
#  ('augustine/serm20.txt', 'christian'),
#  ('augustine/serm4.txt', 'christian'),
#  ('augustine/serm5.txt', 'christian'),
#  ('augustine/serm6.txt', 'christian'),
#  ('augustine/serm7.txt', 'christian'),
#  ('augustine/serm71.txt', 'christian'),
#  ('augustine/serm72.txt', 'christian'),
#  ('augustine/serm73.txt', 'christian'),
#  ('augustine/serm74.txt', 'christian'),
#  ('augustine/serm75.txt', 'christian'),
#  ('augustine/serm76.txt', 'christian'),
#  ('augustine/serm77.txt', 'christian'),
#  ('augustine/serm78.txt', 'christian'),
#  ('augustine/serm79.txt', 'christian'),
#  ('augustine/serm8.txt', 'christian'),
#  ('augustine/serm80.txt', 'christian'),
#  ('augustine/serm81.txt', 'christian'),
#  ('augustine/serm82.txt', 'christian'),
#  ('augustine/serm83.txt', 'christian'),
#  ('augustine/serm87.txt', 'christian'),
#  ('augustine/serm88.txt', 'christian'),
#  ('augustine/serm9.txt', 'christian'),
#  ('augustine/serm90.txt', 'christian'),
#  ('augustine/serm92.txt', 'christian'),
#  ('augustine/serm95.txt', 'christian'),
#  ('augustine/serm99.txt', 'christian'),
#  ('augustine/trin1.txt', 'christian'),
#  ('augustine/trin10.txt', 'christian'),
#  ('augustine/trin11.txt', 'christian'),
#  ('augustine/trin12.txt', 'christian'),
#  ('augustine/trin13.txt', 'christian'),
#  ('augustine/trin14.txt', 'christian'),
#  ('augustine/trin15.txt', 'christian'),
#  ('augustine/trin2.txt', 'christian'),
#  ('augustine/trin3.txt', 'christian'),
#  ('augustine/trin4.txt', 'christian'),
#  ('augustine/trin5.txt', 'christian'),
#  ('augustine/trin6.txt', 'christian'),
#  ('augustine/trin7.txt', 'christian'),
#  ('augustine/trin8.txt', 'christian'),
#  ('augustine/trin9.txt', 'christian'),
#  ('bacon/bacon.distributio.txt', 'neo_latin'),
#  ('bacon/bacon.epistola.txt', 'neo_latin'),
#  ('bacon/bacon.hist1.txt', 'neo_latin'),
#  ('bacon/bacon.hist10.txt', 'neo_latin'),
#  ('bacon/bacon.hist11.txt', 'neo_latin'),
#  ('bacon/bacon.hist2.txt', 'neo_latin'),
#  ('bacon/bacon.hist3.txt', 'neo_latin'),
#  ('bacon/bacon.hist4.txt', 'neo_latin'),
#  ('bacon/bacon.hist5.txt', 'neo_latin'),
#  ('bacon/bacon.hist6.txt', 'neo_latin'),
#  ('bacon/bacon.hist7.txt', 'neo_latin'),
#  ('bacon/bacon.hist8.txt', 'neo_latin'),
#  ('bacon/bacon.hist9.txt', 'neo_latin'),
#  ('bacon/bacon.intro.txt', 'neo_latin'),
#  ('bacon/bacon.liber1.txt', 'neo_latin'),
#  ('bacon/bacon.liber2.txt', 'neo_latin'),
#  ('bacon/bacon.praefatio.txt', 'neo_latin'),
#  ('bacon/bacon.praefatio2.txt', 'neo_latin'),
#  ('bacon/bacon.sermones.txt', 'neo_latin'),
#  ('bacon/bacon.titlepage.txt', 'neo_latin'),
#  ('bede/bede1.txt', 'christian'),
#  ('bede/bede2.txt', 'christian'),
#  ('bede/bede3.txt', 'christian'),
#  ('bede/bede4.txt', 'christian'),
#  ('bede/bede5.txt', 'christian'),
#  ('bede/bedecontinuatio.txt', 'christian'),
#  ('bede/bedepraef.txt', 'christian'),
#  ('bede/bedeproverbs.txt', 'christian'),
#  ('benedict.txt', 'christian'),
#  ('berengar.txt', 'christian'),
#  ('bible/acts.txt', 'christian'),
#  ('bible/amos.txt', 'christian'),
#  ('bible/baruch.txt', 'christian'),
#  ('bible/chronicles1.txt', 'christian'),
#  ('bible/chronicles2.txt', 'christian'),
#  ('bible/colossians.txt', 'christian'),
#  ('bible/corinthians1.txt', 'christian'),
#  ('bible/corinthians2.txt', 'christian'),
#  ('bible/daniel.txt', 'christian'),
#  ('bible/deuteronomy.txt', 'christian'),
#  ('bible/ecclesiastes.txt', 'christian'),
#  ('bible/ephesians.txt', 'christian'),
#  ('bible/esdras1.txt', 'christian'),
#  ('bible/esdras2.txt', 'christian'),
#  ('bible/esther.txt', 'christian'),
#  ('bible/exodus.txt', 'christian'),
#  ('bible/ezekiel.txt', 'christian'),
#  ('bible/ezra.txt', 'christian'),
#  ('bible/galatians.txt', 'christian'),
#  ('bible/genesis.txt', 'christian'),
#  ('bible/habakkuk.txt', 'christian'),
#  ('bible/haggai.txt', 'christian'),
#  ('bible/hebrews.txt', 'christian'),
#  ('bible/hosea.txt', 'christian'),
#  ('bible/isaiah.txt', 'christian'),
#  ('bible/james.txt', 'christian'),
#  ('bible/jeremiah.txt', 'christian'),
#  ('bible/job.txt', 'christian'),
#  ('bible/joel.txt', 'christian'),
#  ('bible/john.txt', 'christian'),
#  ('bible/john1.txt', 'christian'),
#  ('bible/john2.txt', 'christian'),
#  ('bible/john3.txt', 'christian'),
#  ('bible/jonah.txt', 'christian'),
#  ('bible/joshua.txt', 'christian'),
#  ('bible/jude.txt', 'christian'),
#  ('bible/judges.txt', 'christian'),
#  ('bible/judith.txt', 'christian'),
#  ('bible/kings1.txt', 'christian'),
#  ('bible/kings2.txt', 'christian'),
#  ('bible/lamentations.txt', 'christian'),
#  ('bible/leviticus.txt', 'christian'),
#  ('bible/luke.txt', 'christian'),
#  ('bible/macabees1.txt', 'christian'),
#  ('bible/macabees2.txt', 'christian'),
#  ('bible/malachias.txt', 'christian'),
#  ('bible/manasses.txt', 'christian'),
#  ('bible/mark.txt', 'christian'),
#  ('bible/matthew.txt', 'christian'),
#  ('bible/micah.txt', 'christian'),
#  ('bible/nahum.txt', 'christian'),
#  ('bible/nehemiah.txt', 'christian'),
#  ('bible/numbers.txt', 'christian'),
#  ('bible/obadiah.txt', 'christian'),
#  ('bible/peter1.txt', 'christian'),
#  ('bible/peter2.txt', 'christian'),
#  ('bible/philemon.txt', 'christian'),
#  ('bible/philip.txt', 'christian'),
#  ('bible/prologi.txt', 'christian'),
#  ('bible/proverbs.txt', 'christian'),
#  ('bible/psalms.txt', 'christian'),
#  ('bible/revelation.txt', 'christian'),
#  ('bible/romans.txt', 'christian'),
#  ('bible/ruth.txt', 'christian'),
#  ('bible/samuel1.txt', 'christian'),
#  ('bible/samuel2.txt', 'christian'),
#  ('bible/sirach.txt', 'christian'),
#  ('bible/songofsongs.txt', 'christian'),
#  ('bible/thessalonians1.txt', 'christian'),
#  ('bible/thessalonians2.txt', 'christian'),
#  ('bible/timothy1.txt', 'christian'),
#  ('bible/timothy2.txt', 'christian'),
#  ('bible/titum.txt', 'christian'),
#  ('bible/tobia.txt', 'christian'),
#  ('bible/wisdom.txt', 'christian'),
#  ('bible/zacharias.txt', 'christian'),
#  ('bible/zephaniah.txt', 'christian'),
#  ('boethiusdacia/deaeternitate.txt', 'medieval'),
#  ('boethiusdacia/desummobono.txt', 'medieval'),
#  ('bonaventura.itinerarium.txt', 'christian'),
#  ('bultelius/bultelius1.txt', 'neo_latin'),
#  ('bultelius/bultelius2.txt', 'neo_latin'),
#  ('caesar/alex.txt', 'republican'),
#  ('caesar/bc1.txt', 'republican'),
#  ('caesar/bc2.txt', 'republican'),
#  ('caesar/bc3.txt', 'republican'),
#  ('caesar/bellafr.txt', 'republican'),
#  ('caesar/gall1.txt', 'republican'),
#  ('caesar/gall2.txt', 'republican'),
#  ('caesar/gall3.txt', 'republican'),
#  ('caesar/gall4.txt', 'republican'),
#  ('caesar/gall5.txt', 'republican'),
#  ('caesar/gall6.txt', 'republican'),
#  ('caesar/gall7.txt', 'republican'),
#  ('caesar/gall8.txt', 'republican'),
#  ('caesar/hisp.txt', 'republican'),
#  ('campion/campion.elegies.txt', 'neo_latin'),
#  ('campion/campion.epigr1.txt', 'neo_latin'),
#  ('campion/campion.epigr2.txt', 'neo_latin'),
#  ('campion/campion.misc.txt', 'neo_latin'),
#  ('campion/campion.plot1.txt', 'neo_latin'),
#  ('campion/campion.plot2.txt', 'neo_latin'),
#  ('campion/campion.thamesin.txt', 'neo_latin'),
#  ('campion/campion.umbra.txt', 'neo_latin'),
#  ('capellanus/capellanus1.txt', 'misc'),
#  ('capellanus/capellanus2.txt', 'misc'),
#  ('capellanus/capellanus3.txt', 'misc'),
#  ('carm.bur.txt', 'medieval'),
#  ('cassiodorus/anima.txt', 'christian'),
#  ('cassiodorus/epist.txt', 'christian'),
#  ('cassiodorus/musica.txt', 'christian'),
#  ('cassiodorus/orationes.txt', 'christian'),
#  ('cassiodorus/varia.praef.txt', 'christian'),
#  ('cassiodorus/varia1.txt', 'christian'),
#  ('cassiodorus/varia10.txt', 'christian'),
#  ('cassiodorus/varia11.txt', 'christian'),
#  ('cassiodorus/varia12.txt', 'christian'),
#  ('cassiodorus/varia2.txt', 'christian'),
#  ('cassiodorus/varia3.txt', 'christian'),
#  ('cassiodorus/varia4.txt', 'christian'),
#  ('cassiodorus/varia5.txt', 'christian'),
#  ('cassiodorus/varia6.txt', 'christian'),
#  ('cassiodorus/varia7.txt', 'christian'),
#  ('cassiodorus/varia8.txt', 'christian'),
#  ('cassiodorus/varia9.txt', 'christian'),
#  ('cato/cato.agri.txt', 'misc'),
#  ('cato/cato.frag.txt', 'misc'),
#  ('catullus.txt', 'augustan'),
#  ('cicero/acad.txt', 'republican'),
#  ('cicero/adbrutum1.txt', 'republican'),
#  ('cicero/adbrutum2.txt', 'republican'),
#  ('cicero/amic.txt', 'republican'),
#  ('cicero/arch.txt', 'republican'),
#  ('cicero/att1.txt', 'republican'),
#  ('cicero/att10.txt', 'republican'),
#  ('cicero/att11.txt', 'republican'),
#  ('cicero/att12.txt', 'republican'),
#  ('cicero/att13.txt', 'republican'),
#  ('cicero/att14.txt', 'republican'),
#  ('cicero/att15.txt', 'republican'),
#  ('cicero/att16.txt', 'republican'),
#  ('cicero/att2.txt', 'republican'),
#  ('cicero/att3.txt', 'republican'),
#  ('cicero/att4.txt', 'republican'),
#  ('cicero/att5.txt', 'republican'),
#  ('cicero/att6.txt', 'republican'),
#  ('cicero/att7.txt', 'republican'),
#  ('cicero/att8.txt', 'republican'),
#  ('cicero/att9.txt', 'republican'),
#  ('cicero/balbo.txt', 'republican'),
#  ('cicero/brut.txt', 'republican'),
#  ('cicero/caecilium.txt', 'republican'),
#  ('cicero/caecina.txt', 'republican'),
#  ('cicero/cael.txt', 'republican'),
#  ('cicero/cat1.txt', 'republican'),
#  ('cicero/cat2.txt', 'republican'),
#  ('cicero/cat3.txt', 'republican'),
#  ('cicero/cat4.txt', 'republican'),
#  ('cicero/cluentio.txt', 'republican'),
#  ('cicero/compet.txt', 'republican'),
#  ('cicero/consulatu.txt', 'republican'),
#  ('cicero/deio.txt', 'republican'),
#  ('cicero/divinatione1.txt', 'republican'),
#  ('cicero/divinatione2.txt', 'republican'),
#  ('cicero/domo.txt', 'republican'),
#  ('cicero/fam1.txt', 'republican'),
#  ('cicero/fam10.txt', 'republican'),
#  ('cicero/fam11.txt', 'republican'),
#  ('cicero/fam12.txt', 'republican'),
#  ('cicero/fam13.txt', 'republican'),
#  ('cicero/fam14.txt', 'republican'),
#  ('cicero/fam15.txt', 'republican'),
#  ('cicero/fam16.txt', 'republican'),
#  ('cicero/fam2.txt', 'republican'),
#  ('cicero/fam3.txt', 'republican'),
#  ('cicero/fam4.txt', 'republican'),
#  ('cicero/fam5.txt', 'republican'),
#  ('cicero/fam6.txt', 'republican'),
#  ('cicero/fam7.txt', 'republican'),
#  ('cicero/fam8.txt', 'republican'),
#  ('cicero/fam9.txt', 'republican'),
#  ('cicero/fato.txt', 'republican'),
#  ('cicero/fin1.txt', 'republican'),
#  ('cicero/fin2.txt', 'republican'),
#  ('cicero/fin3.txt', 'republican'),
#  ('cicero/fin4.txt', 'republican'),
#  ('cicero/fin5.txt', 'republican'),
#  ('cicero/flacco.txt', 'republican'),
#  ('cicero/fonteio.txt', 'republican'),
#  ('cicero/fratrem1.txt', 'republican'),
#  ('cicero/fratrem2.txt', 'republican'),
#  ('cicero/fratrem3.txt', 'republican'),
#  ('cicero/haruspicum.txt', 'republican'),
#  ('cicero/imp.txt', 'republican'),
#  ('cicero/inventione1.txt', 'republican'),
#  ('cicero/inventione2.txt', 'republican'),
#  ('cicero/leg1.txt', 'republican'),
#  ('cicero/leg2.txt', 'republican'),
#  ('cicero/leg3.txt', 'republican'),
#  ('cicero/legagr1.txt', 'republican'),
#  ('cicero/legagr2.txt', 'republican'),
#  ('cicero/legagr3.txt', 'republican'),
#  ('cicero/lig.txt', 'republican'),
#  ('cicero/marc.txt', 'republican'),
#  ('cicero/milo.txt', 'republican'),
#  ('cicero/murena.txt', 'republican'),
#  ('cicero/nd1.txt', 'republican'),
#  ('cicero/nd2.txt', 'republican'),
#  ('cicero/nd3.txt', 'republican'),
#  ('cicero/off1.txt', 'republican'),
#  ('cicero/off2.txt', 'republican'),
#  ('cicero/off3.txt', 'republican'),
#  ('cicero/optgen.txt', 'republican'),
#  ('cicero/orator.txt', 'republican'),
#  ('cicero/oratore1.txt', 'republican'),
#  ('cicero/oratore2.txt', 'republican'),
#  ('cicero/oratore3.txt', 'republican'),
#  ('cicero/paradoxa.txt', 'republican'),
#  ('cicero/partitione.txt', 'republican'),
#  ('cicero/phil1.txt', 'republican'),
#  ('cicero/phil10.txt', 'republican'),
#  ('cicero/phil11.txt', 'republican'),
#  ('cicero/phil12.txt', 'republican'),
#  ('cicero/phil13.txt', 'republican'),
#  ('cicero/phil14.txt', 'republican'),
#  ('cicero/phil2.txt', 'republican'),
#  ('cicero/phil3.txt', 'republican'),
#  ('cicero/phil4.txt', 'republican'),
#  ('cicero/phil5.txt', 'republican'),
#  ('cicero/phil6.txt', 'republican'),
#  ('cicero/phil7.txt', 'republican'),
#  ('cicero/phil8.txt', 'republican'),
#  ('cicero/phil9.txt', 'republican'),
#  ('cicero/piso.txt', 'republican'),
#  ('cicero/plancio.txt', 'republican'),
#  ('cicero/postreditum.txt', 'republican'),
#  ('cicero/postreditum2.txt', 'republican'),
#  ('cicero/prov.txt', 'republican'),
#  ('cicero/quinc.txt', 'republican'),
#  ('cicero/rabirio.txt', 'republican'),
#  ('cicero/rabiriopost.txt', 'republican'),
#  ('cicero/repub1.txt', 'republican'),
#  ('cicero/repub2.txt', 'republican'),
#  ('cicero/repub3.txt', 'republican'),
#  ('cicero/repub4.txt', 'republican'),
#  ('cicero/repub5.txt', 'republican'),
#  ('cicero/repub6.txt', 'republican'),
#  ('cicero/rosccom.txt', 'republican'),
#  ('cicero/scauro.txt', 'republican'),
#  ('cicero/senectute.txt', 'republican'),
#  ('cicero/sestio.txt', 'republican'),
#  ('cicero/sex.rosc.txt', 'republican'),
#  ('cicero/sulla.txt', 'republican'),
#  ('cicero/topica.txt', 'republican'),
#  ('cicero/tusc1.txt', 'republican'),
#  ('cicero/tusc2.txt', 'republican'),
#  ('cicero/tusc3.txt', 'republican'),
#  ('cicero/tusc4.txt', 'republican'),
#  ('cicero/tusc5.txt', 'republican'),
#  ('cicero/vatin.txt', 'republican'),
#  ('cicero/ver1.txt', 'republican'),
#  ('cicero/verres.2.1.txt', 'republican'),
#  ('cicero/verres.2.2.txt', 'republican'),
#  ('cicero/verres.2.3.txt', 'republican'),
#  ('cicero/verres.2.4.txt', 'republican'),
#  ('cicero/verres.2.5.txt', 'republican'),
#  ('claudian/claudian.cons6.txt', 'misc'),
#  ('claudian/claudian.olyb.txt', 'misc'),
#  ('claudian/claudian.proserp1.txt', 'misc'),
#  ('claudian/claudian.proserp2.txt', 'misc'),
#  ('claudian/claudian.proserp3.txt', 'misc'),
#  ('claudian/claudian.ruf1.txt', 'misc'),
#  ('columella/columella.arbor.txt', 'early_silver'),
#  ('columella/columella.rr1.txt', 'early_silver'),
#  ('columella/columella.rr10.txt', 'early_silver'),
#  ('columella/columella.rr11.txt', 'early_silver'),
#  ('columella/columella.rr12.txt', 'early_silver'),
#  ('columella/columella.rr2.txt', 'early_silver'),
#  ('columella/columella.rr3.txt', 'early_silver'),
#  ('columella/columella.rr4.txt', 'early_silver'),
#  ('columella/columella.rr5.txt', 'early_silver'),
#  ('columella/columella.rr6.txt', 'early_silver'),
#  ('columella/columella.rr7.txt', 'early_silver'),
#  ('columella/columella.rr8.txt', 'early_silver'),
#  ('columella/columella.rr9.txt', 'early_silver'),
#  ('commodianus/commodianus1.txt', 'christian'),
#  ('commodianus/commodianus2.txt', 'christian'),
#  ('commodianus/commodianus3.txt', 'christian'),
#  ('creeds.txt', 'christian'),
#  ('curtius/curtius10.txt', 'misc'),
#  ('curtius/curtius3.txt', 'misc'),
#  ('curtius/curtius4.txt', 'misc'),
#  ('curtius/curtius5.txt', 'misc'),
#  ('curtius/curtius6.txt', 'misc'),
#  ('curtius/curtius7.txt', 'misc'),
#  ('curtius/curtius8.txt', 'misc'),
#  ('curtius/curtius9.txt', 'misc'),
#  ('dante/ec1.txt', 'medieval'),
#  ('dante/ep.txt', 'medieval'),
#  ('dante/mon1.txt', 'medieval'),
#  ('dante/mon2.txt', 'medieval'),
#  ('dante/mon3.txt', 'medieval'),
#  ('dante/vulgar.txt', 'medieval'),
#  ('dante/vulgar2.txt', 'medieval'),
#  ('decretum.txt', 'christian'),
#  ('descartes/des.ep.txt', 'neo_latin'),
#  ('descartes/des.med1.txt', 'neo_latin'),
#  ('descartes/des.med2.txt', 'neo_latin'),
#  ('descartes/des.med3.txt', 'neo_latin'),
#  ('descartes/des.med4.txt', 'neo_latin'),
#  ('descartes/des.med5.txt', 'neo_latin'),
#  ('descartes/des.med6.txt', 'neo_latin'),
#  ('descartes/des.pr.txt', 'neo_latin'),
#  ('descartes/des.syn.txt', 'neo_latin'),
#  ('diesirae.txt', 'christian'),
#  ('enn.txt', 'old'),
#  ('ennodius.txt', 'christian'),
#  ('erasmus/antibarb.txt', 'neo_latin'),
#  ('erasmus/coll.txt', 'neo_latin'),
#  ('erasmus/ep.txt', 'neo_latin'),
#  ('erasmus/inst.txt', 'neo_latin'),
#  ('erasmus/laude.txt', 'neo_latin'),
#  ('erasmus/moriae.txt', 'neo_latin'),
#  ('erasmus/querela.txt', 'neo_latin'),
#  ('eucherius.txt', 'christian'),
#  ('eugippius.txt', 'christian'),
#  ('eutropius/eutropius1.txt', 'misc'),
#  ('eutropius/eutropius10.txt', 'misc'),
#  ('eutropius/eutropius2.txt', 'misc'),
#  ('eutropius/eutropius3.txt', 'misc'),
#  ('eutropius/eutropius4.txt', 'misc'),
#  ('eutropius/eutropius5.txt', 'misc'),
#  ('eutropius/eutropius6.txt', 'misc'),
#  ('eutropius/eutropius7.txt', 'misc'),
#  ('eutropius/eutropius8.txt', 'misc'),
#  ('eutropius/eutropius9.txt', 'misc'),
#  ('frontinus/aqua1.txt', 'misc'),
#  ('frontinus/aqua2.txt', 'misc'),
#  ('frontinus/contro.txt', 'misc'),
#  ('frontinus/lim.txt', 'misc'),
#  ('frontinus/mensoria.txt', 'misc'),
#  ('frontinus/qualitate.txt', 'misc'),
#  ('frontinus/strat1.txt', 'misc'),
#  ('frontinus/strat2.txt', 'misc'),
#  ('frontinus/strat3.txt', 'misc'),
#  ('frontinus/strat4.txt', 'misc'),
#  ('fulgentius/fulgentius1.txt', 'late_silver'),
#  ('fulgentius/fulgentius2.txt', 'late_silver'),
#  ('fulgentius/fulgentius3.txt', 'late_silver'),
#  ('fulgentius/fulgentius4.txt', 'late_silver'),
#  ('fulgentius/fulgentius5.txt', 'late_silver'),
#  ('galileo/galileo.sid.txt', 'neo_latin'),
#  ('gellius/gellius1.txt', 'late_silver'),
#  ('gellius/gellius10.txt', 'late_silver'),
#  ('gellius/gellius11.txt', 'late_silver'),
#  ('gellius/gellius13.txt', 'late_silver'),
#  ('gellius/gellius2.txt', 'late_silver'),
#  ('gellius/gellius20.txt', 'late_silver'),
#  ('gellius/gellius3.txt', 'late_silver'),
#  ('gellius/gellius4.txt', 'late_silver'),
#  ('gellius/gellius5.txt', 'late_silver'),
#  ('gellius/gellius6.txt', 'late_silver'),
#  ('gellius/gellius7.txt', 'late_silver'),
#  ('gellius/gellius8.txt', 'late_silver'),
#  ('gellius/gellius9.txt', 'late_silver'),
#  ('gellius/gelliuscapitula.txt', 'late_silver'),
#  ('gellius/gelliuspraef.txt', 'late_silver'),
#  ('gestafrancorum/gestafrancorum1.txt', 'misc'),
#  ('gestafrancorum/gestafrancorum10.txt', 'misc'),
#  ('gestafrancorum/gestafrancorum2.txt', 'misc'),
#  ('gestafrancorum/gestafrancorum3.txt', 'misc'),
#  ('gestafrancorum/gestafrancorum4.txt', 'misc'),
#  ('gestafrancorum/gestafrancorum5.txt', 'misc'),
#  ('gestafrancorum/gestafrancorum6.txt', 'misc'),
#  ('gestafrancorum/gestafrancorum7.txt', 'misc'),
#  ('gestafrancorum/gestafrancorum8.txt', 'misc'),
#  ('gestafrancorum/gestafrancorum9.txt', 'misc'),
#  ('greg.txt', 'christian'),
#  ('gregory7.txt', 'christian'),
#  ('gregorytours/gregorytours1.txt', 'christian'),
#  ('gregorytours/gregorytours10.txt', 'christian'),
#  ('gregorytours/gregorytours2.txt', 'christian'),
#  ('gregorytours/gregorytours3.txt', 'christian'),
#  ('gregorytours/gregorytours4.txt', 'christian'),
#  ('gregorytours/gregorytours5.txt', 'christian'),
#  ('gregorytours/gregorytours6.txt', 'christian'),
#  ('gregorytours/gregorytours7.txt', 'christian'),
#  ('gregorytours/gregorytours8.txt', 'christian'),
#  ('gregorytours/gregorytours9.txt', 'christian'),
#  ('horace/arspoet.txt', 'augustan'),
#  ('horace/carm1.txt', 'augustan'),
#  ('horace/carm2.txt', 'augustan'),
#  ('horace/carm3.txt', 'augustan'),
#  ('horace/carm4.txt', 'augustan'),
#  ('horace/carmsaec.txt', 'augustan'),
#  ('horace/ep.txt', 'augustan'),
#  ('horace/epist1.txt', 'augustan'),
#  ('horace/epist2.txt', 'augustan'),
#  ('horace/serm1.txt', 'augustan'),
#  ('horace/serm2.txt', 'augustan'),
#  ('hugo/hugo.solo.txt', 'christian'),
#  ('hugo/hugo1.txt', 'christian'),
#  ('hugo/hugo2.txt', 'christian'),
#  ('hugo/hugo3.txt', 'christian'),
#  ('hugo/hugo4.txt', 'christian'),
#  ('hugo/hugo5.txt', 'christian'),
#  ('hugo/hugo6.txt', 'christian'),
#  ('hyginus/hyginus1.txt', 'augustan'),
#  ('hyginus/hyginus2.txt', 'augustan'),
#  ('hyginus/hyginus3.txt', 'augustan'),
#  ('hyginus/hyginus4.txt', 'augustan'),
#  ('hyginus/hyginus5.txt', 'augustan'),
#  ('hyginus/hyginus6.txt', 'augustan'),
#  ('hymni.txt', 'christian'),
#  ('isidore/1.txt', 'christian'),
#  ('isidore/10.txt', 'christian'),
#  ('isidore/11.txt', 'christian'),
#  ('isidore/12.txt', 'christian'),
#  ('isidore/13.txt', 'christian'),
#  ('isidore/14.txt', 'christian'),
#  ('isidore/15.txt', 'christian'),
#  ('isidore/16.txt', 'christian'),
#  ('isidore/17.txt', 'christian'),
#  ('isidore/18.txt', 'christian'),
#  ('isidore/19.txt', 'christian'),
#  ('isidore/2.txt', 'christian'),
#  ('isidore/20.txt', 'christian'),
#  ('isidore/3.txt', 'christian'),
#  ('isidore/4.txt', 'christian'),
#  ('isidore/5.txt', 'christian'),
#  ('isidore/6.txt', 'christian'),
#  ('isidore/7.txt', 'christian'),
#  ('isidore/8.txt', 'christian'),
#  ('isidore/9.txt', 'christian'),
#  ('isidore/historia.txt', 'christian'),
#  ('isidore/sententiae1.txt', 'christian'),
#  ('isidore/sententiae2.txt', 'christian'),
#  ('isidore/sententiae3.txt', 'christian'),
#  ('jerome/contraioannem.txt', 'christian'),
#  ('jerome/epistulae.txt', 'christian'),
#  ('jerome/vitamalchus.txt', 'christian'),
#  ('jerome/vitapauli.txt', 'christian'),
#  ('junillus.txt', 'christian'),
#  ('justin/1.txt', 'late_silver'),
#  ('justin/10.txt', 'late_silver'),
#  ('justin/11.txt', 'late_silver'),
#  ('justin/12.txt', 'late_silver'),
#  ('justin/13.txt', 'late_silver'),
#  ('justin/14.txt', 'late_silver'),
#  ('justin/15.txt', 'late_silver'),
#  ('justin/16.txt', 'late_silver'),
#  ('justin/17.txt', 'late_silver'),
#  ('justin/18.txt', 'late_silver'),
#  ('justin/19.txt', 'late_silver'),
#  ('justin/2.txt', 'late_silver'),
#  ('justin/20.txt', 'late_silver'),
#  ('justin/21.txt', 'late_silver'),
#  ('justin/22.txt', 'late_silver'),
#  ('justin/23.txt', 'late_silver'),
#  ('justin/24.txt', 'late_silver'),
#  ('justin/25.txt', 'late_silver'),
#  ('justin/26.txt', 'late_silver'),
#  ('justin/27.txt', 'late_silver'),
#  ('justin/28.txt', 'late_silver'),
#  ('justin/29.txt', 'late_silver'),
#  ('justin/3.txt', 'late_silver'),
#  ('justin/30.txt', 'late_silver'),
#  ('justin/31.txt', 'late_silver'),
#  ('justin/32.txt', 'late_silver'),
#  ('justin/33.txt', 'late_silver'),
#  ('justin/34.txt', 'late_silver'),
#  ('justin/35.txt', 'late_silver'),
#  ('justin/36.txt', 'late_silver'),
#  ('justin/37.txt', 'late_silver'),
#  ('justin/38.txt', 'late_silver'),
#  ('justin/39.txt', 'late_silver'),
#  ('justin/4.txt', 'late_silver'),
#  ('justin/40.txt', 'late_silver'),
#  ('justin/41.txt', 'late_silver'),
#  ('justin/42.txt', 'late_silver'),
#  ('justin/43.txt', 'late_silver'),
#  ('justin/44.txt', 'late_silver'),
#  ('justin/5.txt', 'late_silver'),
#  ('justin/6.txt', 'late_silver'),
#  ('justin/7.txt', 'late_silver'),
#  ('justin/8.txt', 'late_silver'),
#  ('justin/9.txt', 'late_silver'),
#  ('justin/praefatio.txt', 'late_silver'),
#  ('justin/prologi.txt', 'late_silver'),
#  ('justinian/codex1.txt', 'misc'),
#  ('justinian/codex10.txt', 'misc'),
#  ('justinian/codex11.txt', 'misc'),
#  ('justinian/codex12.txt', 'misc'),
#  ('justinian/codex2.txt', 'misc'),
#  ('justinian/codex3.txt', 'misc'),
#  ('justinian/codex4.txt', 'misc'),
#  ('justinian/codex5.txt', 'misc'),
#  ('justinian/codex6.txt', 'misc'),
#  ('justinian/codex7.txt', 'misc'),
#  ('justinian/codex8.txt', 'misc'),
#  ('justinian/codex9.txt', 'misc'),
#  ('justinian/digest1.txt', 'misc'),
#  ('justinian/digest10.txt', 'misc'),
#  ('justinian/digest11.txt', 'misc'),
#  ('justinian/digest12.txt', 'misc'),
#  ('justinian/digest13.txt', 'misc'),
#  ('justinian/digest14.txt', 'misc'),
#  ('justinian/digest15.txt', 'misc'),
#  ('justinian/digest16.txt', 'misc'),
#  ('justinian/digest17.txt', 'misc'),
#  ('justinian/digest18.txt', 'misc'),
#  ('justinian/digest19.txt', 'misc'),
#  ('justinian/digest2.txt', 'misc'),
#  ('justinian/digest20.txt', 'misc'),
#  ('justinian/digest21.txt', 'misc'),
#  ('justinian/digest22.txt', 'misc'),
#  ('justinian/digest23.txt', 'misc'),
#  ('justinian/digest24.txt', 'misc'),
#  ('justinian/digest25.txt', 'misc'),
#  ('justinian/digest26.txt', 'misc'),
#  ('justinian/digest27.txt', 'misc'),
#  ('justinian/digest28.txt', 'misc'),
#  ('justinian/digest29.txt', 'misc'),
#  ('justinian/digest3.txt', 'misc'),
#  ('justinian/digest30.txt', 'misc'),
#  ('justinian/digest31.txt', 'misc'),
#  ('justinian/digest32.txt', 'misc'),
#  ('justinian/digest33.txt', 'misc'),
#  ('justinian/digest34.txt', 'misc'),
#  ('justinian/digest35.txt', 'misc'),
#  ('justinian/digest36.txt', 'misc'),
#  ('justinian/digest37.txt', 'misc'),
#  ('justinian/digest38.txt', 'misc'),
#  ('justinian/digest39.txt', 'misc'),
#  ('justinian/digest4.txt', 'misc'),
#  ('justinian/digest40.txt', 'misc'),
#  ('justinian/digest41.txt', 'misc'),
#  ('justinian/digest42.txt', 'misc'),
#  ('justinian/digest43.txt', 'misc'),
#  ('justinian/digest44.txt', 'misc'),
#  ('justinian/digest45.txt', 'misc'),
#  ('justinian/digest46.txt', 'misc'),
#  ('justinian/digest47.txt', 'misc'),
#  ('justinian/digest48.txt', 'misc'),
#  ('justinian/digest49.txt', 'misc'),
#  ('justinian/digest5.txt', 'misc'),
#  ('justinian/digest50.txt', 'misc'),
#  ('justinian/digest6.txt', 'misc'),
#  ('justinian/digest7.txt', 'misc'),
#  ('justinian/digest8.txt', 'misc'),
#  ('justinian/digest9.txt', 'misc'),
#  ('justinian/institutes.proem.txt', 'misc'),
#  ('justinian/institutes1.txt', 'misc'),
#  ('justinian/institutes2.txt', 'misc'),
#  ('justinian/institutes3.txt', 'misc'),
#  ('justinian/institutes4.txt', 'misc'),
#  ('juvenal/1.txt', 'early_silver'),
#  ('juvenal/10.txt', 'early_silver'),
#  ('juvenal/11.txt', 'early_silver'),
#  ('juvenal/12.txt', 'early_silver'),
#  ('juvenal/13.txt', 'early_silver'),
#  ('juvenal/14.txt', 'early_silver'),
#  ('juvenal/15.txt', 'early_silver'),
#  ('juvenal/16.txt', 'early_silver'),
#  ('juvenal/2.txt', 'early_silver'),
#  ('juvenal/3.txt', 'early_silver'),
#  ('juvenal/4.txt', 'early_silver'),
#  ('juvenal/5.txt', 'early_silver'),
#  ('juvenal/6.txt', 'early_silver'),
#  ('juvenal/7.txt', 'early_silver'),
#  ('juvenal/8.txt', 'early_silver'),
#  ('juvenal/9.txt', 'early_silver'),
#  ('kempis/kempis1.txt', 'christian'),
#  ('kempis/kempis2.txt', 'christian'),
#  ('kempis/kempis3.txt', 'christian'),
#  ('kempis/kempis4.txt', 'christian'),
#  ('kepler/strena.txt', 'neo_latin'),
#  ('lactantius/demort.txt', 'misc'),
#  ('lactantius/divinst1.txt', 'misc'),
#  ('leothegreat/quadragesima1.txt', 'christian'),
#  ('leothegreat/quadragesima2.txt', 'christian'),
#  ('livy/liv.1.txt', 'augustan'),
#  ('livy/liv.10.txt', 'augustan'),
#  ('livy/liv.2.txt', 'augustan'),
#  ('livy/liv.21.txt', 'augustan'),
#  ('livy/liv.22.txt', 'augustan'),
#  ('livy/liv.23.txt', 'augustan'),
#  ('livy/liv.24.txt', 'augustan'),
#  ('livy/liv.25.txt', 'augustan'),
#  ('livy/liv.26.txt', 'augustan'),
#  ('livy/liv.27.txt', 'augustan'),
#  ('livy/liv.28.txt', 'augustan'),
#  ('livy/liv.29.txt', 'augustan'),
#  ('livy/liv.3.txt', 'augustan'),
#  ('livy/liv.30.txt', 'augustan'),
#  ('livy/liv.31.txt', 'augustan'),
#  ('livy/liv.32.txt', 'augustan'),
#  ('livy/liv.33.txt', 'augustan'),
#  ('livy/liv.34.txt', 'augustan'),
#  ('livy/liv.35.txt', 'augustan'),
#  ('livy/liv.36.txt', 'augustan'),
#  ('livy/liv.37.txt', 'augustan'),
#  ('livy/liv.38.txt', 'augustan'),
#  ('livy/liv.39.txt', 'augustan'),
#  ('livy/liv.4.txt', 'augustan'),
#  ('livy/liv.40.txt', 'augustan'),
#  ('livy/liv.41.txt', 'augustan'),
#  ('livy/liv.42.txt', 'augustan'),
#  ('livy/liv.43.txt', 'augustan'),
#  ('livy/liv.44.txt', 'augustan'),
#  ('livy/liv.45.txt', 'augustan'),
#  ('livy/liv.5.txt', 'augustan'),
#  ('livy/liv.6.txt', 'augustan'),
#  ('livy/liv.7.txt', 'augustan'),
#  ('livy/liv.8.txt', 'augustan'),
#  ('livy/liv.9.txt', 'augustan'),
#  ('livy/liv.per.txt', 'augustan'),
#  ('livy/liv.per1.txt', 'augustan'),
#  ('livy/liv.per10.txt', 'augustan'),
#  ('livy/liv.per100.txt', 'augustan'),
#  ('livy/liv.per101.txt', 'augustan'),
#  ('livy/liv.per102.txt', 'augustan'),
#  ('livy/liv.per103.txt', 'augustan'),
#  ('livy/liv.per104.txt', 'augustan'),
#  ('livy/liv.per105.txt', 'augustan'),
#  ('livy/liv.per106.txt', 'augustan'),
#  ('livy/liv.per107.txt', 'augustan'),
#  ('livy/liv.per108.txt', 'augustan'),
#  ('livy/liv.per109.txt', 'augustan'),
#  ('livy/liv.per11.txt', 'augustan'),
#  ('livy/liv.per110.txt', 'augustan'),
#  ('livy/liv.per111.txt', 'augustan'),
#  ('livy/liv.per112.txt', 'augustan'),
#  ('livy/liv.per113.txt', 'augustan'),
#  ('livy/liv.per114.txt', 'augustan'),
#  ('livy/liv.per115.txt', 'augustan'),
#  ('livy/liv.per116.txt', 'augustan'),
#  ('livy/liv.per117.txt', 'augustan'),
#  ('livy/liv.per118.txt', 'augustan'),
#  ('livy/liv.per119.txt', 'augustan'),
#  ('livy/liv.per12.txt', 'augustan'),
#  ('livy/liv.per120.txt', 'augustan'),
#  ('livy/liv.per121.txt', 'augustan'),
#  ('livy/liv.per122.txt', 'augustan'),
#  ('livy/liv.per123.txt', 'augustan'),
#  ('livy/liv.per124.txt', 'augustan'),
#  ('livy/liv.per125.txt', 'augustan'),
#  ('livy/liv.per126.txt', 'augustan'),
#  ('livy/liv.per127.txt', 'augustan'),
#  ('livy/liv.per128.txt', 'augustan'),
#  ('livy/liv.per129.txt', 'augustan'),
#  ('livy/liv.per13.txt', 'augustan'),
#  ('livy/liv.per130.txt', 'augustan'),
#  ('livy/liv.per131.txt', 'augustan'),
#  ('livy/liv.per132.txt', 'augustan'),
#  ('livy/liv.per133.txt', 'augustan'),
#  ('livy/liv.per134.txt', 'augustan'),
#  ('livy/liv.per135.txt', 'augustan'),
#  ('livy/liv.per136-7.txt', 'augustan'),
#  ('livy/liv.per138.txt', 'augustan'),
#  ('livy/liv.per139.txt', 'augustan'),
#  ('livy/liv.per14.txt', 'augustan'),
#  ('livy/liv.per140.txt', 'augustan'),
#  ('livy/liv.per141.txt', 'augustan'),
#  ('livy/liv.per142.txt', 'augustan'),
#  ('livy/liv.per15.txt', 'augustan'),
#  ('livy/liv.per16.txt', 'augustan'),
#  ('livy/liv.per17.txt', 'augustan'),
#  ('livy/liv.per18.txt', 'augustan'),
#  ('livy/liv.per19.txt', 'augustan'),
#  ('livy/liv.per2.txt', 'augustan'),
#  ('livy/liv.per20.txt', 'augustan'),
#  ('livy/liv.per21.txt', 'augustan'),
#  ('livy/liv.per22.txt', 'augustan'),
#  ('livy/liv.per23.txt', 'augustan'),
#  ('livy/liv.per24.txt', 'augustan'),
#  ('livy/liv.per25.txt', 'augustan'),
#  ('livy/liv.per26.txt', 'augustan'),
#  ('livy/liv.per27.txt', 'augustan'),
#  ('livy/liv.per28.txt', 'augustan'),
#  ('livy/liv.per29.txt', 'augustan'),
#  ('livy/liv.per3.txt', 'augustan'),
#  ('livy/liv.per30.txt', 'augustan'),
#  ('livy/liv.per31.txt', 'augustan'),
#  ('livy/liv.per32.txt', 'augustan'),
#  ...]

# %%
predicted_files_cats
# Out:
# [('1644.txt', 'republican'),
#  ('abbofloracensis.txt', 'christian'),
#  ('adso.txt', 'christian'),
#  ('aelredus.txt', 'christian'),
#  ('agnes.txt', 'neo_latin'),
#  ('alanus/alanus1.txt', 'christian'),
#  ('alanus/alanus2.txt', 'christian'),
#  ('albertanus/albertanus.arsloquendi.txt', 'christian'),
#  ('albertanus/albertanus.liberconsol.txt', 'christian'),
#  ('albertanus/albertanus.sermo.txt', 'christian'),
#  ('albertanus/albertanus.sermo1.txt', 'christian'),
#  ('albertanus/albertanus.sermo2.txt', 'christian'),
#  ('albertanus/albertanus.sermo3.txt', 'christian'),
#  ('albertanus/albertanus.sermo4.txt', 'christian'),
#  ('albertanus/albertanus1.txt', 'christian'),
#  ('albertanus/albertanus2.txt', 'christian'),
#  ('albertanus/albertanus3.txt', 'christian'),
#  ('albertanus/albertanus4.txt', 'christian'),
#  ('albertofaix/hist1.txt', 'christian'),
#  ('albertofaix/hist10.txt', 'christian'),
#  ('albertofaix/hist11.txt', 'christian'),
#  ('albertofaix/hist12.txt', 'christian'),
#  ('albertofaix/hist2.txt', 'christian'),
#  ('albertofaix/hist3.txt', 'christian'),
#  ('albertofaix/hist4.txt', 'christian'),
#  ('albertofaix/hist5.txt', 'christian'),
#  ('albertofaix/hist6.txt', 'christian'),
#  ('albertofaix/hist7.txt', 'christian'),
#  ('albertofaix/hist8.txt', 'christian'),
#  ('albertofaix/hist9.txt', 'christian'),
#  ('alfonsi.disciplina.txt', 'augustan'),
#  ('ammianus/14.txt', 'christian'),
#  ('ammianus/15.txt', 'christian'),
#  ('ammianus/16.txt', 'christian'),
#  ('ammianus/17.txt', 'christian'),
#  ('ammianus/18.txt', 'christian'),
#  ('ammianus/19.txt', 'christian'),
#  ('ammianus/20.txt', 'christian'),
#  ('ammianus/21.txt', 'christian'),
#  ('ammianus/22.txt', 'christian'),
#  ('ammianus/23.txt', 'christian'),
#  ('ammianus/24.txt', 'christian'),
#  ('ammianus/25.txt', 'christian'),
#  ('ammianus/26.txt', 'christian'),
#  ('ammianus/27.txt', 'christian'),
#  ('ammianus/28.txt', 'christian'),
#  ('ammianus/29.txt', 'christian'),
#  ('ammianus/30.txt', 'christian'),
#  ('ammianus/31.txt', 'christian'),
#  ('ampelius.txt', 'christian'),
#  ('andecavis.txt', 'christian'),
#  ('andreasbergoma.txt', 'christian'),
#  ('angilbert.txt', 'christian'),
#  ('annalesregnifrancorum.txt', 'christian'),
#  ('annalesvedastini.txt', 'christian'),
#  ('anon.deramis.txt', 'republican'),
#  ('anon.nev.txt', 'christian'),
#  ('appverg.aetna.txt', 'christian'),
#  ('appverg.catalepton.txt', 'christian'),
#  ('appverg.ciris.txt', 'christian'),
#  ('appvergcomp.txt', 'christian'),
#  ('appvergculex.txt', 'christian'),
#  ('apuleius/apuleius.apol.txt', 'christian'),
#  ('apuleius/apuleius.cupid.txt', 'republican'),
#  ('apuleius/apuleius.deosocratis.txt', 'christian'),
#  ('apuleius/apuleius.dog1.txt', 'christian'),
#  ('apuleius/apuleius.dog2.txt', 'christian'),
#  ('apuleius/apuleius.florida.txt', 'late_silver'),
#  ('apuleius/apuleius.mundo.txt', 'christian'),
#  ('apuleius/apuleius1.txt', 'early_silver'),
#  ('apuleius/apuleius10.txt', 'early_silver'),
#  ('apuleius/apuleius11.txt', 'early_silver'),
#  ('apuleius/apuleius2.txt', 'early_silver'),
#  ('apuleius/apuleius3.txt', 'early_silver'),
#  ('apuleius/apuleius4.txt', 'early_silver'),
#  ('apuleius/apuleius5.txt', 'early_silver'),
#  ('apuleius/apuleius6.txt', 'early_silver'),
#  ('apuleius/apuleius7.txt', 'early_silver'),
#  ('apuleius/apuleius8.txt', 'early_silver'),
#  ('apuleius/apuleius9.txt', 'early_silver'),
#  ('aquinas/corpuschristi.txt', 'early_silver'),
#  ('aquinas/ente.txt', 'early_silver'),
#  ('aquinas/epist.txt', 'early_silver'),
#  ('aquinas/expositio.txt', 'early_silver'),
#  ('aquinas/p1.txt', 'early_silver'),
#  ('aquinas/princ.txt', 'early_silver'),
#  ('aquinas/prologus.txt', 'early_silver'),
#  ('aquinas/q1.1.txt', 'early_silver'),
#  ('aquinas/q1.10.txt', 'early_silver'),
#  ('aquinas/q1.11.txt', 'early_silver'),
#  ('aquinas/q1.12.txt', 'early_silver'),
#  ('aquinas/q1.13.txt', 'early_silver'),
#  ('aquinas/q1.14.txt', 'early_silver'),
#  ('aquinas/q1.15.txt', 'early_silver'),
#  ('aquinas/q1.16.txt', 'early_silver'),
#  ('aquinas/q1.17.txt', 'early_silver'),
#  ('aquinas/q1.18.txt', 'early_silver'),
#  ('aquinas/q1.19.txt', 'early_silver'),
#  ('aquinas/q1.2.txt', 'early_silver'),
#  ('aquinas/q1.20.txt', 'early_silver'),
#  ('aquinas/q1.21.txt', 'early_silver'),
#  ('aquinas/q1.22.txt', 'early_silver'),
#  ('aquinas/q1.23.txt', 'early_silver'),
#  ('aquinas/q1.24.txt', 'early_silver'),
#  ('aquinas/q1.25.txt', 'early_silver'),
#  ('aquinas/q1.26.txt', 'early_silver'),
#  ('aquinas/q1.27.txt', 'early_silver'),
#  ('aquinas/q1.28.txt', 'early_silver'),
#  ('aquinas/q1.29.txt', 'early_silver'),
#  ('aquinas/q1.3.txt', 'early_silver'),
#  ('aquinas/q1.30.txt', 'early_silver'),
#  ('aquinas/q1.31.txt', 'early_silver'),
#  ('aquinas/q1.32.txt', 'early_silver'),
#  ('aquinas/q1.33.txt', 'early_silver'),
#  ('aquinas/q1.34.txt', 'early_silver'),
#  ('aquinas/q1.35.txt', 'early_silver'),
#  ('aquinas/q1.36.txt', 'early_silver'),
#  ('aquinas/q1.37.txt', 'early_silver'),
#  ('aquinas/q1.38.txt', 'early_silver'),
#  ('aquinas/q1.39.txt', 'early_silver'),
#  ('aquinas/q1.4.txt', 'early_silver'),
#  ('aquinas/q1.40.txt', 'early_silver'),
#  ('aquinas/q1.41.txt', 'early_silver'),
#  ('aquinas/q1.42.txt', 'early_silver'),
#  ('aquinas/q1.43.txt', 'early_silver'),
#  ('aquinas/q1.44.txt', 'early_silver'),
#  ('aquinas/q1.45.txt', 'early_silver'),
#  ('aquinas/q1.46.txt', 'early_silver'),
#  ('aquinas/q1.47.txt', 'early_silver'),
#  ('aquinas/q1.48.txt', 'early_silver'),
#  ('aquinas/q1.49.txt', 'early_silver'),
#  ('aquinas/q1.5.txt', 'early_silver'),
#  ('aquinas/q1.50.txt', 'early_silver'),
#  ('aquinas/q1.51.txt', 'early_silver'),
#  ('aquinas/q1.52.txt', 'early_silver'),
#  ('aquinas/q1.53.txt', 'early_silver'),
#  ('aquinas/q1.54.txt', 'early_silver'),
#  ('aquinas/q1.55.txt', 'early_silver'),
#  ('aquinas/q1.56.txt', 'early_silver'),
#  ('aquinas/q1.57.txt', 'early_silver'),
#  ('aquinas/q1.58.txt', 'early_silver'),
#  ('aquinas/q1.59.txt', 'early_silver'),
#  ('aquinas/q1.6.txt', 'early_silver'),
#  ('aquinas/q1.60.txt', 'early_silver'),
#  ('aquinas/q1.61.txt', 'early_silver'),
#  ('aquinas/q1.62.txt', 'early_silver'),
#  ('aquinas/q1.63.txt', 'early_silver'),
#  ('aquinas/q1.64.txt', 'early_silver'),
#  ('aquinas/q1.65.txt', 'early_silver'),
#  ('aquinas/q1.66.txt', 'early_silver'),
#  ('aquinas/q1.67.txt', 'early_silver'),
#  ('aquinas/q1.68.txt', 'early_silver'),
#  ('aquinas/q1.69.txt', 'early_silver'),
#  ('aquinas/q1.7.txt', 'early_silver'),
#  ('aquinas/q1.70.txt', 'early_silver'),
#  ('aquinas/q1.71.txt', 'early_silver'),
#  ('aquinas/q1.72.txt', 'early_silver'),
#  ('aquinas/q1.73.txt', 'early_silver'),
#  ('aquinas/q1.74.txt', 'early_silver'),
#  ('aquinas/q1.8.txt', 'early_silver'),
#  ('aquinas/q1.80.txt', 'early_silver'),
#  ('aquinas/q1.81.txt', 'early_silver'),
#  ('aquinas/q1.82.txt', 'early_silver'),
#  ('aquinas/q1.83.txt', 'early_silver'),
#  ('aquinas/q1.86.txt', 'early_silver'),
#  ('aquinas/q1.87.txt', 'early_silver'),
#  ('aquinas/q1.9.txt', 'early_silver'),
#  ('arbroath.txt', 'augustan'),
#  ('archpoet.txt', 'christian'),
#  ('arnobius/arnobius1.txt', 'christian'),
#  ('arnobius/arnobius2.txt', 'christian'),
#  ('arnobius/arnobius3.txt', 'christian'),
#  ('arnobius/arnobius4.txt', 'christian'),
#  ('arnobius/arnobius5.txt', 'christian'),
#  ('arnobius/arnobius6.txt', 'christian'),
#  ('arnobius/arnobius7.txt', 'christian'),
#  ('arnulf.txt', 'christian'),
#  ('asconius.txt', 'christian'),
#  ('asserius.txt', 'christian'),
#  ('aus.mos.txt', 'christian'),
#  ('aus.sept.sent.txt', 'christian'),
#  ('ave.phoen.txt', 'augustan'),
#  ('avianus.txt', 'christian'),
#  ('avienus.ora.txt', 'christian'),
#  ('avienus.periegesis.txt', 'christian'),
#  ('axio.txt', 'augustan'),
#  ('balbus.txt', 'neo_latin'),
#  ('balde1.txt', 'neo_latin'),
#  ('balde2.txt', 'neo_latin'),
#  ('baldo.txt', 'neo_latin'),
#  ('bebel.txt', 'neo_latin'),
#  ('bernardcluny1.txt', 'neo_latin'),
#  ('bernardcluny2.txt', 'neo_latin'),
#  ('biggs.txt', 'neo_latin'),
#  ('bill.rights.txt', 'neo_latin'),
#  ('blesensis.txt', 'augustan'),
#  ('boskovic.txt', 'neo_latin'),
#  ('brevechronicon.txt', 'neo_latin'),
#  ('buchanan.txt', 'neo_latin'),
#  ('caeciliusbalbus.txt', 'augustan'),
#  ('calpurniusflaccus.txt', 'republican'),
#  ('calpurniussiculus.txt', 'christian'),
#  ('capellanus/capellanus1.txt', 'christian'),
#  ('capellanus/capellanus2.txt', 'christian'),
#  ('capellanus/capellanus3.txt', 'christian'),
#  ('carmenarvale.txt', 'republican'),
#  ('carmeninvictoriam.txt', 'republican'),
#  ('carmensaliare.txt', 'republican'),
#  ('catalogueliberien.txt', 'republican'),
#  ('cato.dis.txt', 'augustan'),
#  ('cato/cato.agri.txt', 'augustan'),
#  ('cato/cato.frag.txt', 'augustan'),
#  ('celtis.odes.txt', 'republican'),
#  ('celtis.oratio.txt', 'republican'),
#  ('censorinus.txt', 'republican'),
#  ('cinna.txt', 'augustan'),
#  ('claud.inscr.txt', 'early_silver'),
#  ('claudian/claudian.cons6.txt', 'republican'),
#  ('claudian/claudian.olyb.txt', 'republican'),
#  ('claudian/claudian.proserp1.txt', 'republican'),
#  ('claudian/claudian.proserp2.txt', 'republican'),
#  ('claudian/claudian.proserp3.txt', 'republican'),
#  ('claudian/claudian.ruf1.txt', 'republican'),
#  ('clitophon.txt', 'augustan'),
#  ('colman.txt', 'republican'),
#  ('columba1.txt', 'augustan'),
#  ('columba2.txt', 'augustan'),
#  ('columbus.txt', 'republican'),
#  ('comes.txt', 'augustan'),
#  ('corvinus1.txt', 'augustan'),
#  ('corvinus2.txt', 'augustan'),
#  ('cotta.txt', 'augustan'),
#  ('curtius/curtius10.txt', 'republican'),
#  ('curtius/curtius3.txt', 'republican'),
#  ('curtius/curtius4.txt', 'republican'),
#  ('curtius/curtius5.txt', 'republican'),
#  ('curtius/curtius6.txt', 'republican'),
#  ('curtius/curtius7.txt', 'republican'),
#  ('curtius/curtius8.txt', 'republican'),
#  ('curtius/curtius9.txt', 'republican'),
#  ('dares.txt', 'augustan'),
#  ('dares1.txt', 'augustan'),
#  ('debury.txt', 'christian'),
#  ('declaratio.txt', 'christian'),
#  ('dicchristi.txt', 'augustan'),
#  ('dicquid.txt', 'augustan'),
#  ('diravi.txt', 'christian'),
#  ('don.txt', 'augustan'),
#  ('donation.txt', 'augustan'),
#  ('dulcesolum.txt', 'augustan'),
#  ('dumdiane.txt', 'christian'),
#  ('dumdomus.txt', 'augustan'),
#  ('dumestas.txt', 'early_silver'),
#  ('ebulo.txt', 'augustan'),
#  ('egeria1.txt', 'christian'),
#  ('egeria2.txt', 'christian'),
#  ('ein.txt', 'christian'),
#  ('ency.fides.txt', 'late_silver'),
#  ('ep.priapismo.txt', 'christian'),
#  ('epistaustras.txt', 'christian'),
#  ('epitaphs.txt', 'christian'),
#  ('epitomecononiana.txt', 'christian'),
#  ('epitomefeliciana.txt', 'christian'),
#  ('erchempert.txt', 'christian'),
#  ('estas.txt', 'christian'),
#  ('eugenius.txt', 'early_silver'),
#  ('eutropius/eutropius1.txt', 'christian'),
#  ('eutropius/eutropius10.txt', 'christian'),
#  ('eutropius/eutropius2.txt', 'christian'),
#  ('eutropius/eutropius3.txt', 'christian'),
#  ('eutropius/eutropius4.txt', 'christian'),
#  ('eutropius/eutropius5.txt', 'christian'),
#  ('eutropius/eutropius6.txt', 'christian'),
#  ('eutropius/eutropius7.txt', 'christian'),
#  ('eutropius/eutropius8.txt', 'christian'),
#  ('eutropius/eutropius9.txt', 'christian'),
#  ('exivi.txt', 'christian'),
#  ('fabe.txt', 'christian'),
#  ('falcandus.txt', 'augustan'),
#  ('falcone.txt', 'republican'),
#  ('ferraria.txt', 'republican'),
#  ('ficino.txt', 'early_silver'),
#  ('fletcher.txt', 'augustan'),
#  ('florus1.txt', 'late_silver'),
#  ('florus2.txt', 'late_silver'),
#  ('foedusaeternum.txt', 'christian'),
#  ('forsett1.txt', 'augustan'),
#  ('forsett2.txt', 'augustan'),
#  ('fortunat.txt', 'christian'),
#  ('fragmentumlaurentianum.txt', 'late_silver'),
#  ('fredegarius.txt', 'late_silver'),
#  ('frodebertus.txt', 'late_silver'),
#  ('frontinus/aqua1.txt', 'late_silver'),
#  ('frontinus/aqua2.txt', 'late_silver'),
#  ('frontinus/contro.txt', 'late_silver'),
#  ('frontinus/lim.txt', 'late_silver'),
#  ('frontinus/mensoria.txt', 'late_silver'),
#  ('frontinus/qualitate.txt', 'late_silver'),
#  ('frontinus/strat1.txt', 'late_silver'),
#  ('frontinus/strat2.txt', 'late_silver'),
#  ('frontinus/strat3.txt', 'late_silver'),
#  ('frontinus/strat4.txt', 'late_silver'),
#  ('fronto.txt', 'early_silver'),
#  ('fulbert.txt', 'early_silver'),
#  ('gaius1.txt', 'christian'),
#  ('gaius2.txt', 'christian'),
#  ('gaius3.txt', 'christian'),
#  ('gaius4.txt', 'christian'),
#  ('garcilaso.txt', 'christian'),
#  ('garland.txt', 'christian'),
#  ('gaud.txt', 'christian'),
#  ('gauss.txt', 'christian'),
#  ('germanicus.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum1.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum10.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum2.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum3.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum4.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum5.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum6.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum7.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum8.txt', 'christian'),
#  ('gestafrancorum/gestafrancorum9.txt', 'christian'),
#  ('gestarom.txt', 'christian'),
#  ('gioacchino.txt', 'christian'),
#  ('godfrey.epigrammata.txt', 'christian'),
#  ('godfrey.epigrammatahist.txt', 'christian'),
#  ('grattius.txt', 'christian'),
#  ('gravissimas.txt', 'christian'),
#  ('gregdecretals1.txt', 'christian'),
#  ('gregdecretals2.txt', 'christian'),
#  ('gregdecretals3.txt', 'christian'),
#  ('gregdecretals4.txt', 'christian'),
#  ('gregdecretals5.txt', 'christian'),
#  ('gwinne1.txt', 'republican'),
#  ('gwinne2.txt', 'republican'),
#  ('gwinne3.txt', 'republican'),
#  ('gwinne4.txt', 'republican'),
#  ('gwinne5.1.txt', 'republican'),
#  ('gwinne5.2.txt', 'republican'),
#  ('gwinne5.3.txt', 'republican'),
#  ('gwinne5.4.txt', 'republican'),
#  ('halley.txt', 'christian'),
#  ('hebet.txt', 'augustan'),
#  ('henry1.txt', 'republican'),
#  ('henry2.txt', 'republican'),
#  ('henry3.txt', 'republican'),
#  ('henrysettimello.txt', 'augustan'),
#  ('hipp.txt', 'augustan'),
#  ('histapoll.txt', 'augustan'),
#  ('histbrit.txt', 'augustan'),
#  ('holberg.txt', 'christian'),
#  ('hrabanus.txt', 'augustan'),
#  ('hydatiuschronicon.txt', 'augustan'),
#  ('hydatiusfasti.txt', 'augustan'),
#  ('iabervocius.txt', 'augustan'),
#  ('iamdulcis.txt', 'christian'),
#  ('ilias.txt', 'christian'),
#  ('index.txt', 'christian'),
#  ('indices.txt', 'christian'),
#  ('innocent1.txt', 'augustan'),
#  ('innocent2.txt', 'augustan'),
#  ('inquisitio.txt', 'christian'),
#  ('inscriptions.txt', 'christian'),
#  ('iordanes1.txt', 'christian'),
#  ('iordanes2.txt', 'christian'),
#  ('ipsavivere.txt', 'christian'),
#  ('janus1.txt', 'christian'),
#  ('janus2.txt', 'christian'),
#  ('jfkhonor.txt', 'augustan'),
#  ('johannes.txt', 'christian'),
#  ('justin/1.txt', 'christian'),
#  ('justin/10.txt', 'christian'),
#  ('justin/11.txt', 'christian'),
#  ('justin/12.txt', 'christian'),
#  ('justin/13.txt', 'christian'),
#  ('justin/14.txt', 'christian'),
#  ('justin/15.txt', 'christian'),
#  ('justin/16.txt', 'christian'),
#  ('justin/17.txt', 'christian'),
#  ('justin/18.txt', 'christian'),
#  ('justin/19.txt', 'christian'),
#  ('justin/2.txt', 'christian'),
#  ('justin/20.txt', 'christian'),
#  ('justin/21.txt', 'christian'),
#  ('justin/22.txt', 'christian'),
#  ('justin/23.txt', 'christian'),
#  ('justin/24.txt', 'christian'),
#  ('justin/25.txt', 'christian'),
#  ('justin/26.txt', 'christian'),
#  ('justin/27.txt', 'christian'),
#  ('justin/28.txt', 'christian'),
#  ('justin/29.txt', 'christian'),
#  ('justin/3.txt', 'christian'),
#  ('justin/30.txt', 'christian'),
#  ('justin/31.txt', 'christian'),
#  ('justin/32.txt', 'christian'),
#  ('justin/33.txt', 'christian'),
#  ('justin/34.txt', 'christian'),
#  ('justin/35.txt', 'christian'),
#  ('justin/36.txt', 'christian'),
#  ('justin/37.txt', 'christian'),
#  ('justin/38.txt', 'christian'),
#  ('justin/39.txt', 'christian'),
#  ('justin/4.txt', 'christian'),
#  ('justin/40.txt', 'christian'),
#  ('justin/41.txt', 'christian'),
#  ('justin/42.txt', 'christian'),
#  ('justin/43.txt', 'christian'),
#  ('justin/44.txt', 'christian'),
#  ('justin/5.txt', 'christian'),
#  ('justin/6.txt', 'christian'),
#  ('justin/7.txt', 'christian'),
#  ('justin/8.txt', 'christian'),
#  ('justin/9.txt', 'christian'),
#  ('justin/praefatio.txt', 'christian'),
#  ('justin/prologi.txt', 'christian'),
#  ('justinian/codex1.txt', 'republican'),
#  ('justinian/codex10.txt', 'republican'),
#  ('justinian/codex11.txt', 'republican'),
#  ('justinian/codex12.txt', 'republican'),
#  ('justinian/codex2.txt', 'republican'),
#  ('justinian/codex3.txt', 'republican'),
#  ('justinian/codex4.txt', 'republican'),
#  ('justinian/codex5.txt', 'republican'),
#  ('justinian/codex6.txt', 'republican'),
#  ('justinian/codex7.txt', 'republican'),
#  ('justinian/codex8.txt', 'republican'),
#  ('justinian/codex9.txt', 'republican'),
#  ('justinian/digest1.txt', 'augustan'),
#  ('justinian/digest10.txt', 'augustan'),
#  ('justinian/digest11.txt', 'augustan'),
#  ('justinian/digest12.txt', 'augustan'),
#  ('justinian/digest13.txt', 'augustan'),
#  ('justinian/digest14.txt', 'augustan'),
#  ('justinian/digest15.txt', 'augustan'),
#  ('justinian/digest16.txt', 'augustan'),
#  ('justinian/digest17.txt', 'augustan'),
#  ('justinian/digest18.txt', 'augustan'),
#  ('justinian/digest19.txt', 'augustan'),
#  ('justinian/digest2.txt', 'augustan'),
#  ('justinian/digest20.txt', 'augustan'),
#  ('justinian/digest21.txt', 'augustan'),
#  ('justinian/digest22.txt', 'augustan'),
#  ('justinian/digest23.txt', 'augustan'),
#  ('justinian/digest24.txt', 'augustan'),
#  ('justinian/digest25.txt', 'augustan'),
#  ('justinian/digest26.txt', 'augustan'),
#  ('justinian/digest27.txt', 'augustan'),
#  ('justinian/digest28.txt', 'augustan'),
#  ('justinian/digest29.txt', 'augustan'),
#  ('justinian/digest3.txt', 'augustan'),
#  ('justinian/digest30.txt', 'augustan'),
#  ('justinian/digest31.txt', 'augustan'),
#  ('justinian/digest32.txt', 'augustan'),
#  ('justinian/digest33.txt', 'augustan'),
#  ('justinian/digest34.txt', 'augustan'),
#  ('justinian/digest35.txt', 'augustan'),
#  ('justinian/digest36.txt', 'augustan'),
#  ('justinian/digest37.txt', 'augustan'),
#  ('justinian/digest38.txt', 'augustan'),
#  ('justinian/digest39.txt', 'augustan'),
#  ('justinian/digest4.txt', 'augustan'),
#  ('justinian/digest40.txt', 'augustan'),
#  ('justinian/digest41.txt', 'augustan'),
#  ('justinian/digest42.txt', 'augustan'),
#  ('justinian/digest43.txt', 'augustan'),
#  ('justinian/digest44.txt', 'augustan'),
#  ('justinian/digest45.txt', 'augustan'),
#  ('justinian/digest46.txt', 'augustan'),
#  ('justinian/digest47.txt', 'augustan'),
#  ('justinian/digest48.txt', 'augustan'),
#  ('justinian/digest49.txt', 'augustan'),
#  ('justinian/digest5.txt', 'augustan'),
#  ('justinian/digest50.txt', 'augustan'),
#  ('justinian/digest6.txt', 'augustan'),
#  ('justinian/digest7.txt', 'augustan'),
#  ('justinian/digest8.txt', 'augustan'),
#  ('justinian/digest9.txt', 'augustan'),
#  ('justinian/institutes.proem.txt', 'christian'),
#  ('justinian/institutes1.txt', 'christian'),
#  ('justinian/institutes2.txt', 'christian'),
#  ('justinian/institutes3.txt', 'christian'),
#  ('justinian/institutes4.txt', 'christian'),
#  ('kalila.txt', 'augustan'),
#  ('lactantius/demort.txt', 'augustan'),
#  ('lactantius/divinst1.txt', 'augustan'),
#  ('landor.1858.txt', 'augustan'),
#  ('landor1795.txt', 'christian'),
#  ('landor1806.txt', 'early_silver'),
#  ('landor1810.txt', 'augustan'),
#  ('legenda.stephani.txt', 'augustan'),
#  ('leo1.txt', 'augustan'),
#  ('leo2.txt', 'augustan'),
#  ('leo3.txt', 'augustan'),
#  ('letabundus.txt', 'christian'),
#  ('levis.txt', 'early_silver'),
#  ('lhomond.historiae.txt', 'augustan'),
#  ('lhomond.viris.txt', 'augustan'),
#  ('liberpontificalis1.txt', 'augustan'),
#  ('lotichius.txt', 'augustan'),
#  ('lucernarium.txt', 'christian'),
#  ('luther.95.txt', 'augustan'),
#  ('luther.lteramus.txt', 'augustan'),
#  ('luther.praef.txt', 'augustan'),
#  ('magnacarta.txt', 'early_silver'),
#  ('maidstone.txt', 'early_silver'),
#  ('malaterra1.txt', 'christian'),
#  ('malaterra2.txt', 'christian'),
#  ('malaterra3.txt', 'christian'),
#  ('malaterra4.txt', 'christian'),
#  ('mapps1.txt', 'christian'),
#  ('mapps2.txt', 'christian'),
#  ('marbodus.txt', 'early_silver'),
#  ('marcellinus1.txt', 'early_silver'),
#  ('marcellinus2.txt', 'early_silver'),
#  ('martinbraga/capitula.txt', 'early_silver'),
#  ('martinbraga/concilium1.txt', 'early_silver'),
#  ('martinbraga/concilium2.txt', 'early_silver'),
#  ('martinbraga/exhortatio.txt', 'early_silver'),
#  ('martinbraga/formula.txt', 'early_silver'),
#  ('martinbraga/ira.txt', 'early_silver'),
#  ('martinbraga/pascha.txt', 'early_silver'),
#  ('martinbraga/poems.txt', 'early_silver'),
#  ('martinbraga/repellenda.txt', 'early_silver'),
#  ('martinbraga/rusticus.txt', 'early_silver'),
#  ('martinbraga/sententiae.txt', 'early_silver'),
#  ('martinbraga/superbia.txt', 'early_silver'),
#  ('martinbraga/trina.txt', 'early_silver'),
#  ('marullo.txt', 'early_silver'),
#  ('marx.txt', 'christian'),
#  ('maximianus.txt', 'early_silver'),
#  ('milton.quintnov.txt', 'christian'),
#  ('minucius.txt', 'early_silver'),
#  ('mirabilia.txt', 'early_silver'),
#  ('mirabilia1.txt', 'christian'),
#  ('mirandola/mir1.txt', 'republican'),
#  ('mirandola/mir2.txt', 'republican'),
#  ('mirandola/mir3.txt', 'republican'),
#  ('mirandola/mir4.txt', 'republican'),
#  ('mirandola/mir5.txt', 'republican'),
#  ('mirandola/mir6.txt', 'republican'),
#  ('mirandola/mir7.txt', 'republican'),
#  ('mirandola/mir8.txt', 'republican'),
#  ('mirandola/mir9.txt', 'republican'),
#  ('mirandola/oratio.txt', 'augustan'),
#  ('montanus.txt', 'late_silver'),
#  ('more.txt', 'christian'),
#  ('musavenit.txt', 'early_silver'),
#  ('naevius.txt', 'republican'),
#  ('navagero.txt', 'republican'),
#  ('nemesianus1.txt', 'republican'),
#  ('nemesianus2.txt', 'republican'),
#  ('nemesianus3.txt', 'republican'),
#  ('nemesianus4.txt', 'republican'),
#  ('newton.capita.txt', 'republican'),
#  ('newton.leges.txt', 'republican'),
#  ('newton.regulae.txt', 'republican'),
#  ('newton.scholium.txt', 'republican'),
#  ('nithardus1.txt', 'republican'),
#  ('nithardus2.txt', 'republican'),
#  ('nithardus3.txt', 'republican'),
#  ('nithardus4.txt', 'republican'),
#  ('nivis.txt', 'republican'),
#  ('nobilis.txt', 'republican'),
#  ('notitia1.txt', 'republican'),
#  ('notitia2.txt', 'republican'),
#  ('obsequens.txt', 'christian'),
#  ('omnegenus.txt', 'augustan'),
#  ('oratio.stephani.txt', 'augustan'),
#  ('oresmius.txt', 'augustan'),
#  ('origo.txt', 'augustan'),
#  ('ottofreising/1.txt', 'augustan'),
#  ('ottofreising/2.txt', 'augustan'),
#  ('ottofreising/3.txt', 'augustan'),
#  ('ottofreising/4.txt', 'augustan'),
#  ('ottofreising/epistola.txt', 'augustan'),
#  ('owen.txt', 'christian'),
#  ('paris.txt', 'christian'),
#  ('pascoli.catull.txt', 'republican'),
#  ('pascoli.iug.txt', 'christian'),
#  ('pascoli.laur.txt', 'augustan'),
#  ('pascoli.sen.txt', 'early_silver'),
#  ('pascoli.veianius.txt', 'christian'),
#  ('passerat.txt', 'christian'),
#  ('patricius1.txt', 'late_silver'),
#  ('patricius2.txt', 'late_silver'),
#  ('pauldeacon/carmina.txt', 'augustan'),
#  ('pauldeacon/fabulae.txt', 'augustan'),
#  ('pauldeacon/hist1.txt', 'augustan'),
#  ('pauldeacon/hist2.txt', 'augustan'),
#  ('pauldeacon/hist3.txt', 'augustan'),
#  ('pauldeacon/hist4.txt', 'augustan'),
#  ('pauldeacon/hist5.txt', 'augustan'),
#  ('pauldeacon/hist6.txt', 'augustan'),
#  ('pauldeacon/histrom1.txt', 'augustan'),
#  ('pauldeacon/histrom10.txt', 'augustan'),
#  ('pauldeacon/histrom11.txt', 'augustan'),
#  ('pauldeacon/histrom12.txt', 'augustan'),
#  ('pauldeacon/histrom13.txt', 'augustan'),
#  ('pauldeacon/histrom14.txt', 'augustan'),
#  ('pauldeacon/histrom15.txt', 'augustan'),
#  ('pauldeacon/histrom16.txt', 'augustan'),
#  ('pauldeacon/histrom2.txt', 'augustan'),
#  ('pauldeacon/histrom3.txt', 'augustan'),
#  ('pauldeacon/histrom4.txt', 'augustan'),
#  ('pauldeacon/histrom5.txt', 'augustan'),
#  ('pauldeacon/histrom6.txt', 'augustan'),
#  ('pauldeacon/histrom7.txt', 'augustan'),
#  ('pauldeacon/histrom8.txt', 'augustan'),
#  ('pauldeacon/histrom9.txt', 'augustan'),
#  ('paulinus.ausonium.txt', 'augustan'),
#  ('pervig.txt', 'augustan'),
#  ('petrarchmedicus.txt', 'augustan'),
#  ('piccolomini.carmen.txt', 'christian'),
#  ('piccolomini.ep1.txt', 'augustan'),
#  ('piccolomini.ep2.txt', 'augustan'),
#  ('piccolomini.ep3.txt', 'augustan'),
#  ('piccolomini.ep4.txt', 'augustan'),
#  ('piccolomini.ep5.txt', 'augustan'),
#  ('piccolomini.ep6.txt', 'augustan'),
#  ('piccolomini.turcos.txt', 'augustan'),
#  ('planctus.txt', 'christian'),
#  ('poggio.txt', 'augustan'),
#  ('pomponius1.txt', 'augustan'),
#  ('pomponius2.txt', 'augustan'),
#  ('pomponius3.txt', 'augustan'),
#  ('pontano.txt', 'christian'),
#  ('poree.txt', 'republican'),
#  ('porphyrius.txt', 'augustan'),
#  ('potatores.txt', 'augustan'),
#  ('prataiam.txt', 'augustan'),
#  ('prec.terr.txt', 'augustan'),
#  ('precatio.txt', 'augustan'),
#  ('priapea.txt', 'augustan'),
#  ('prop2.txt', 'augustan'),
#  ('prop3.txt', 'augustan'),
#  ('prop4.txt', 'early_silver'),
#  ('prosperus.epistola.txt', 'early_silver'),
#  ('prosperus.rufinum.txt', 'early_silver'),
#  ('prosperus.sententiae.txt', 'early_silver'),
#  ('protospatarius.txt', 'augustan'),
#  ('psplato.amatores.txt', 'augustan'),
#  ('psplato.demodocus.txt', 'augustan'),
#  ('psplato.eryxias.txt', 'augustan'),
#  ('psplato.halcyon.txt', 'augustan'),
#  ('psplato.iusto.txt', 'augustan'),
#  ('psplato.minos.txt', 'augustan'),
#  ('psplato.sisyphus.txt', 'augustan'),
#  ('psplato.virtu.txt', 'augustan'),
#  ('pulchracomis.txt', 'augustan'),
#  ('quum.txt', 'early_silver'),
#  ('raoul.txt', 'christian'),
#  ('reposianus.txt', 'christian'),
#  ('rhetores.txt', 'christian'),
#  ('richerus1.txt', 'christian'),
#  ('richerus2.txt', 'christian'),
#  ('richerus3.txt', 'christian'),
#  ('richerus4.txt', 'christian'),
#  ('rimbaud.txt', 'christian'),
#  ('ruaeus.txt', 'christian'),
#  ('rumor.txt', 'early_silver'),
#  ('rutilius.txt', 'christian'),
#  ('rutiliuslupus.txt', 'augustan'),
#  ('sabinus1.txt', 'early_silver'),
#  ('sabinus2.txt', 'early_silver'),
#  ('sabinus3.txt', 'early_silver'),
#  ('sannazaro1.txt', 'early_silver'),
#  ('sannazaro2.txt', 'early_silver'),
#  ('scaliger.txt', 'early_silver'),
#  ('scbaccanalibus.txt', 'early_silver'),
#  ('scottus.txt', 'early_silver'),
#  ('sedulius.solis.txt', 'early_silver'),
#  ('sedulius1.txt', 'early_silver'),
#  ('sedulius2.txt', 'early_silver'),
#  ('sedulius3.txt', 'early_silver'),
#  ('sedulius4.txt', 'early_silver'),
#  ('sedulius5.txt', 'early_silver'),
#  ('septsap.txt', 'christian'),
#  ('sha/30.txt', 'christian'),
#  ('sha/aelii.txt', 'christian'),
#  ('sha/alexsev.txt', 'christian'),
#  ('sha/ant.txt', 'christian'),
#  ('sha/aurel.txt', 'christian'),
#  ('sha/avid.txt', 'christian'),
#  ('sha/car.txt', 'republican'),
#  ('sha/carus.txt', 'republican'),
#  ('sha/claud.txt', 'republican'),
#  ('sha/clod.txt', 'republican'),
#  ('sha/com.txt', 'republican'),
#  ('sha/diad.txt', 'augustan'),
#  ('sha/didiul.txt', 'augustan'),
#  ('sha/firmus.txt', 'christian'),
#  ('sha/gall.txt', 'christian'),
#  ('sha/geta.txt', 'christian'),
#  ('sha/gord.txt', 'christian'),
#  ('sha/hadr.txt', 'augustan'),
#  ('sha/helio.txt', 'christian'),
#  ('sha/mac.txt', 'early_silver'),
#  ('sha/marcant.txt', 'early_silver'),
#  ('sha/max.txt', 'early_silver'),
#  ('sha/maxbal.txt', 'early_silver'),
#  ('sha/pert.txt', 'augustan'),
#  ('sha/pesc.txt', 'augustan'),
#  ('sha/probus.txt', 'augustan'),
#  ('sha/sepsev.txt', 'early_silver'),
#  ('sha/tacitus.txt', 'christian'),
#  ('sha/val.txt', 'christian'),
#  ('sha/verus.txt', 'augustan'),
#  ('sicmeafata.txt', 'early_silver'),
#  ('sidonius1.txt', 'early_silver'),
#  ('sidonius2.txt', 'early_silver'),
#  ('sidonius3.txt', 'early_silver'),
#  ('sidonius4.txt', 'early_silver'),
#  ('sidonius5.txt', 'early_silver'),
#  ('sidonius6.txt', 'early_silver'),
#  ('sidonius7.txt', 'early_silver'),
#  ('sidonius8.txt', 'early_silver'),
#  ('sidonius9.txt', 'early_silver'),
#  ('sigebert.script.txt', 'early_silver'),
#  ('sigebert.virgin.txt', 'early_silver'),
#  ('sigebert.vitabrevior.txt', 'early_silver'),
#  ('simedignetur.txt', 'early_silver'),
#  ('smarius.txt', 'christian'),
#  ('solet.txt', 'early_silver'),
#  ('solinus1.txt', 'early_silver'),
#  ('solinus1a.txt', 'early_silver'),
#  ('solinus2.txt', 'early_silver'),
#  ('solinus2a.txt', 'early_silver'),
#  ('solinus3.txt', 'early_silver'),
#  ('solinus3a.txt', 'early_silver'),
#  ('solinus4.txt', 'early_silver'),
#  ('solinus4a.txt', 'early_silver'),
#  ('solinus5.txt', 'early_silver'),
#  ('sulpiciusseveruschron1.txt', 'early_silver'),
#  ('sulpiciusseveruschron2.txt', 'early_silver'),
#  ('sulpiciusseverusmartin.txt', 'early_silver'),
#  ('suscipeflos.txt', 'early_silver'),
#  ('syrus.txt', 'augustan'),
#  ('tempusest.txt', 'christian'),
#  ('terraiam.txt', 'christian'),
#  ('testamentum.txt', 'christian'),
#  ('tevigilans.txt', 'early_silver'),
#  ('theganus.txt', 'christian'),
#  ('theodolus.txt', 'christian'),
#  ('theodosius/theod01.txt', 'christian'),
#  ('theodosius/theod02.txt', 'christian'),
#  ('theodosius/theod03.txt', 'christian'),
#  ('theodosius/theod04.txt', 'christian'),
#  ('theodosius/theod05.txt', 'christian'),
#  ('theodosius/theod06.txt', 'christian'),
#  ('theodosius/theod07.txt', 'christian'),
#  ('theodosius/theod08.txt', 'christian'),
#  ('theodosius/theod09.txt', 'christian'),
#  ('theodosius/theod10.txt', 'christian'),
#  ('theodosius/theod11.txt', 'christian'),
#  ('theodosius/theod12.txt', 'christian'),
#  ('theodosius/theod13.txt', 'christian'),
#  ('theodosius/theod14.txt', 'christian'),
#  ('theodosius/theod15.txt', 'christian'),
#  ('theodosius/theod16.txt', 'christian'),
#  ('theophanes.txt', 'christian'),
#  ('thesauro.txt', 'christian'),
#  ('thomasedessa.txt', 'christian'),
#  ('tunger.txt', 'christian'),
#  ('valesianus.txt', 'christian'),
#  ('valesianus1.txt', 'christian'),
#  ('valesianus2.txt', 'christian'),
#  ('vegetius1.txt', 'christian'),
#  ('vegetius2.txt', 'christian'),
#  ('vegetius3.txt', 'christian'),
#  ('vegetius4.txt', 'christian'),
#  ('vegius.txt', 'christian'),
#  ('venantius.txt', 'christian'),
#  ('vestiunt.txt', 'christian'),
#  ('vicentius.txt', 'christian'),
#  ('vico.orat6.txt', 'christian'),
#  ('victor.caes.txt', 'augustan'),
#  ('victor.caes2.txt', 'christian'),
#  ('victor.ill.txt', 'augustan'),
#  ('victor.origio.txt', 'christian'),
#  ('vida.txt', 'christian'),
#  ('vitacaroli.txt', 'christian'),
#  ('volovirum.txt', 'christian'),
#  ('voragine/alexio.txt', 'christian'),
#  ('voragine/ambro.txt', 'christian'),
#  ('voragine/anast.txt', 'christian'),
#  ('voragine/andrea.txt', 'christian'),
#  ('voragine/ant.txt', 'christian'),
#  ('voragine/blas.txt', 'christian'),
#  ('voragine/chris.txt', 'christian'),
#  ('voragine/fran.txt', 'christian'),
#  ('voragine/georgio.txt', 'christian'),
#  ('voragine/iacob.txt', 'christian'),
#  ('voragine/iul.txt', 'christian'),
#  ('voragine/jud.txt', 'christian'),
#  ('voragine/luc.txt', 'christian'),
#  ('voragine/marc.txt', 'christian'),
#  ('voragine/mariamag.txt', 'augustan'),
#  ('voragine/marina.txt', 'christian'),
#  ('voragine/nic.txt', 'christian'),
#  ('voragine/paulo.txt', 'christian'),
#  ('voragine/seb.txt', 'christian'),
#  ('voragine/septem.txt', 'christian'),
#  ('voragine/silv.txt', 'christian'),
#  ('voragine/thom.txt', 'christian'),
#  ('voragine/vin.txt', 'christian'),
#  ('voragine/vir.txt', 'christian'),
#  ('waardenburg.txt', 'republican'),
#  ('waltarius1.txt', 'christian'),
#  ('waltarius2.txt', 'christian'),
#  ('waltarius3.txt', 'christian'),
#  ('walter/pastourelles.txt', 'christian'),
#  ('walter/walter1.txt', 'christian'),
#  ('walter/walter2.txt', 'christian'),
#  ('walter/walter3.txt', 'christian'),
#  ('walter10.txt', 'christian'),
#  ('walter11.txt', 'christian'),
#  ('walter12.txt', 'christian'),
#  ('walter4.txt', 'christian'),
#  ('walter5.txt', 'christian'),
#  ('walter6.txt', 'christian'),
#  ('walter7.txt', 'christian'),
#  ('walter8.txt', 'christian'),
#  ('walter9.txt', 'christian'),
#  ('walton.txt', 'neo_latin'),
#  ('williamapulia.txt', 'christian'),
#  ('williamtyre/1.txt', 'christian'),
#  ('williamtyre/10.txt', 'christian'),
#  ('williamtyre/11.txt', 'christian'),
#  ('williamtyre/12.txt', 'christian'),
#  ('williamtyre/13.txt', 'christian'),
#  ('williamtyre/14.txt', 'christian'),
#  ('williamtyre/15.txt', 'christian'),
#  ('williamtyre/16.txt', 'christian'),
#  ('williamtyre/17.txt', 'christian'),
#  ('williamtyre/18.txt', 'christian'),
#  ('williamtyre/19.txt', 'christian'),
#  ('williamtyre/2.txt', 'christian'),
#  ('williamtyre/20.txt', 'christian'),
#  ('williamtyre/21.txt', 'christian'),
#  ('williamtyre/22.txt', 'christian'),
#  ('williamtyre/23.txt', 'christian'),
#  ('williamtyre/3.txt', 'christian'),
#  ('williamtyre/4.txt', 'christian'),
#  ('williamtyre/5.txt', 'christian'),
#  ('williamtyre/6.txt', 'christian'),
#  ('williamtyre/7.txt', 'christian'),
#  ('williamtyre/8.txt', 'christian'),
#  ('williamtyre/9.txt', 'christian'),
#  ('williamtyre/prologus.txt', 'christian'),
#  ('withof.txt', 'christian'),
#  ('withof1.txt', 'christian'),
#  ('withof2.txt', 'christian'),
#  ('withof3.txt', 'christian'),
#  ('withof4.txt', 'christian'),
#  ('withof5.txt', 'christian'),
#  ('withof6.txt', 'christian'),
#  ('withof7.txt', 'christian'),
#  ('wmconchesdogma.txt', 'christian'),
#  ('wmconchesphil.txt', 'christian'),
#  ('xanten.txt', 'christian'),
#  ('zonaras.txt', 'christian')]

# %% [markdown]
# ## Conclusion:
# Using tfidf is insufficient for clustering a single author, and across authors the shared signal is not high enough to place them in multi-doc era classification. We will experiment with further feature selection.
# #### To be continued...
