# %% [markdown]
# ### Assessing regularization of Latin corpus texts
# In Cythia Damon's masterful edition of Julius Caesar's _Bellum Civile_ she provides rules for the spelling regularizations she performed in an Appendix Orthographica. This notebook tries to quantify the quality and scope of these suggested regularizations when applied to a larger Latin corpus.

# %%
import os.path
from collections import Counter
import inspect
import os
import sys
from glob import glob
from typing import List, Dict, Tuple

from cltk.corpus.readers import get_corpus_reader
from cltk.stem.latin.j_v import JVReplacer
from cltk.tokenize.latin.sentence import SentenceTokenizer
from cltk.tokenize.word import WordTokenizer
from cltk.corpus.latin.phi5_index import PHI5_INDEX
from tqdm import tqdm

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)
 
from mlyoucanuse.aeoe_replacer import AEOEReplacer
from mlyoucanuse.text_cleaners import ( normalize_accents, disappear_angle_brackets,
                                        drop_punct, disappear_round_brackets,
                                         dehyphenate, accept_editorial,
                                        swallow_braces, swallow_obelized_words,
                                        swallow_square_brackets)

# %% [markdown]
# # Latin Prefix Regularizations
# Adapted from the Appendix Orthographica of Cythia Damon _C. Iuli Caesaris commentarii de bello civili_ (Bellum civile, or Civil War) (Oxford Classical Texts), pp. 166

# %%
# The first string in the tuple is the preferred prefix
# The second string in the tuple is the anomaly to be regularized
regularizations = [('adf', 'aff'),
                  ('agg', 'adg'), 
                  ('all', 'adl'),
                  ('adm', 'amm'),
                  ('adn', 'ann'), # problematic because of 'annuo', '->', 'adnuo' viz. annuus,a,um
                  ('app', 'adp'),
                  ('arr', 'adr'), 
                  ('ass', 'ads'), 
                  ('adst', 'asstan'),
                  ('att', 'adt'), 
                  ('afu', 'affu'), 
                  ('afu', 'abfu'), 
                  ('conic', 'coic'),
                  ('conic', 'conit'), 
                  # ('conic', 'coit'),  # problematic with: ('coitus', '->', 'collus')
                  ('coll', 'conl'), 
                  ('comp', 'conp'),
                  ('corr', 'conr'), 
                  ('ill', 'inl'),
                  ('imm', 'inm'),
                  ('imp', 'inp'), 
                  ('irr', 'inr'),
                  ('obt', 'opt'),
                  ('opp', 'obp'),
                  ('prae', 'pre'),
                  ('subm', 'summ'),
                  ('suff', 'subf'), 
                  ('supp', 'subp'),
                  ('trai', 'transi') # problematic: ('transis', '->', 'trais', 7)
                 ]

# %%
# In the following sections, we will show Damon's preferred prefix first

# some useful functions

def get_matches(prefix:str, word_counts:Dict[str,int])->Tuple[int, List[str]]:
    egs = [(key, val) for key,val in word_counts.items() if key.startswith(prefix)]
    if len(egs) ==0:
        return 0, []
    vals, counts = zip(*egs)
    egs = sorted(egs, key=lambda x:x[1], reverse=True)
    return sum(counts), egs

def print_regularizations(word_counts):
    total_transformations = 0
    for prefix_one, prefix_two in regularizations:
        prefix_one_num, prefix_one_egs = get_matches(prefix_one, word_counts) 
        prefix_two_num, prefix_two_egs = get_matches(prefix_two, word_counts) 
        print(f"# prefix examples: {prefix_one}- {prefix_one_num:,}, {prefix_two}- {prefix_two_num:,}")
        common_transforms = []
        for word, count in prefix_two_egs:
            transformed = word.replace(prefix_two, prefix_one)
            if transformed in word_counts:
                common_transforms.append((word, '->', transformed, count))
                total_transformations +=count
        print(f'exact transform matches: {len(common_transforms)}')            
        for item in common_transforms:
            print(item)
    print(f"total transformations proposed {total_transformations:,}")

# %% [markdown]
# # Tesserae Corpus: Proposed Spelling Regularizations

# %%
tesserae = get_corpus_reader(corpus_name='latin_text_tesserae', language='latin')
word_counts = Counter()
jv_replacer = JVReplacer()
aeoe_replacer = AEOEReplacer()
toker = WordTokenizer('latin')
sent_toker = SentenceTokenizer()

for file in tqdm(tesserae.fileids(), total=len(tesserae.fileids())):
    for sent in tesserae.sents(file):
        sent = aeoe_replacer.replace(jv_replacer.replace(sent))
        sent = normalize_accents(sent)
        sent = accept_editorial(sent)
        sent = drop_punct(sent)
        for token in toker.tokenize(sent):
            word_counts.update({token : 1})

print_regularizations(word_counts)
# Out:
# 100%|██████████| 762/762 [03:24<00:00,  3.72it/s]
# # prefix examples: adf- 4,606, aff- 1,488
# exact transform matches: 257
# ('affectus', '->', 'adfectus', 144)
# ('affectu', '->', 'adfectu', 70)
# ('affectum', '->', 'adfectum', 64)
# ('affert', '->', 'adfert', 40)
# ('afferre', '->', 'adferre', 39)
# ('affatim', '->', 'adfatim', 33)
# ('affirmat', '->', 'adfirmat', 32)
# ('affectibus', '->', 'adfectibus', 28)
# ('affectio', '->', 'adfectio', 25)
# ('affici', '->', 'adfici', 21)
# ('afferat', '->', 'adferat', 21)
# ('afferri', '->', 'adferri', 20)
# ('afferunt', '->', 'adferunt', 17)
# ('afflictis', '->', 'adflictis', 16)
# ('afflicti', '->', 'adflicti', 15)
# ('affuit', '->', 'adfuit', 15)
# ('affirmauit', '->', 'adfirmauit', 15)
# ('afficit', '->', 'adficit', 15)
# ('affore', '->', 'adfore', 14)
# ('affatur', '->', 'adfatur', 14)
# ('affirmare', '->', 'adfirmare', 13)
# ('affinitatem', '->', 'adfinitatem', 13)
# ('afflixit', '->', 'adflixit', 12)
# ('afflatu', '->', 'adflatu', 12)
# ('afferret', '->', 'adferret', 11)
# ('affines', '->', 'adfines', 11)
# ('affecti', '->', 'adfecti', 10)
# ('affirmans', '->', 'adfirmans', 10)
# ('afficitur', '->', 'adficitur', 10)
# ('afflictos', '->', 'adflictos', 9)
# ('affectat', '->', 'adfectat', 9)
# ('affinis', '->', 'adfinis', 9)
# ('affirmant', '->', 'adfirmant', 9)
# ('affectans', '->', 'adfectans', 8)
# ('affirmabat', '->', 'adfirmabat', 8)
# ('affecit', '->', 'adfecit', 8)
# ('affluentia', '->', 'adfluentia', 8)
# ('affero', '->', 'adfero', 8)
# ('affecta', '->', 'adfecta', 8)
# ('affectionis', '->', 'adfectionis', 7)
# ('afflictae', '->', 'adflictae', 7)
# ('affecto', '->', 'adfecto', 7)
# ('afflictus', '->', 'adflictus', 7)
# ('afflicta', '->', 'adflicta', 7)
# ('affatibus', '->', 'adfatibus', 7)
# ('afflictam', '->', 'adflictam', 7)
# ('affatus', '->', 'adfatus', 7)
# ('affectionem', '->', 'adfectionem', 7)
# ('affixa', '->', 'adfixa', 7)
# ('afferant', '->', 'adferant', 7)
# ('afflictas', '->', 'adflictas', 6)
# ('affirmo', '->', 'adfirmo', 6)
# ('affligi', '->', 'adfligi', 6)
# ('affixus', '->', 'adfixus', 6)
# ('affabilis', '->', 'adfabilis', 6)
# ('afferebat', '->', 'adferebat', 6)
# ('affectiones', '->', 'adfectiones', 6)
# ('afficere', '->', 'adficere', 6)
# ('affectant', '->', 'adfectant', 5)
# ('affluere', '->', 'adfluere', 5)
# ('affectabat', '->', 'adfectabat', 5)
# ('affusa', '->', 'adfusa', 5)
# ('afflictum', '->', 'adflictum', 5)
# ('afficiuntur', '->', 'adficiuntur', 5)
# ('affinem', '->', 'adfinem', 5)
# ('affluens', '->', 'adfluens', 5)
# ('affectos', '->', 'adfectos', 5)
# ('affatu', '->', 'adfatu', 5)
# ('affertur', '->', 'adfertur', 5)
# ('affectis', '->', 'adfectis', 5)
# ('affectuum', '->', 'adfectuum', 5)
# ('affirmatio', '->', 'adfirmatio', 5)
# ('afferet', '->', 'adferet', 5)
# ('afferetur', '->', 'adferetur', 5)
# ('affari', '->', 'adfari', 5)
# ('affectas', '->', 'adfectas', 5)
# ('afflatus', '->', 'adflatus', 5)
# ('affluebant', '->', 'adfluebant', 4)
# ('affabilitate', '->', 'adfabilitate', 4)
# ('affirmabant', '->', 'adfirmabant', 4)
# ('affulsisse', '->', 'adfulsisse', 4)
# ('affectata', '->', 'adfectata', 4)
# ('affirmantem', '->', 'adfirmantem', 4)
# ('affigi', '->', 'adfigi', 4)
# ('affluentibus', '->', 'adfluentibus', 4)
# ('affluit', '->', 'adfluit', 4)
# ('affluentius', '->', 'adfluentius', 4)
# ('affers', '->', 'adfers', 4)
# ('afficiatur', '->', 'adficiatur', 4)
# ('afflicto', '->', 'adflicto', 4)
# ('affuisset', '->', 'adfuisset', 4)
# ('affligebat', '->', 'adfligebat', 3)
# ('affectator', '->', 'adfectator', 3)
# ('afflictabant', '->', 'adflictabant', 3)
# ('afflictabat', '->', 'adflictabat', 3)
# ('affixis', '->', 'adfixis', 3)
# ('affluentes', '->', 'adfluentes', 3)
# ('affinitate', '->', 'adfinitate', 3)
# ('affixo', '->', 'adfixo', 3)
# ('affirma', '->', 'adfirma', 3)
# ('afferas', '->', 'adferas', 3)
# ('afficiunt', '->', 'adficiunt', 3)
# ('afflictionibus', '->', 'adflictionibus', 3)
# ('affinitatis', '->', 'adfinitatis', 3)
# ('affligat', '->', 'adfligat', 3)
# ('affuturum', '->', 'adfuturum', 3)
# ('afficiantur', '->', 'adficiantur', 3)
# ('afficior', '->', 'adficior', 3)
# ('affirmamus', '->', 'adfirmamus', 3)
# ('afferatur', '->', 'adferatur', 3)
# ('affui', '->', 'adfui', 3)
# ('afflauit', '->', 'adflauit', 3)
# ('affectam', '->', 'adfectam', 3)
# ('afficeret', '->', 'adficeret', 3)
# ('afflatum', '->', 'adflatum', 3)
# ('affluat', '->', 'adfluat', 3)
# ('affer', '->', 'adfer', 3)
# ('afficiet', '->', 'adficiet', 3)
# ('affigere', '->', 'adfigere', 3)
# ('afferam', '->', 'adferam', 3)
# ('affirmantibus', '->', 'adfirmantibus', 3)
# ('affectati', '->', 'adfectati', 2)
# ('affuerit', '->', 'adfuerit', 2)
# ('affectasse', '->', 'adfectasse', 2)
# ('affusi', '->', 'adfusi', 2)
# ('affectare', '->', 'adfectare', 2)
# ('affectauit', '->', 'adfectauit', 2)
# ('affirmante', '->', 'adfirmante', 2)
# ('affliguntur', '->', 'adfliguntur', 2)
# ('affectatae', '->', 'adfectatae', 2)
# ('affligeret', '->', 'adfligeret', 2)
# ('affluente', '->', 'adfluente', 2)
# ('affectando', '->', 'adfectando', 2)
# ('affuturus', '->', 'adfuturus', 2)
# ('affi', '->', 'adfi', 2)
# ('affligerentur', '->', 'adfligerentur', 2)
# ('affixi', '->', 'adfixi', 2)
# ('affectionibus', '->', 'adfectionibus', 2)
# ('afflauerit', '->', 'adflauerit', 2)
# ('affirmet', '->', 'adfirmet', 2)
# ('affinium', '->', 'adfinium', 2)
# ('affectae', '->', 'adfectae', 2)
# ('affulsit', '->', 'adfulsit', 2)
# ('affirmatum', '->', 'adfirmatum', 2)
# ('afficeretur', '->', 'adficeretur', 2)
# ('affecerant', '->', 'adfecerant', 2)
# ('affluentis', '->', 'adfluentis', 2)
# ('afflictio', '->', 'adflictio', 2)
# ('afferte', '->', 'adferte', 2)
# ('affectionum', '->', 'adfectionum', 2)
# ('affluant', '->', 'adfluant', 2)
# ('afficiant', '->', 'adficiant', 2)
# ('affuturam', '->', 'adfuturam', 2)
# ('afferebam', '->', 'adferebam', 2)
# ('affirmatur', '->', 'adfirmatur', 2)
# ('affuisses', '->', 'adfuisses', 2)
# ('affluenti', '->', 'adfluenti', 2)
# ('afflueret', '->', 'adflueret', 2)
# ('afferrent', '->', 'adferrent', 2)
# ('affinitatibus', '->', 'adfinitatibus', 2)
# ('afficiendum', '->', 'adficiendum', 2)
# ('afferes', '->', 'adferes', 2)
# ('afflari', '->', 'adflari', 2)
# ('affata', '->', 'adfata', 2)
# ('affusus', '->', 'adfusus', 2)
# ('affluet', '->', 'adfluet', 2)
# ('affulserat', '->', 'adfulserat', 2)
# ('affirmes', '->', 'adfirmes', 2)
# ('affectantibus', '->', 'adfectantibus', 2)
# ('affrictu', '->', 'adfrictu', 2)
# ('affingere', '->', 'adfingere', 2)
# ('affectatio', '->', 'adfectatio', 2)
# ('afferent', '->', 'adferent', 2)
# ('affirmasse', '->', 'adfirmasse', 2)
# ('affirmasset', '->', 'adfirmasset', 2)
# ('affligens', '->', 'adfligens', 1)
# ('affectatam', '->', 'adfectatam', 1)
# ('afficiendus', '->', 'adficiendus', 1)
# ('affulsisset', '->', 'adfulsisset', 1)
# ('affulserit', '->', 'adfulserit', 1)
# ('affingens', '->', 'adfingens', 1)
# ('affectamus', '->', 'adfectamus', 1)
# ('afferente', '->', 'adferente', 1)
# ('affectatum', '->', 'adfectatum', 1)
# ('affluunt', '->', 'adfluunt', 1)
# ('affixas', '->', 'adfixas', 1)
# ('affirmantes', '->', 'adfirmantes', 1)
# ('afflictabatur', '->', 'adflictabatur', 1)
# ('affixam', '->', 'adfixam', 1)
# ('affirmando', '->', 'adfirmando', 1)
# ('affingimus', '->', 'adfingimus', 1)
# ('afflictare', '->', 'adflictare', 1)
# ('affligit', '->', 'adfligit', 1)
# ('affinxit', '->', 'adfinxit', 1)
# ('afforet', '->', 'adforet', 1)
# ('affirmas', '->', 'adfirmas', 1)
# ('afficiat', '->', 'adficiat', 1)
# ('affligebantur', '->', 'adfligebantur', 1)
# ('afflictauerat', '->', 'adflictauerat', 1)
# ('afflixerat', '->', 'adflixerat', 1)
# ('afficiens', '->', 'adficiens', 1)
# ('affingitur', '->', 'adfingitur', 1)
# ('affigant', '->', 'adfigant', 1)
# ('affuisti', '->', 'adfuisti', 1)
# ('affuistis', '->', 'adfuistis', 1)
# ('affirmatis', '->', 'adfirmatis', 1)
# ('afferemus', '->', 'adferemus', 1)
# ('afferentur', '->', 'adferentur', 1)
# ('afferendum', '->', 'adferendum', 1)
# ('affinitates', '->', 'adfinitates', 1)
# ('affirmandi', '->', 'adfirmandi', 1)
# ('afficientur', '->', 'adficientur', 1)
# ('afflata', '->', 'adflata', 1)
# ('affligitur', '->', 'adfligitur', 1)
# ('afficiam', '->', 'adficiam', 1)
# ('affigens', '->', 'adfigens', 1)
# ('afferebant', '->', 'adferebant', 1)
# ('afflati', '->', 'adflati', 1)
# ('afflixisti', '->', 'adflixisti', 1)
# ('affligunt', '->', 'adfligunt', 1)
# ('affixum', '->', 'adfixum', 1)
# ('affirment', '->', 'adfirment', 1)
# ('affabiliter', '->', 'adfabiliter', 1)
# ('affundit', '->', 'adfundit', 1)
# ('afficerentur', '->', 'adficerentur', 1)
# ('affecerunt', '->', 'adfecerunt', 1)
# ('affuerant', '->', 'adfuerant', 1)
# ('affirmaui', '->', 'adfirmaui', 1)
# ('afflictat', '->', 'adflictat', 1)
# ('affecerint', '->', 'adfecerint', 1)
# ('affirmauerunt', '->', 'adfirmauerunt', 1)
# ('affigit', '->', 'adfigit', 1)
# ('affirmetis', '->', 'adfirmetis', 1)
# ('affectanda', '->', 'adfectanda', 1)
# ('afficeris', '->', 'adficeris', 1)
# ('affinibus', '->', 'adfinibus', 1)
# ('afflabitur', '->', 'adflabitur', 1)
# ('affixit', '->', 'adfixit', 1)
# ('afficiebat', '->', 'adficiebat', 1)
# ('affectet', '->', 'adfectet', 1)
# ('affigatur', '->', 'adfigatur', 1)
# ('afflante', '->', 'adflante', 1)
# ('affusum', '->', 'adfusum', 1)
# ('affiget', '->', 'adfiget', 1)
# ('affligar', '->', 'adfligar', 1)
# ('affliget', '->', 'adfliget', 1)
# ('afflabat', '->', 'adflabat', 1)
# ('affectate', '->', 'adfectate', 1)
# ('afflictarum', '->', 'adflictarum', 1)
# ('affirmarent', '->', 'adfirmarent', 1)
# ('affluentem', '->', 'adfluentem', 1)
# ('affini', '->', 'adfini', 1)
# ('affueris', '->', 'adfueris', 1)
# ('affuisse', '->', 'adfuisse', 1)
# ('affuerunt', '->', 'adfuerunt', 1)
# ('afflixerint', '->', 'adflixerint', 1)
# ('affluxerit', '->', 'adfluxerit', 1)
# # prefix examples: agg- 624, adg- 700
# exact transform matches: 46
# ('adgressus', '->', 'aggressus', 112)
# ('adgredi', '->', 'aggredi', 56)
# ('adgreditur', '->', 'aggreditur', 48)
# ('adgressi', '->', 'aggressi', 37)
# ('adgrediar', '->', 'aggrediar', 32)
# ('adgrederetur', '->', 'aggrederetur', 22)
# ('adgrederentur', '->', 'aggrederentur', 18)
# ('adgrediuntur', '->', 'aggrediuntur', 14)
# ('adgredior', '->', 'aggredior', 12)
# ('adgrediendi', '->', 'aggrediendi', 11)
# ('adgressa', '->', 'aggressa', 9)
# ('adgressurus', '->', 'aggressurus', 9)
# ('adgrauata', '->', 'aggrauata', 8)
# ('adgredienda', '->', 'aggredienda', 6)
# ('adgredimur', '->', 'aggredimur', 6)
# ('adglomerant', '->', 'agglomerant', 6)
# ('adgrediare', '->', 'aggrediare', 5)
# ('adgredere', '->', 'aggredere', 5)
# ('adgrauauit', '->', 'aggrauauit', 5)
# ('adgesta', '->', 'aggesta', 4)
# ('adgressuri', '->', 'aggressuri', 4)
# ('adgressurum', '->', 'aggressurum', 4)
# ('adgrediatur', '->', 'aggrediatur', 3)
# ('adgrediamur', '->', 'aggrediamur', 2)
# ('adgregare', '->', 'aggregare', 2)
# ('adgrederis', '->', 'aggrederis', 2)
# ('adgrediemur', '->', 'aggrediemur', 2)
# ('adgressum', '->', 'aggressum', 2)
# ('adgrediantur', '->', 'aggrediantur', 2)
# ('adgressos', '->', 'aggressos', 2)
# ('adgerunt', '->', 'aggerunt', 2)
# ('adgestu', '->', 'aggestu', 2)
# ('adgesto', '->', 'aggesto', 1)
# ('adgregauerant', '->', 'aggregauerant', 1)
# ('adgeri', '->', 'aggeri', 1)
# ('adgressuros', '->', 'aggressuros', 1)
# ('adglutinant', '->', 'agglutinant', 1)
# ('adgerunda', '->', 'aggerunda', 1)
# ('adgerentem', '->', 'aggerentem', 1)
# ('adgrauetur', '->', 'aggrauetur', 1)
# ('adgressionem', '->', 'aggressionem', 1)
# ('adgrauare', '->', 'aggrauare', 1)
# ('adgeritur', '->', 'aggeritur', 1)
# ('adgestis', '->', 'aggestis', 1)
# ('adgestus', '->', 'aggestus', 1)
# ('adgrediens', '->', 'aggrediens', 1)
# # prefix examples: all- 1,249, adl- 873
# exact transform matches: 94
# ('adlatum', '->', 'allatum', 53)
# ('adloquitur', '->', 'alloquitur', 48)
# ('adlata', '->', 'allata', 38)
# ('adlatae', '->', 'allatae', 35)
# ('adlocutus', '->', 'allocutus', 26)
# ('adloqui', '->', 'alloqui', 23)
# ('adluit', '->', 'alluit', 21)
# ('adloquio', '->', 'alloquio', 19)
# ('adluitur', '->', 'alluitur', 16)
# ('adligat', '->', 'alligat', 13)
# ('adloquiis', '->', 'alloquiis', 13)
# ('adloquor', '->', 'alloquor', 13)
# ('adlatis', '->', 'allatis', 12)
# ('adlatura', '->', 'allatura', 12)
# ('adlatas', '->', 'allatas', 12)
# ('adloquar', '->', 'alloquar', 11)
# ('adludens', '->', 'alludens', 10)
# ('adlatus', '->', 'allatus', 10)
# ('adlato', '->', 'allato', 10)
# ('adlatam', '->', 'allatam', 9)
# ('adlaturum', '->', 'allaturum', 8)
# ('adlicere', '->', 'allicere', 8)
# ('adleuat', '->', 'alleuat', 8)
# ('adlicit', '->', 'allicit', 7)
# ('adlegit', '->', 'allegit', 7)
# ('adlocutio', '->', 'allocutio', 7)
# ('adligauit', '->', 'alligauit', 5)
# ('adludit', '->', 'alludit', 5)
# ('adlidet', '->', 'allidet', 5)
# ('adloquens', '->', 'alloquens', 5)
# ('adlegauit', '->', 'allegauit', 5)
# ('adliget', '->', 'alliget', 4)
# ('adloquium', '->', 'alloquium', 4)
# ('adloquere', '->', 'alloquere', 4)
# ('adlati', '->', 'allati', 3)
# ('adlegat', '->', 'allegat', 3)
# ('adlaturam', '->', 'allaturam', 3)
# ('adligatum', '->', 'alligatum', 3)
# ('adlici', '->', 'allici', 3)
# ('adligari', '->', 'alligari', 3)
# ('adleuari', '->', 'alleuari', 3)
# ('adloquebatur', '->', 'alloquebatur', 3)
# ('adleuans', '->', 'alleuans', 3)
# ('adlaturos', '->', 'allaturos', 3)
# ('adligetur', '->', 'alligetur', 3)
# ('adligati', '->', 'alligati', 3)
# ('adludunt', '->', 'alludunt', 3)
# ('adlocuta', '->', 'allocuta', 2)
# ('adliciat', '->', 'alliciat', 2)
# ('adligata', '->', 'alligata', 2)
# ('adleuandum', '->', 'alleuandum', 2)
# ('adligatam', '->', 'alligatam', 2)
# ('adligare', '->', 'alligare', 2)
# ('adloqueris', '->', 'alloqueris', 2)
# ('adlisa', '->', 'allisa', 2)
# ('adligabit', '->', 'alligabit', 2)
# ('adligatos', '->', 'alligatos', 2)
# ('adliceret', '->', 'alliceret', 2)
# ('adligato', '->', 'alligato', 2)
# ('adliciendi', '->', 'alliciendi', 2)
# ('adleuantur', '->', 'alleuantur', 2)
# ('adlecti', '->', 'allecti', 2)
# ('adliciendo', '->', 'alliciendo', 2)
# ('adlego', '->', 'allego', 1)
# ('adlegabat', '->', 'allegabat', 1)
# ('adliciant', '->', 'alliciant', 1)
# ('adlegationibus', '->', 'allegationibus', 1)
# ('adlegatos', '->', 'allegatos', 1)
# ('adleget', '->', 'alleget', 1)
# ('adligaretur', '->', 'alligaretur', 1)
# ('adludere', '->', 'alludere', 1)
# ('adluuio', '->', 'alluuio', 1)
# ('adlocutionem', '->', 'allocutionem', 1)
# ('adleua', '->', 'alleua', 1)
# ('adlidit', '->', 'allidit', 1)
# ('adleuentur', '->', 'alleuentur', 1)
# ('adluderet', '->', 'alluderet', 1)
# ('adludentibus', '->', 'alludentibus', 1)
# ('adligans', '->', 'alligans', 1)
# ('adleuatio', '->', 'alleuatio', 1)
# ('adligandum', '->', 'alligandum', 1)
# ('adlegemus', '->', 'allegemus', 1)
# ('adligabitur', '->', 'alligabitur', 1)
# ('adloquamur', '->', 'alloquamur', 1)
# ('adloquimur', '->', 'alloquimur', 1)
# ('adliciendas', '->', 'alliciendas', 1)
# ('adligo', '->', 'alligo', 1)
# ('adligatus', '->', 'alligatus', 1)
# ('adliciebat', '->', 'alliciebat', 1)
# ('adlegantes', '->', 'allegantes', 1)
# ('adlectum', '->', 'allectum', 1)
# ('adlegans', '->', 'allegans', 1)
# ('adlusit', '->', 'allusit', 1)
# ('adlacrimans', '->', 'allacrimans', 1)
# # prefix examples: adm- 4,543, amm- 102
# exact transform matches: 40
# ('ammonet', '->', 'admonet', 7)
# ('ammiror', '->', 'admiror', 5)
# ('ammonuit', '->', 'admonuit', 4)
# ('amminiculo', '->', 'adminiculo', 3)
# ('ammiratus', '->', 'admiratus', 3)
# ('ammoneret', '->', 'admoneret', 3)
# ('ammiratio', '->', 'admiratio', 3)
# ('ammirere', '->', 'admirere', 2)
# ('ammixtio', '->', 'admixtio', 2)
# ('ammirationem', '->', 'admirationem', 2)
# ('amminiculis', '->', 'adminiculis', 2)
# ('ammonere', '->', 'admonere', 2)
# ('ammirantibus', '->', 'admirantibus', 2)
# ('ammoneor', '->', 'admoneor', 2)
# ('ammonitionem', '->', 'admonitionem', 2)
# ('ammoneant', '->', 'admoneant', 1)
# ('ammonetis', '->', 'admonetis', 1)
# ('ammonens', '->', 'admonens', 1)
# ('ammonebatur', '->', 'admonebatur', 1)
# ('ammouit', '->', 'admouit', 1)
# ('ammonitio', '->', 'admonitio', 1)
# ('amministrationis', '->', 'administrationis', 1)
# ('ammouebo', '->', 'admouebo', 1)
# ('ammirari', '->', 'admirari', 1)
# ('amministrare', '->', 'administrare', 1)
# ('amministrat', '->', 'administrat', 1)
# ('ammoueri', '->', 'admoueri', 1)
# ('ammiscent', '->', 'admiscent', 1)
# ('ammotis', '->', 'admotis', 1)
# ('ammouet', '->', 'admouet', 1)
# ('ammittunt', '->', 'admittunt', 1)
# ('ammisit', '->', 'admisit', 1)
# ('ammissum', '->', 'admissum', 1)
# ('ammonuimus', '->', 'admonuimus', 1)
# ('ammiranda', '->', 'admiranda', 1)
# ('ammoneo', '->', 'admoneo', 1)
# ('ammonuisse', '->', 'admonuisse', 1)
# ('ammonentur', '->', 'admonentur', 1)
# ('ammi', '->', 'admi', 1)
# ('ammorso', '->', 'admorso', 1)
# # prefix examples: adn- 787, ann- 8,057
# exact transform matches: 52
# ('annuo', '->', 'adnuo', 34)
# ('annuis', '->', 'adnuis', 19)
# ('annuit', '->', 'adnuit', 13)
# ('annitentibus', '->', 'adnitentibus', 5)
# ('annuat', '->', 'adnuat', 4)
# ('annexa', '->', 'adnexa', 3)
# ('ann', '->', 'adn', 3)
# ('annuens', '->', 'adnuens', 3)
# ('annotandum', '->', 'adnotandum', 3)
# ('annexi', '->', 'adnexi', 2)
# ('annexis', '->', 'adnexis', 2)
# ('annuntiabat', '->', 'adnuntiabat', 2)
# ('annuerit', '->', 'adnuerit', 2)
# ('annotata', '->', 'adnotata', 2)
# ('annumerare', '->', 'adnumerare', 2)
# ('annotabo', '->', 'adnotabo', 2)
# ('annuisset', '->', 'adnuisset', 2)
# ('annuimus', '->', 'adnuimus', 2)
# ('annexam', '->', 'adnexam', 1)
# ('annectunt', '->', 'adnectunt', 1)
# ('annectebat', '->', 'adnectebat', 1)
# ('annecti', '->', 'adnecti', 1)
# ('annuntio', '->', 'adnuntio', 1)
# ('anniti', '->', 'adniti', 1)
# ('annuntiat', '->', 'adnuntiat', 1)
# ('annuntians', '->', 'adnuntians', 1)
# ('annuntietur', '->', 'adnuntietur', 1)
# ('annuntiari', '->', 'adnuntiari', 1)
# ('annuntiatur', '->', 'adnuntiatur', 1)
# ('annitente', '->', 'adnitente', 1)
# ('annuntiandum', '->', 'adnuntiandum', 1)
# ('annectit', '->', 'adnectit', 1)
# ('annuite', '->', 'adnuite', 1)
# ('annectens', '->', 'adnectens', 1)
# ('annotauit', '->', 'adnotauit', 1)
# ('annotationibus', '->', 'adnotationibus', 1)
# ('annuunt', '->', 'adnuunt', 1)
# ('annuere', '->', 'adnuere', 1)
# ('annuerunt', '->', 'adnuerunt', 1)
# ('annuente', '->', 'adnuente', 1)
# ('annuet', '->', 'adnuet', 1)
# ('annexos', '->', 'adnexos', 1)
# ('annumerata', '->', 'adnumerata', 1)
# ('annuentibus', '->', 'adnuentibus', 1)
# ('annuisse', '->', 'adnuisse', 1)
# ('annare', '->', 'adnare', 1)
# ('annotationem', '->', 'adnotationem', 1)
# ('annuerant', '->', 'adnuerant', 1)
# ('annuerat', '->', 'adnuerat', 1)
# ('annuendi', '->', 'adnuendi', 1)
# ('annuerint', '->', 'adnuerint', 1)
# ('annumerauit', '->', 'adnumerauit', 1)
# # prefix examples: app- 6,918, adp- 1,966
# exact transform matches: 249
# ('adposita', '->', 'apposita', 70)
# ('adprehendit', '->', 'apprehendit', 52)
# ('adpropinquare', '->', 'appropinquare', 35)
# ('adpropinquauit', '->', 'appropinquauit', 33)
# ('adpositum', '->', 'appositum', 30)
# ('adprobare', '->', 'approbare', 29)
# ('adplicuit', '->', 'applicuit', 27)
# ('adprime', '->', 'apprime', 23)
# ('adposuit', '->', 'apposuit', 21)
# ('adpositus', '->', 'appositus', 20)
# ('adprobantibus', '->', 'approbantibus', 20)
# ('adpetebat', '->', 'appetebat', 20)
# ('adpetit', '->', 'appetit', 19)
# ('adpropinquaret', '->', 'appropinquaret', 19)
# ('adparet', '->', 'apparet', 19)
# ('adprehensa', '->', 'apprehensa', 19)
# ('adprehendens', '->', 'apprehendens', 18)
# ('adprehendi', '->', 'apprehendi', 17)
# ('adprobauit', '->', 'approbauit', 16)
# ('adpulsa', '->', 'appulsa', 16)
# ('adpulit', '->', 'appulit', 15)
# ('adpetens', '->', 'appetens', 15)
# ('adpetere', '->', 'appetere', 15)
# ('adpropinquante', '->', 'appropinquante', 14)
# ('adprehendere', '->', 'apprehendere', 14)
# ('adprobatio', '->', 'approbatio', 14)
# ('adpetitio', '->', 'appetitio', 14)
# ('adpositis', '->', 'appositis', 13)
# ('adprehensum', '->', 'apprehensum', 13)
# ('adpendit', '->', 'appendit', 13)
# ('adprehensis', '->', 'apprehensis', 12)
# ('adpropinquabat', '->', 'appropinquabat', 12)
# ('adpetitus', '->', 'appetitus', 12)
# ('adparuit', '->', 'apparuit', 12)
# ('adposito', '->', 'apposito', 12)
# ('adpositi', '->', 'appositi', 11)
# ('adparatum', '->', 'apparatum', 11)
# ('adpropinquat', '->', 'appropinquat', 10)
# ('adprobant', '->', 'approbant', 10)
# ('adpetunt', '->', 'appetunt', 10)
# ('adponitur', '->', 'apponitur', 10)
# ('adprobat', '->', 'approbat', 10)
# ('adprobatur', '->', 'approbatur', 10)
# ('adpropinquant', '->', 'appropinquant', 10)
# ('adpropinquantes', '->', 'appropinquantes', 9)
# ('adplicat', '->', 'applicat', 9)
# ('adprobata', '->', 'approbata', 9)
# ('adplicuerunt', '->', 'applicuerunt', 9)
# ('adpetentia', '->', 'appetentia', 8)
# ('adpropinquantem', '->', 'appropinquantem', 8)
# ('adpetisse', '->', 'appetisse', 8)
# ('adpropinquasset', '->', 'appropinquasset', 8)
# ('adprobationem', '->', 'approbationem', 8)
# ('adprehendentes', '->', 'apprehendentes', 8)
# ('adpetant', '->', 'appetant', 8)
# ('adpropinquans', '->', 'appropinquans', 8)
# ('adpetitur', '->', 'appetitur', 8)
# ('adprehende', '->', 'apprehende', 8)
# ('adponet', '->', 'apponet', 7)
# ('adplicauit', '->', 'applicauit', 7)
# ('adponatur', '->', 'apponatur', 7)
# ('adprobante', '->', 'approbante', 7)
# ('adparatu', '->', 'apparatu', 7)
# ('adpeteret', '->', 'appeteret', 7)
# ('adplicant', '->', 'applicant', 7)
# ('adparatus', '->', 'apparatus', 7)
# ('adpendi', '->', 'appendi', 7)
# ('adpetenda', '->', 'appetenda', 7)
# ('adprehendat', '->', 'apprehendat', 7)
# ('adpropinquabant', '->', 'appropinquabant', 6)
# ('adprehenso', '->', 'apprehenso', 6)
# ('adpulsu', '->', 'appulsu', 6)
# ('adpetitum', '->', 'appetitum', 6)
# ('adpetendum', '->', 'appetendum', 6)
# ('adplicata', '->', 'applicata', 6)
# ('adprobatum', '->', 'approbatum', 6)
# ('adpo', '->', 'appo', 6)
# ('adponi', '->', 'apponi', 6)
# ('adpulsae', '->', 'appulsae', 6)
# ('adprobet', '->', 'approbet', 5)
# ('adpetis', '->', 'appetis', 5)
# ('adpropinquantibus', '->', 'appropinquantibus', 5)
# ('adprobo', '->', 'approbo', 5)
# ('adprobauisset', '->', 'approbauisset', 5)
# ('adpropinquet', '->', 'appropinquet', 5)
# ('adprobari', '->', 'approbari', 5)
# ('adpulsus', '->', 'appulsus', 5)
# ('adponit', '->', 'apponit', 5)
# ('adprobent', '->', 'approbent', 5)
# ('adportet', '->', 'apportet', 5)
# ('adpositam', '->', 'appositam', 5)
# ('adplicari', '->', 'applicari', 5)
# ('adposui', '->', 'apposui', 5)
# ('adparere', '->', 'apparere', 5)
# ('adplica', '->', 'applica', 5)
# ('adprendere', '->', 'apprendere', 5)
# ('adponere', '->', 'apponere', 4)
# ('adpetiit', '->', 'appetiit', 4)
# ('adpropinquassent', '->', 'appropinquassent', 4)
# ('adpropinquarent', '->', 'appropinquarent', 4)
# ('adpetentis', '->', 'appetentis', 4)
# ('adpetentem', '->', 'appetentem', 4)
# ('adpetitiones', '->', 'appetitiones', 4)
# ('adpetimus', '->', 'appetimus', 4)
# ('adpareat', '->', 'appareat', 4)
# ('adpetat', '->', 'appetat', 4)
# ('adparent', '->', 'apparent', 4)
# ('adpareret', '->', 'appareret', 4)
# ('adplicet', '->', 'applicet', 4)
# ('adprobabo', '->', 'approbabo', 4)
# ('adporto', '->', 'apporto', 4)
# ('adprehenderint', '->', 'apprehenderint', 4)
# ('adponuntur', '->', 'apponuntur', 4)
# ('adpetendo', '->', 'appetendo', 4)
# ('adpetentes', '->', 'appetentes', 4)
# ('adpulsis', '->', 'appulsis', 3)
# ('adpetiuerunt', '->', 'appetiuerunt', 3)
# ('adparat', '->', 'apparat', 3)
# ('adprobas', '->', 'approbas', 3)
# ('adpropinquantis', '->', 'appropinquantis', 3)
# ('adparuisse', '->', 'apparuisse', 3)
# ('adparebat', '->', 'apparebat', 3)
# ('adpellere', '->', 'appellere', 3)
# ('adpetebant', '->', 'appetebant', 3)
# ('adplicatur', '->', 'applicatur', 3)
# ('adpetistis', '->', 'appetistis', 3)
# ('adpetita', '->', 'appetita', 3)
# ('adpulsam', '->', 'appulsam', 3)
# ('adprehenditur', '->', 'apprehenditur', 3)
# ('adpendebat', '->', 'appendebat', 3)
# ('adponam', '->', 'apponam', 3)
# ('adpropinquanti', '->', 'appropinquanti', 3)
# ('adprehensi', '->', 'apprehensi', 3)
# ('adplicarent', '->', 'applicarent', 3)
# ('adportari', '->', 'apportari', 3)
# ('adportas', '->', 'apportas', 3)
# ('adparari', '->', 'apparari', 3)
# ('adpeti', '->', 'appeti', 3)
# ('adpetiui', '->', 'appetiui', 2)
# ('adponerentur', '->', 'apponerentur', 2)
# ('adplicatis', '->', 'applicatis', 2)
# ('adprobauerunt', '->', 'approbauerunt', 2)
# ('adpetitu', '->', 'appetitu', 2)
# ('adprobato', '->', 'approbato', 2)
# ('adpetitionem', '->', 'appetitionem', 2)
# ('adpetiuit', '->', 'appetiuit', 2)
# ('adposite', '->', 'apposite', 2)
# ('adpetuntur', '->', 'appetuntur', 2)
# ('adpellitur', '->', 'appellitur', 2)
# ('adpulsi', '->', 'appulsi', 2)
# ('adponite', '->', 'apponite', 2)
# ('adpetisset', '->', 'appetisset', 2)
# ('adpetente', '->', 'appetente', 2)
# ('adpetas', '->', 'appetas', 2)
# ('adplicauerunt', '->', 'applicauerunt', 2)
# ('adprobarent', '->', 'approbarent', 2)
# ('adpetebatur', '->', 'appetebatur', 2)
# ('adpetiti', '->', 'appetiti', 2)
# ('adplicatos', '->', 'applicatos', 2)
# ('adplicantes', '->', 'applicantes', 2)
# ('adplicabat', '->', 'applicabat', 2)
# ('adpelle', '->', 'appelle', 2)
# ('adpulerit', '->', 'appulerit', 2)
# ('adpendere', '->', 'appendere', 2)
# ('adponunt', '->', 'apponunt', 2)
# ('adponat', '->', 'apponat', 2)
# ('adplicitum', '->', 'applicitum', 2)
# ('adpropians', '->', 'appropians', 2)
# ('adprehendisset', '->', 'apprehendisset', 2)
# ('adprobantium', '->', 'approbantium', 2)
# ('adplicando', '->', 'applicando', 2)
# ('adplicantur', '->', 'applicantur', 2)
# ('adplicare', '->', 'applicare', 2)
# ('adpetendi', '->', 'appetendi', 2)
# ('adprobaret', '->', 'approbaret', 2)
# ('adpellatur', '->', 'appellatur', 1)
# ('adpeto', '->', 'appeto', 1)
# ('adpropinquatio', '->', 'appropinquatio', 1)
# ('adprobationes', '->', 'approbationes', 1)
# ('adpetendos', '->', 'appetendos', 1)
# ('adpositos', '->', 'appositos', 1)
# ('adponebat', '->', 'apponebat', 1)
# ('adportata', '->', 'apportata', 1)
# ('adparabantur', '->', 'apparabantur', 1)
# ('adplicaui', '->', 'applicaui', 1)
# ('adportaui', '->', 'apportaui', 1)
# ('adprobaris', '->', 'approbaris', 1)
# ('adportans', '->', 'apportans', 1)
# ('adpulerat', '->', 'appulerat', 1)
# ('adprobasset', '->', 'approbasset', 1)
# ('adpellunt', '->', 'appellunt', 1)
# ('adpetentissimus', '->', 'appetentissimus', 1)
# ('adpetieris', '->', 'appetieris', 1)
# ('adprendas', '->', 'apprendas', 1)
# ('adprobe', '->', 'approbe', 1)
# ('adposuisse', '->', 'apposuisse', 1)
# ('adplaudente', '->', 'applaudente', 1)
# ('adpete', '->', 'appete', 1)
# ('adprobetur', '->', 'approbetur', 1)
# ('adpetitis', '->', 'appetitis', 1)
# ('adplicabimus', '->', 'applicabimus', 1)
# ('adpropinquatis', '->', 'appropinquatis', 1)
# ('adplicabuntur', '->', 'applicabuntur', 1)
# ('adparitores', '->', 'apparitores', 1)
# ('adpendicibus', '->', 'appendicibus', 1)
# ('adpulisset', '->', 'appulisset', 1)
# ('adprobando', '->', 'approbando', 1)
# ('adparando', '->', 'apparando', 1)
# ('adparata', '->', 'apparata', 1)
# ('adplicaret', '->', 'applicaret', 1)
# ('adpulisti', '->', 'appulisti', 1)
# ('adplicuisse', '->', 'applicuisse', 1)
# ('adpetibiles', '->', 'appetibiles', 1)
# ('adpetet', '->', 'appetet', 1)
# ('adpellem', '->', 'appellem', 1)
# ('adpellandorum', '->', 'appellandorum', 1)
# ('adparentia', '->', 'apparentia', 1)
# ('adpellare', '->', 'appellare', 1)
# ('adpellabo', '->', 'appellabo', 1)
# ('adportatis', '->', 'apportatis', 1)
# ('adparebit', '->', 'apparebit', 1)
# ('adplicent', '->', 'applicent', 1)
# ('adprobantur', '->', 'approbantur', 1)
# ('adpetentius', '->', 'appetentius', 1)
# ('adprehenderat', '->', 'apprehenderat', 1)
# ('adparuisset', '->', 'apparuisset', 1)
# ('adplicati', '->', 'applicati', 1)
# ('adplicentur', '->', 'applicentur', 1)
# ('adpelli', '->', 'appelli', 1)
# ('adponeret', '->', 'apponeret', 1)
# ('adplicitae', '->', 'applicitae', 1)
# ('adpetitam', '->', 'appetitam', 1)
# ('adplicetur', '->', 'applicetur', 1)
# ('adprobaui', '->', 'approbaui', 1)
# ('adplices', '->', 'applices', 1)
# ('adpetitionis', '->', 'appetitionis', 1)
# ('adpetes', '->', 'appetes', 1)
# ('adproperemus', '->', 'approperemus', 1)
# ('adplaudit', '->', 'applaudit', 1)
# ('adpeterent', '->', 'appeterent', 1)
# ('adprobatis', '->', 'approbatis', 1)
# ('adpulerant', '->', 'appulerant', 1)
# ('adpelluntur', '->', 'appelluntur', 1)
# ('adparentes', '->', 'apparentes', 1)
# ('adprehenduntur', '->', 'apprehenduntur', 1)
# ('adproperat', '->', 'approperat', 1)
# ('adplicatum', '->', 'applicatum', 1)
# ('adprehendendo', '->', 'apprehendendo', 1)
# ('adpellasset', '->', 'appellasset', 1)
# # prefix examples: arr- 535, adr- 305
# exact transform matches: 49
# ('adrogantia', '->', 'arrogantia', 26)
# ('adrogantiam', '->', 'arrogantiam', 24)
# ('adrogans', '->', 'arrogans', 19)
# ('adridens', '->', 'arridens', 18)
# ('adrogantiae', '->', 'arrogantiae', 11)
# ('adroganter', '->', 'arroganter', 11)
# ('adrepto', '->', 'arrepto', 8)
# ('adrogantius', '->', 'arrogantius', 6)
# ('adripuit', '->', 'arripuit', 6)
# ('adridet', '->', 'arridet', 6)
# ('adripere', '->', 'arripere', 5)
# ('adrectis', '->', 'arrectis', 5)
# ('adrogare', '->', 'arrogare', 4)
# ('adrogantis', '->', 'arrogantis', 4)
# ('adrisit', '->', 'arrisit', 4)
# ('adrogo', '->', 'arrogo', 4)
# ('adroganti', '->', 'arroganti', 4)
# ('adridere', '->', 'arridere', 4)
# ('adripiunt', '->', 'arripiunt', 3)
# ('adrogantes', '->', 'arrogantes', 3)
# ('adrogantem', '->', 'arrogantem', 3)
# ('adripit', '->', 'arripit', 3)
# ('adrexit', '->', 'arrexit', 3)
# ('adrectae', '->', 'arrectae', 3)
# ('adroget', '->', 'arroget', 2)
# ('adrectus', '->', 'arrectus', 2)
# ('adrectos', '->', 'arrectos', 2)
# ('adrepit', '->', 'arrepit', 2)
# ('adridebat', '->', 'arridebat', 1)
# ('adripi', '->', 'arripi', 1)
# ('adripitur', '->', 'arripitur', 1)
# ('adrogauerunt', '->', 'arrogauerunt', 1)
# ('adrogantium', '->', 'arrogantium', 1)
# ('adripui', '->', 'arripui', 1)
# ('adreptus', '->', 'arreptus', 1)
# ('adripuimus', '->', 'arripuimus', 1)
# ('adrepti', '->', 'arrepti', 1)
# ('adripis', '->', 'arripis', 1)
# ('adrepta', '->', 'arrepta', 1)
# ('adrogatio', '->', 'arrogatio', 1)
# ('adripiens', '->', 'arripiens', 1)
# ('adriserit', '->', 'arriserit', 1)
# ('adrepens', '->', 'arrepens', 1)
# ('adripe', '->', 'arripe', 1)
# ('adrigere', '->', 'arrigere', 1)
# ('adrexerat', '->', 'arrexerat', 1)
# ('adrogantibus', '->', 'arrogantibus', 1)
# ('adriperet', '->', 'arriperet', 1)
# ('adrectas', '->', 'arrectas', 1)
# # prefix examples: ass- 1,452, ads- 5,336
# exact transform matches: 274
# ('adsit', '->', 'assit', 126)
# ('adsequi', '->', 'assequi', 119)
# ('adsentior', '->', 'assentior', 92)
# ('adsensu', '->', 'assensu', 72)
# ('adsumere', '->', 'assumere', 65)
# ('adsidua', '->', 'assidua', 65)
# ('adsiduo', '->', 'assiduo', 63)
# ('adsecutus', '->', 'assecutus', 58)
# ('adsiduis', '->', 'assiduis', 55)
# ('adsumpsit', '->', 'assumpsit', 51)
# ('adsum', '->', 'assum', 47)
# ('adsumpta', '->', 'assumpta', 42)
# ('adsensus', '->', 'assensus', 41)
# ('adsiduus', '->', 'assiduus', 40)
# ('adsumptis', '->', 'assumptis', 39)
# ('adsueti', '->', 'assueti', 36)
# ('adsequitur', '->', 'assequitur', 33)
# ('adsueta', '->', 'assueta', 33)
# ('adsuetum', '->', 'assuetum', 32)
# ('adsint', '->', 'assint', 30)
# ('adsumitur', '->', 'assumitur', 29)
# ('adsumptio', '->', 'assumptio', 28)
# ('adsumens', '->', 'assumens', 28)
# ('adsurgens', '->', 'assurgens', 27)
# ('adsumpto', '->', 'assumpto', 27)
# ('adsensum', '->', 'assensum', 26)
# ('adserunt', '->', 'asserunt', 26)
# ('adsiduitate', '->', 'assiduitate', 25)
# ('adsecuti', '->', 'assecuti', 25)
# ('adserere', '->', 'asserere', 25)
# ('adsensio', '->', 'assensio', 24)
# ('adserit', '->', 'asserit', 23)
# ('adsignat', '->', 'assignat', 23)
# ('adsuetus', '->', 'assuetus', 23)
# ('adserens', '->', 'asserens', 23)
# ('adsumptus', '->', 'assumptus', 22)
# ('adsuetis', '->', 'assuetis', 22)
# ('adsistens', '->', 'assistens', 21)
# ('adsurgit', '->', 'assurgit', 21)
# ('adsciuit', '->', 'assciuit', 20)
# ('adsolet', '->', 'assolet', 20)
# ('adsumptum', '->', 'assumptum', 20)
# ('adsumit', '->', 'assumit', 20)
# ('adsis', '->', 'assis', 20)
# ('adscitus', '->', 'asscitus', 19)
# ('adsidere', '->', 'assidere', 19)
# ('adsertor', '->', 'assertor', 19)
# ('adsentiar', '->', 'assentiar', 19)
# ('adsentiri', '->', 'assentiri', 19)
# ('adsurgere', '->', 'assurgere', 18)
# ('adsedit', '->', 'assedit', 18)
# ('adsueuit', '->', 'assueuit', 17)
# ('adsensi', '->', 'assensi', 17)
# ('adsuetos', '->', 'assuetos', 17)
# ('adsuetas', '->', 'assuetas', 16)
# ('adsistere', '->', 'assistere', 15)
# ('adseruari', '->', 'asseruari', 15)
# ('adseuerat', '->', 'asseuerat', 15)
# ('adsiduitas', '->', 'assiduitas', 15)
# ('adsignant', '->', 'assignant', 15)
# ('adsignauit', '->', 'assignauit', 14)
# ('adsueto', '->', 'assueto', 14)
# ('adsiduum', '->', 'assiduum', 14)
# ('adsignare', '->', 'assignare', 14)
# ('adsiduos', '->', 'assiduos', 13)
# ('adsumet', '->', 'assumet', 13)
# ('adsidet', '->', 'assidet', 13)
# ('adseueratio', '->', 'asseueratio', 13)
# ('adscita', '->', 'asscita', 12)
# ('adsignata', '->', 'assignata', 12)
# ('adsiduae', '->', 'assiduae', 12)
# ('adsignari', '->', 'assignari', 12)
# ('adseuerauit', '->', 'asseuerauit', 11)
# ('adserat', '->', 'asserat', 11)
# ('adsertio', '->', 'assertio', 11)
# ('adsumi', '->', 'assumi', 11)
# ('adsumus', '->', 'assumus', 11)
# ('adsistit', '->', 'assistit', 11)
# ('adseruit', '->', 'asseruit', 11)
# ('adsuetae', '->', 'assuetae', 11)
# ('adsentatio', '->', 'assentatio', 10)
# ('adsidens', '->', 'assidens', 10)
# ('adsuerat', '->', 'assuerat', 10)
# ('adsensionem', '->', 'assensionem', 10)
# ('adsideret', '->', 'assideret', 10)
# ('adsignatur', '->', 'assignatur', 10)
# ('adseuerabat', '->', 'asseuerabat', 9)
# ('adsumuntur', '->', 'assumuntur', 9)
# ('adsumeret', '->', 'assumeret', 9)
# ('adsumptionem', '->', 'assumptionem', 9)
# ('adsentiuntur', '->', 'assentiuntur', 9)
# ('adsueui', '->', 'assueui', 9)
# ('adsume', '->', 'assume', 9)
# ('adsimulata', '->', 'assimulata', 9)
# ('adsiduitatem', '->', 'assiduitatem', 8)
# ('adsuescere', '->', 'assuescere', 8)
# ('adsensiones', '->', 'assensiones', 8)
# ('adsimulare', '->', 'assimulare', 8)
# ('adsectator', '->', 'assectator', 8)
# ('adsiduam', '->', 'assiduam', 8)
# ('adsuescat', '->', 'assuescat', 8)
# ('adsistunt', '->', 'assistunt', 8)
# ('adsumes', '->', 'assumes', 8)
# ('adscito', '->', 'asscito', 7)
# ('adseruare', '->', 'asseruare', 7)
# ('adsumas', '->', 'assumas', 7)
# ('adsurgunt', '->', 'assurgunt', 7)
# ('adsumimus', '->', 'assumimus', 7)
# ('adsiduas', '->', 'assiduas', 7)
# ('adsentiente', '->', 'assentiente', 7)
# ('adseuerant', '->', 'asseuerant', 7)
# ('adsumo', '->', 'assumo', 7)
# ('adsignatum', '->', 'assignatum', 7)
# ('adsurgentem', '->', 'assurgentem', 7)
# ('adsistebant', '->', 'assistebant', 7)
# ('adscitum', '->', 'asscitum', 6)
# ('adsere', '->', 'assere', 6)
# ('adsero', '->', 'assero', 6)
# ('adsidebat', '->', 'assidebat', 6)
# ('adsumpsisse', '->', 'assumpsisse', 6)
# ('adsentari', '->', 'assentari', 6)
# ('adsentiatur', '->', 'assentiatur', 6)
# ('adsecutum', '->', 'assecutum', 6)
# ('adsuetam', '->', 'assuetam', 6)
# ('adsuefactus', '->', 'assuefactus', 6)
# ('adseuerare', '->', 'asseuerare', 6)
# ('adsidui', '->', 'assidui', 6)
# ('adsurgentes', '->', 'assurgentes', 6)
# ('adsuesceret', '->', 'assuesceret', 6)
# ('adsurgat', '->', 'assurgat', 6)
# ('adsumite', '->', 'assumite', 6)
# ('adsereret', '->', 'assereret', 5)
# ('adsimilis', '->', 'assimilis', 5)
# ('adsolent', '->', 'assolent', 5)
# ('adsident', '->', 'assident', 5)
# ('adsurgeret', '->', 'assurgeret', 5)
# ('adsequuntur', '->', 'assequuntur', 5)
# ('adsequamur', '->', 'assequamur', 5)
# ('adsumptionis', '->', 'assumptionis', 5)
# ('adsentator', '->', 'assentator', 5)
# ('adsequebatur', '->', 'assequebatur', 5)
# ('adsentatores', '->', 'assentatores', 5)
# ('adsiduitatis', '->', 'assiduitatis', 5)
# ('adsistentes', '->', 'assistentes', 5)
# ('adsecuta', '->', 'assecuta', 5)
# ('adsensere', '->', 'assensere', 5)
# ('adsiste', '->', 'assiste', 5)
# ('adsistebat', '->', 'assistebat', 4)
# ('adsuefacti', '->', 'assuefacti', 4)
# ('adsumendus', '->', 'assumendus', 4)
# ('adsensionibus', '->', 'assensionibus', 4)
# ('adsentationem', '->', 'assentationem', 4)
# ('adsumpsi', '->', 'assumpsi', 4)
# ('adsequeris', '->', 'assequeris', 4)
# ('adsensit', '->', 'assensit', 4)
# ('adsensurum', '->', 'assensurum', 4)
# ('adsuesce', '->', 'assuesce', 4)
# ('adsiliunt', '->', 'assiliunt', 4)
# ('adsentiebatur', '->', 'assentiebatur', 4)
# ('adserebant', '->', 'asserebant', 4)
# ('adserentes', '->', 'asserentes', 4)
# ('adseris', '->', 'asseris', 4)
# ('adsidentem', '->', 'assidentem', 4)
# ('adsertorem', '->', 'assertorem', 4)
# ('adsuescerent', '->', 'assuescerent', 4)
# ('adsignaret', '->', 'assignaret', 4)
# ('adsentando', '->', 'assentando', 4)
# ('adsimulabo', '->', 'assimulabo', 4)
# ('adsidente', '->', 'assidente', 4)
# ('adsueuerunt', '->', 'assueuerunt', 4)
# ('adsultu', '->', 'assultu', 3)
# ('adsurrexisse', '->', 'assurrexisse', 3)
# ('adsequentur', '->', 'assequentur', 3)
# ('adsistant', '->', 'assistant', 3)
# ('adsentire', '->', 'assentire', 3)
# ('adsidentes', '->', 'assidentes', 3)
# ('adsumenda', '->', 'assumenda', 3)
# ('adsignentur', '->', 'assignentur', 3)
# ('adsequemur', '->', 'assequemur', 3)
# ('adsentandi', '->', 'assentandi', 3)
# ('adsentientibus', '->', 'assentientibus', 3)
# ('adsurrexit', '->', 'assurrexit', 3)
# ('adsignarent', '->', 'assignarent', 3)
# ('adsignandum', '->', 'assignandum', 3)
# ('adsecula', '->', 'assecula', 3)
# ('adsentantium', '->', 'assentantium', 3)
# ('adsumis', '->', 'assumis', 3)
# ('adsertionibus', '->', 'assertionibus', 3)
# ('adsecuturum', '->', 'assecuturum', 3)
# ('adsuerant', '->', 'assuerant', 3)
# ('adsertionem', '->', 'assertionem', 3)
# ('adserto', '->', 'asserto', 3)
# ('adsistentibus', '->', 'assistentibus', 3)
# ('adsedi', '->', 'assedi', 3)
# ('adserua', '->', 'asserua', 3)
# ('adseuerante', '->', 'asseuerante', 2)
# ('adsignabat', '->', 'assignabat', 2)
# ('adsimularet', '->', 'assimularet', 2)
# ('adsentiamur', '->', 'assentiamur', 2)
# ('adsensionis', '->', 'assensionis', 2)
# ('adsumptiua', '->', 'assumptiua', 2)
# ('adsentatorem', '->', 'assentatorem', 2)
# ('adsignato', '->', 'assignato', 2)
# ('adsectatoribus', '->', 'assectatoribus', 2)
# ('adsidenti', '->', 'assidenti', 2)
# ('adsi', '->', 'assi', 2)
# ('adsedisse', '->', 'assedisse', 2)
# ('adserente', '->', 'asserente', 2)
# ('adseritis', '->', 'asseritis', 2)
# ('adsides', '->', 'assides', 2)
# ('adsistam', '->', 'assistam', 2)
# ('adsidentium', '->', 'assidentium', 2)
# ('adsumeretur', '->', 'assumeretur', 2)
# ('adsignantur', '->', 'assignantur', 2)
# ('adserta', '->', 'asserta', 2)
# ('adsertores', '->', 'assertores', 2)
# ('adsonat', '->', 'assonat', 2)
# ('adsimulabat', '->', 'assimulabat', 2)
# ('adsimulato', '->', 'assimulato', 2)
# ('adsimulo', '->', 'assimulo', 2)
# ('adsedisset', '->', 'assedisset', 2)
# ('adsuefaciunt', '->', 'assuefaciunt', 2)
# ('adserenda', '->', 'asserenda', 2)
# ('adseuerantium', '->', 'asseuerantium', 2)
# ('adsultibus', '->', 'assultibus', 2)
# ('adseuerantes', '->', 'asseuerantes', 1)
# ('adseuerate', '->', 'asseuerate', 1)
# ('ads', '->', 'ass', 1)
# ('adsidue', '->', 'assidue', 1)
# ('adsignetur', '->', 'assignetur', 1)
# ('adsensurus', '->', 'assensurus', 1)
# ('adsequebantur', '->', 'assequebantur', 1)
# ('adsentatoribus', '->', 'assentatoribus', 1)
# ('adseuerantem', '->', 'asseuerantem', 1)
# ('adsuefaceret', '->', 'assuefaceret', 1)
# ('adsciscit', '->', 'assciscit', 1)
# ('adseueraret', '->', 'asseueraret', 1)
# ('adsuetudo', '->', 'assuetudo', 1)
# ('adsciscet', '->', 'assciscet', 1)
# ('adserebat', '->', 'asserebat', 1)
# ('adsutas', '->', 'assutas', 1)
# ('adsumatur', '->', 'assumatur', 1)
# ('adsuefacta', '->', 'assuefacta', 1)
# ('adsurrectum', '->', 'assurrectum', 1)
# ('adsient', '->', 'assient', 1)
# ('adsignabatur', '->', 'assignabatur', 1)
# ('adserant', '->', 'asserant', 1)
# ('adserui', '->', 'asserui', 1)
# ('adsideo', '->', 'assideo', 1)
# ('adsilientis', '->', 'assilientis', 1)
# ('adsidam', '->', 'assidam', 1)
# ('adsimulet', '->', 'assimulet', 1)
# ('adseres', '->', 'asseres', 1)
# ('adsidite', '->', 'assidite', 1)
# ('adseruntur', '->', 'asseruntur', 1)
# ('adsurgi', '->', 'assurgi', 1)
# ('adsultus', '->', 'assultus', 1)
# ('adsuescent', '->', 'assuescent', 1)
# ('adsessores', '->', 'assessores', 1)
# ('adsigno', '->', 'assigno', 1)
# ('adsuescas', '->', 'assuescas', 1)
# ('adside', '->', 'asside', 1)
# ('adsentimur', '->', 'assentimur', 1)
# ('adsentatorum', '->', 'assentatorum', 1)
# ('adsurrexerunt', '->', 'assurrexerunt', 1)
# ('adsiliens', '->', 'assiliens', 1)
# ('adseuerabant', '->', 'asseuerabant', 1)
# ('adseuerans', '->', 'asseuerans', 1)
# ('adsistendi', '->', 'assistendi', 1)
# ('adsumitis', '->', 'assumitis', 1)
# ('adsistentium', '->', 'assistentium', 1)
# ('adsignantes', '->', 'assignantes', 1)
# ('adsignatam', '->', 'assignatam', 1)
# ('adsuescant', '->', 'assuescant', 1)
# # prefix examples: adst- 503, asstan- 0
# exact transform matches: 0
# # prefix examples: att- 3,163, adt- 775
# exact transform matches: 173
# ('adtende', '->', 'attende', 43)
# ('adtulit', '->', 'attulit', 42)
# ('adtendite', '->', 'attendite', 29)
# ('adtulerunt', '->', 'attulerunt', 23)
# ('adtinet', '->', 'attinet', 20)
# ('adtribuit', '->', 'attribuit', 15)
# ('adtributa', '->', 'attributa', 15)
# ('adtollere', '->', 'attollere', 14)
# ('adtulerat', '->', 'attulerat', 14)
# ('adtingere', '->', 'attingere', 14)
# ('adtendere', '->', 'attendere', 13)
# ('adtrita', '->', 'attrita', 11)
# ('adtributae', '->', 'attributae', 9)
# ('adtritis', '->', 'attritis', 9)
# ('adtrahere', '->', 'attrahere', 7)
# ('adtendit', '->', 'attendit', 7)
# ('adtingit', '->', 'attingit', 6)
# ('adtonitus', '->', 'attonitus', 6)
# ('adtendat', '->', 'attendat', 6)
# ('adtrectare', '->', 'attrectare', 6)
# ('adtuli', '->', 'attuli', 6)
# ('adtenuatus', '->', 'attenuatus', 6)
# ('adtoniti', '->', 'attoniti', 6)
# ('adtingat', '->', 'attingat', 6)
# ('adtendis', '->', 'attendis', 5)
# ('adtritu', '->', 'attritu', 5)
# ('adtollens', '->', 'attollens', 5)
# ('adtulisse', '->', 'attulisse', 5)
# ('adtributum', '->', 'attributum', 5)
# ('adtributas', '->', 'attributas', 5)
# ('adtulissent', '->', 'attulissent', 5)
# ('adtentius', '->', 'attentius', 5)
# ('adtonitos', '->', 'attonitos', 5)
# ('adtingam', '->', 'attingam', 4)
# ('adtollite', '->', 'attollite', 4)
# ('adtenuata', '->', 'attenuata', 4)
# ('adtribui', '->', 'attribui', 4)
# ('adtributi', '->', 'attributi', 4)
# ('adtigerit', '->', 'attigerit', 4)
# ('adtonita', '->', 'attonita', 4)
# ('adtriuit', '->', 'attriuit', 4)
# ('adtriuerat', '->', 'attriuerat', 4)
# ('adtulisset', '->', 'attulisset', 4)
# ('adtraxit', '->', 'attraxit', 4)
# ('adtendentes', '->', 'attendentes', 4)
# ('adtritus', '->', 'attritus', 4)
# ('adtollat', '->', 'attollat', 4)
# ('adtrectat', '->', 'attrectat', 3)
# ('adtrahitur', '->', 'attrahitur', 3)
# ('adtrahit', '->', 'attrahit', 3)
# ('adtente', '->', 'attente', 3)
# ('adtendendum', '->', 'attendendum', 3)
# ('adtinere', '->', 'attinere', 3)
# ('adtriti', '->', 'attriti', 3)
# ('adtingimus', '->', 'attingimus', 3)
# ('adtendens', '->', 'attendens', 3)
# ('adtrahi', '->', 'attrahi', 3)
# ('adtulerant', '->', 'attulerant', 3)
# ('adtenderis', '->', 'attenderis', 3)
# ('adtendas', '->', 'attendas', 3)
# ('adtendi', '->', 'attendi', 3)
# ('adtinebat', '->', 'attinebat', 3)
# ('adtonitam', '->', 'attonitam', 3)
# ('adtolli', '->', 'attolli', 2)
# ('adtolleret', '->', 'attolleret', 2)
# ('adtribuere', '->', 'attribuere', 2)
# ('adtenderet', '->', 'attenderet', 2)
# ('adtactus', '->', 'attactus', 2)
# ('adtribuerat', '->', 'attribuerat', 2)
# ('adtingi', '->', 'attingi', 2)
# ('adtendunt', '->', 'attendunt', 2)
# ('adtritum', '->', 'attritum', 2)
# ('adtrahatur', '->', 'attrahatur', 2)
# ('adtulimus', '->', 'attulimus', 2)
# ('adtributionibus', '->', 'attributionibus', 2)
# ('adtigi', '->', 'attigi', 2)
# ('adtigit', '->', 'attigit', 2)
# ('adtulerit', '->', 'attulerit', 2)
# ('adtollitur', '->', 'attollitur', 2)
# ('adtenuatae', '->', 'attenuatae', 2)
# ('adtrito', '->', 'attrito', 2)
# ('adtendamus', '->', 'attendamus', 2)
# ('adtenuari', '->', 'attenuari', 2)
# ('adtrahunt', '->', 'attrahunt', 2)
# ('adtraxi', '->', 'attraxi', 2)
# ('adtingas', '->', 'attingas', 2)
# ('adtentiore', '->', 'attentiore', 2)
# ('adtenti', '->', 'attenti', 2)
# ('adtingerent', '->', 'attingerent', 2)
# ('adterere', '->', 'atterere', 2)
# ('adtineat', '->', 'attineat', 2)
# ('adtingunt', '->', 'attingunt', 2)
# ('adtingant', '->', 'attingant', 2)
# ('adtribuunt', '->', 'attribuunt', 2)
# ('adtollunt', '->', 'attollunt', 2)
# ('adtulere', '->', 'attulere', 2)
# ('adteri', '->', 'atteri', 2)
# ('adtritas', '->', 'attritas', 2)
# ('adtemptare', '->', 'attemptare', 2)
# ('adtritae', '->', 'attritae', 2)
# ('adtulisti', '->', 'attulisti', 2)
# ('adtrahas', '->', 'attrahas', 2)
# ('adtenta', '->', 'attenta', 2)
# ('adtonitas', '->', 'attonitas', 2)
# ('adtinuit', '->', 'attinuit', 2)
# ('adtendo', '->', 'attendo', 1)
# ('adtentus', '->', 'attentus', 1)
# ('adtento', '->', 'attento', 1)
# ('adtollis', '->', 'attollis', 1)
# ('adtestatio', '->', 'attestatio', 1)
# ('adtacti', '->', 'attacti', 1)
# ('adtenditur', '->', 'attenditur', 1)
# ('adtestari', '->', 'attestari', 1)
# ('adtrahendus', '->', 'attrahendus', 1)
# ('adtollendus', '->', 'attollendus', 1)
# ('adtributam', '->', 'attributam', 1)
# ('adtinuerit', '->', 'attinuerit', 1)
# ('adtinuisse', '->', 'attinuisse', 1)
# ('adtonitum', '->', 'attonitum', 1)
# ('adtrectari', '->', 'attrectari', 1)
# ('adtriuere', '->', 'attriuere', 1)
# ('adtribuerent', '->', 'attribuerent', 1)
# ('adtingens', '->', 'attingens', 1)
# ('adtentior', '->', 'attentior', 1)
# ('adtigerunt', '->', 'attigerunt', 1)
# ('adtondens', '->', 'attondens', 1)
# ('adtingendum', '->', 'attingendum', 1)
# ('adtigimus', '->', 'attigimus', 1)
# ('adtenuetur', '->', 'attenuetur', 1)
# ('adtraxerit', '->', 'attraxerit', 1)
# ('adtendam', '->', 'attendam', 1)
# ('adtrahe', '->', 'attrahe', 1)
# ('adtonitis', '->', 'attonitis', 1)
# ('adtentio', '->', 'attentio', 1)
# ('adtingebat', '->', 'attingebat', 1)
# ('adtendant', '->', 'attendant', 1)
# ('adtendatis', '->', 'attendatis', 1)
# ('adtracta', '->', 'attracta', 1)
# ('adtondent', '->', 'attondent', 1)
# ('adtuleritis', '->', 'attuleritis', 1)
# ('adtineret', '->', 'attineret', 1)
# ('adtribuerentur', '->', 'attribuerentur', 1)
# ('adtonito', '->', 'attonito', 1)
# ('adtonsis', '->', 'attonsis', 1)
# ('adtribuas', '->', 'attribuas', 1)
# ('adtribuatur', '->', 'attribuatur', 1)
# ('adtractus', '->', 'attractus', 1)
# ('adtactu', '->', 'attactu', 1)
# ('adtigeris', '->', 'attigeris', 1)
# ('adtines', '->', 'attines', 1)
# ('adtribuuntur', '->', 'attribuuntur', 1)
# ('adtritos', '->', 'attritos', 1)
# ('adtribuant', '->', 'attribuant', 1)
# ('adtollente', '->', 'attollente', 1)
# ('adtollentes', '->', 'attollentes', 1)
# ('adtollentem', '->', 'attollentem', 1)
# ('adtollentia', '->', 'attollentia', 1)
# ('adtigerint', '->', 'attigerint', 1)
# ('adtollenda', '->', 'attollenda', 1)
# ('adtriuerant', '->', 'attriuerant', 1)
# ('adtritio', '->', 'attritio', 1)
# ('adtuleram', '->', 'attuleram', 1)
# ('adtigeram', '->', 'attigeram', 1)
# ('adtollant', '->', 'attollant', 1)
# ('adtollet', '->', 'attollet', 1)
# ('adtuleris', '->', 'attuleris', 1)
# ('adtendentem', '->', 'attendentem', 1)
# ('adtrahat', '->', 'attrahat', 1)
# ('adtolle', '->', 'attolle', 1)
# ('adtractum', '->', 'attractum', 1)
# ('adtinent', '->', 'attinent', 1)
# ('adtentissima', '->', 'attentissima', 1)
# ('adtingendus', '->', 'attingendus', 1)
# # prefix examples: afu- 180, affu- 67
# exact transform matches: 14
# ('affuit', '->', 'afuit', 15)
# ('affuisset', '->', 'afuisset', 4)
# ('affuturum', '->', 'afuturum', 3)
# ('affui', '->', 'afui', 3)
# ('affuerit', '->', 'afuerit', 2)
# ('affuturus', '->', 'afuturus', 2)
# ('affuturam', '->', 'afuturam', 2)
# ('affuisses', '->', 'afuisses', 2)
# ('affuisti', '->', 'afuisti', 1)
# ('affuerant', '->', 'afuerant', 1)
# ('affueram', '->', 'afueram', 1)
# ('affueris', '->', 'afueris', 1)
# ('affuisse', '->', 'afuisse', 1)
# ('affuerunt', '->', 'afuerunt', 1)
# # prefix examples: afu- 180, abfu- 15
# exact transform matches: 6
# ('abfuit', '->', 'afuit', 5)
# ('abfuerit', '->', 'afuerit', 3)
# ('abfuisse', '->', 'afuisse', 2)
# ('abfuisset', '->', 'afuisset', 1)
# ('abfuturam', '->', 'afuturam', 1)
# ('abfuisti', '->', 'afuisti', 1)
# # prefix examples: conic- 157, coic- 80
# exact transform matches: 16
# ('coiciuntur', '->', 'coniciuntur', 13)
# ('coicitur', '->', 'conicitur', 8)
# ('coicienda', '->', 'conicienda', 8)
# ('coiciunt', '->', 'coniciunt', 7)
# ('coiciantur', '->', 'coniciantur', 6)
# ('coicere', '->', 'conicere', 5)
# ('coici', '->', 'conici', 5)
# ('coiciendum', '->', 'coniciendum', 5)
# ('coiciebant', '->', 'coniciebant', 4)
# ('coicerent', '->', 'conicerent', 4)
# ('coiciatur', '->', 'coniciatur', 3)
# ('coiceretur', '->', 'coniceretur', 2)
# ('coicerentur', '->', 'conicerentur', 2)
# ('coice', '->', 'conice', 2)
# ('coicit', '->', 'conicit', 1)
# ('coicientes', '->', 'conicientes', 1)
# # prefix examples: conic- 157, conit- 16
# exact transform matches: 4
# ('coniti', '->', 'conici', 3)
# ('conititur', '->', 'conicitur', 2)
# ('coniterentur', '->', 'conicerentur', 1)
# ('conitere', '->', 'conicere', 1)
# # prefix examples: coll- 4,435, conl- 2,074
# exact transform matches: 235
# ('conlocauit', '->', 'collocauit', 83)
# ('conlega', '->', 'collega', 83)
# ('conloquium', '->', 'colloquium', 71)
# ('conlatis', '->', 'collatis', 61)
# ('conlata', '->', 'collata', 57)
# ('conlegam', '->', 'collegam', 52)
# ('conlegae', '->', 'collegae', 48)
# ('conloquia', '->', 'colloquia', 46)
# ('conloquio', '->', 'colloquio', 42)
# ('conloqui', '->', 'colloqui', 36)
# ('conlocata', '->', 'collocata', 35)
# ('conlocatum', '->', 'collocatum', 28)
# ('conlatio', '->', 'collatio', 27)
# ('conlocentur', '->', 'collocentur', 27)
# ('conlocare', '->', 'collocare', 26)
# ('conlapsa', '->', 'collapsa', 26)
# ('conlegium', '->', 'collegium', 25)
# ('conlocari', '->', 'collocari', 21)
# ...
# ('inruebant', '->', 'irruebant', 3)
# ('inrigatum', '->', 'irrigatum', 3)
# ('inriguo', '->', 'irriguo', 3)
# ('inritationem', '->', 'irritationem', 3)
# ('inritatio', '->', 'irritatio', 3)
# ('inreuerentia', '->', 'irreuerentia', 3)
# ('inreligiosi', '->', 'irreligiosi', 3)
# ('inritandam', '->', 'irritandam', 3)
# ('inrumpentibus', '->', 'irrumpentibus', 3)
# ('inreuocabilis', '->', 'irreuocabilis', 3)
# ('inrequietus', '->', 'irrequietus', 3)
# ('inritis', '->', 'irritis', 3)
# ('inrumpentis', '->', 'irrumpentis', 3)
# ('inritamento', '->', 'irritamento', 3)
# ('inrequietis', '->', 'irrequietis', 2)
# ('inruptionis', '->', 'irruptionis', 2)
# ('inruptiones', '->', 'irruptiones', 2)
# ('inruentium', '->', 'irruentium', 2)
# ('inrepserit', '->', 'irrepserit', 2)
# ('inrationabiles', '->', 'irrationabiles', 2)
# ('inrideri', '->', 'irrideri', 2)
# ('inretitum', '->', 'irretitum', 2)
# ('inrisioni', '->', 'irrisioni', 2)
# ('inruperit', '->', 'irruperit', 2)
# ('inrepentibus', '->', 'irrepentibus', 2)
# ('inritatior', '->', 'irritatior', 2)
# ('inrogatam', '->', 'irrogatam', 2)
# ('inruens', '->', 'irruens', 2)
# ('inritarent', '->', 'irritarent', 2)
# ('inruente', '->', 'irruente', 2)
# ('inritatos', '->', 'irritatos', 2)
# ('inrupturos', '->', 'irrupturos', 2)
# ('inrupturi', '->', 'irrupturi', 2)
# ('inrepentes', '->', 'irrepentes', 2)
# ('inritamentis', '->', 'irritamentis', 2)
# ('inreuocabili', '->', 'irreuocabili', 2)
# ('inridente', '->', 'irridente', 2)
# ('inriguas', '->', 'irriguas', 2)
# ('inrigare', '->', 'irrigare', 2)
# ('inreuocabile', '->', 'irreuocabile', 2)
# ('inrumpis', '->', 'irrumpis', 2)
# ('inroret', '->', 'irroret', 1)
# ('inrepat', '->', 'irrepat', 1)
# ('inritabilis', '->', 'irritabilis', 1)
# ('inritatam', '->', 'irritatam', 1)
# ('inrepserunt', '->', 'irrepserunt', 1)
# ('inruebat', '->', 'irruebat', 1)
# ('inrisi', '->', 'irrisi', 1)
# ('inrueret', '->', 'irrueret', 1)
# ('inrigarentur', '->', 'irrigarentur', 1)
# ('inruentem', '->', 'irruentem', 1)
# ('inriguos', '->', 'irriguos', 1)
# ('inrationabiliter', '->', 'irrationabiliter', 1)
# ('inrigans', '->', 'irrigans', 1)
# ('inrigationes', '->', 'irrigationes', 1)
# ('inrogauerit', '->', 'irrogauerit', 1)
# ('inrigui', '->', 'irrigui', 1)
# ('inresoluta', '->', 'irresoluta', 1)
# ('inritaueris', '->', 'irritaueris', 1)
# ('inrisas', '->', 'irrisas', 1)
# ('inretire', '->', 'irretire', 1)
# ('inrisis', '->', 'irrisis', 1)
# ('inreuerentem', '->', 'irreuerentem', 1)
# ('inruentibus', '->', 'irruentibus', 1)
# ('inrationalibus', '->', 'irrationalibus', 1)
# ('inrationalia', '->', 'irrationalia', 1)
# ('inroga', '->', 'irroga', 1)
# ('inrepserat', '->', 'irrepserat', 1)
# ('inruenti', '->', 'irruenti', 1)
# ('inritauerant', '->', 'irritauerant', 1)
# ('inrisus', '->', 'irrisus', 1)
# ('inritandis', '->', 'irritandis', 1)
# ('inrumpente', '->', 'irrumpente', 1)
# # prefix examples: obt- 2,286, opt- 4,633
# exact transform matches: 95
# ('optinent', '->', 'obtinent', 27)
# ('optinuit', '->', 'obtinuit', 21)
# ('optinet', '->', 'obtinet', 20)
# ('optigit', '->', 'obtigit', 19)
# ('optinere', '->', 'obtinere', 14)
# ('optulit', '->', 'obtulit', 11)
# ('optemperare', '->', 'obtemperare', 7)
# ('optinuere', '->', 'obtinuere', 6)
# ('optineat', '->', 'obtineat', 6)
# ('optinente', '->', 'obtinente', 6)
# ('optineri', '->', 'obtineri', 5)
# ('optinens', '->', 'obtinens', 5)
# ('optinebat', '->', 'obtinebat', 4)
# ('optutu', '->', 'obtutu', 3)
# ('optutum', '->', 'obtutum', 3)
# ('optines', '->', 'obtines', 3)
# ('optineret', '->', 'obtineret', 3)
# ('optineant', '->', 'obtineant', 3)
# ('optingere', '->', 'obtingere', 3)
# ('optinuisset', '->', 'obtinuisset', 3)
# ('optorto', '->', 'obtorto', 3)
# ('optigerat', '->', 'obtigerat', 3)
# ('optinendi', '->', 'obtinendi', 3)
# ('optulerat', '->', 'obtulerat', 3)
# ('optutus', '->', 'obtutus', 2)
# ('optinentes', '->', 'obtinentes', 2)
# ('optuli', '->', 'obtuli', 2)
# ('opteri', '->', 'obteri', 2)
# ('optemperasse', '->', 'obtemperasse', 2)
# ('optemperatum', '->', 'obtemperatum', 2)
# ('optinerent', '->', 'obtinerent', 2)
# ('opteritur', '->', 'obteritur', 2)
# ('optulisse', '->', 'obtulisse', 2)
# ('optinuerat', '->', 'obtinuerat', 2)
# ('optestor', '->', 'obtestor', 2)
# ('optinebis', '->', 'obtinebis', 2)
# ('optineo', '->', 'obtineo', 2)
# ('optulisti', '->', 'obtulisti', 2)
# ('optegere', '->', 'obtegere', 2)
# ('opturatis', '->', 'obturatis', 2)
# ('optinentem', '->', 'obtinentem', 2)
# ('optulerunt', '->', 'obtulerunt', 2)
# ('optentu', '->', 'obtentu', 1)
# ('optinui', '->', 'obtinui', 1)
# ('optinendos', '->', 'obtinendos', 1)
# ('optentum', '->', 'obtentum', 1)
# ('optineatur', '->', 'obtineatur', 1)
# ('optinueris', '->', 'obtinueris', 1)
# ('optinenda', '->', 'obtinenda', 1)
# ('optemperari', '->', 'obtemperari', 1)
# ('optinebunt', '->', 'obtinebunt', 1)
# ('optemperantes', '->', 'obtemperantes', 1)
# ('optinebatur', '->', 'obtinebatur', 1)
# ('optinendum', '->', 'obtinendum', 1)
# ('optinendam', '->', 'obtinendam', 1)
# ('optinemus', '->', 'obtinemus', 1)
# ('optundat', '->', 'obtundat', 1)
# ('optusus', '->', 'obtusus', 1)
# ('optunditur', '->', 'obtunditur', 1)
# ('opturet', '->', 'obturet', 1)
# ('opterit', '->', 'obterit', 1)
# ('optundi', '->', 'obtundi', 1)
# ('optinuerit', '->', 'obtinuerit', 1)
# ('optinentis', '->', 'obtinentis', 1)
# ('optruncauit', '->', 'obtruncauit', 1)
# ('opticuisti', '->', 'obticuisti', 1)
# ('optundit', '->', 'obtundit', 1)
# ('optinebit', '->', 'obtinebit', 1)
# ('optinget', '->', 'obtinget', 1)
# ('optrudere', '->', 'obtrudere', 1)
# ('optingit', '->', 'obtingit', 1)
# ('optinentur', '->', 'obtinentur', 1)
# ('opturata', '->', 'obturata', 1)
# ('opturamentis', '->', 'obturamentis', 1)
# ('opturatum', '->', 'obturatum', 1)
# ('optulisset', '->', 'obtulisset', 1)
# ('optigerit', '->', 'obtigerit', 1)
# ('optinendas', '->', 'obtinendas', 1)
# ('optusis', '->', 'obtusis', 1)
# ('optemperant', '->', 'obtemperant', 1)
# ('optulere', '->', 'obtulere', 1)
# ('optorpuisse', '->', 'obtorpuisse', 1)
# ('optemperat', '->', 'obtemperat', 1)
# ('optentui', '->', 'obtentui', 1)
# ('optemperans', '->', 'obtemperans', 1)
# ('optemperaret', '->', 'obtemperaret', 1)
# ('optulerit', '->', 'obtulerit', 1)
# ('optento', '->', 'obtento', 1)
# ('optemperauit', '->', 'obtemperauit', 1)
# ('optinenti', '->', 'obtinenti', 1)
# ('optinentibus', '->', 'obtinentibus', 1)
# ('optendunt', '->', 'obtendunt', 1)
# ('optinendae', '->', 'obtinendae', 1)
# ('optinuerant', '->', 'obtinuerant', 1)
# ('optinuerunt', '->', 'obtinuerunt', 1)
# # prefix examples: opp- 5,698, obp- 226
# exact transform matches: 50
# ('obprobrium', '->', 'opprobrium', 104)
# ('obprobria', '->', 'opprobria', 10)
# ('obprobrio', '->', 'opprobrio', 7)
# ('obprobrii', '->', 'opprobrii', 7)
# ('obpugnationem', '->', 'oppugnationem', 6)
# ('obprobriis', '->', 'opprobriis', 5)
# ('obpugnauit', '->', 'oppugnauit', 4)
# ('obpugnare', '->', 'oppugnare', 3)
# ('obpugnabat', '->', 'oppugnabat', 3)
# ('obpugnatio', '->', 'oppugnatio', 3)
# ('obprimitur', '->', 'opprimitur', 3)
# ('obposuit', '->', 'opposuit', 3)
# ('obpugnantium', '->', 'oppugnantium', 3)
# ('obpugnantes', '->', 'oppugnantes', 3)
# ('obpugnantibus', '->', 'oppugnantibus', 2)
# ('obpressit', '->', 'oppressit', 2)
# ('obpugnanda', '->', 'oppugnanda', 2)
# ('obpressus', '->', 'oppressus', 2)
# ('obpugnatur', '->', 'oppugnatur', 2)
# ('obpugnabant', '->', 'oppugnabant', 2)
# ('obpugnando', '->', 'oppugnando', 2)
# ('obpugnant', '->', 'oppugnant', 2)
# ('obposita', '->', 'opposita', 2)
# ('obpugnatores', '->', 'oppugnatores', 2)
# ('obponendum', '->', 'opponendum', 1)
# ('obprimit', '->', 'opprimit', 1)
# ('obpressi', '->', 'oppressi', 1)
# ('obprimere', '->', 'opprimere', 1)
# ('obpugnaret', '->', 'oppugnaret', 1)
# ('obpeteret', '->', 'oppeteret', 1)
# ('obpressum', '->', 'oppressum', 1)
# ('obprimebat', '->', 'opprimebat', 1)
# ('obpetisse', '->', 'oppetisse', 1)
# ('obponi', '->', 'opponi', 1)
# ('obponatur', '->', 'opponatur', 1)
# ('obpugnarent', '->', 'oppugnarent', 1)
# ('obpugnabis', '->', 'oppugnabis', 1)
# ('obpugnat', '->', 'oppugnat', 1)
# ('obpugnans', '->', 'oppugnans', 1)
# ('obpugnante', '->', 'oppugnante', 1)
# ('obprimor', '->', 'opprimor', 1)
# ('obpugnationibus', '->', 'oppugnationibus', 1)
# ('obprimi', '->', 'opprimi', 1)
# ('obpugnationes', '->', 'oppugnationes', 1)
# ('obpugnatoribus', '->', 'oppugnatoribus', 1)
# ('obpugnationis', '->', 'oppugnationis', 1)
# ('obpositam', '->', 'oppositam', 1)
# ('obpositae', '->', 'oppositae', 1)
# ('obpugnatum', '->', 'oppugnatum', 1)
# ('obpugnandum', '->', 'oppugnandum', 1)
# # prefix examples: prae- 40,075, pre- 6,334
# exact transform matches: 47
# ('precibus', '->', 'praecibus', 477)
# ('premi', '->', 'praemi', 50)
# ('preti', '->', 'praeti', 32)
# ('premis', '->', 'praemis', 21)
# ('pre', '->', 'prae', 9)
# ('prelis', '->', 'praelis', 9)
# ('prela', '->', 'praela', 8)
# ('prelo', '->', 'praelo', 4)
# ('prestat', '->', 'praestat', 3)
# ('preciae', '->', 'praeciae', 3)
# ('precepit', '->', 'praecepit', 2)
# ('pregnans', '->', 'praegnans', 2)
# ('precede', '->', 'praecede', 2)
# ('presul', '->', 'praesul', 2)
# ('preda', '->', 'praeda', 2)
# ('precepta', '->', 'praecepta', 2)
# ('prepotens', '->', 'praepotens', 2)
# ('precipiunt', '->', 'praecipiunt', 1)
# ('preceperit', '->', 'praeceperit', 1)
# ('preterquam', '->', 'praeterquam', 1)
# ('presente', '->', 'praesente', 1)
# ('presens', '->', 'praesens', 1)
# ('presumpsit', '->', 'praesumpsit', 1)
# ('precipit', '->', 'praecipit', 1)
# ('preuaricatorem', '->', 'praeuaricatorem', 1)
# ('prebuit', '->', 'praebuit', 1)
# ('precellit', '->', 'praecellit', 1)
# ('preclara', '->', 'praeclara', 1)
# ('predam', '->', 'praedam', 1)
# ('presulis', '->', 'praesulis', 1)
# ('prepete', '->', 'praepete', 1)
# ('prepes', '->', 'praepes', 1)
# ('preparat', '->', 'praeparat', 1)
# ('preceptor', '->', 'praeceptor', 1)
# ('preferat', '->', 'praeferat', 1)
# ('precauete', '->', 'praecauete', 1)
# ('predura', '->', 'praedura', 1)
# ('premia', '->', 'praemia', 1)
# ('preerit', '->', 'praeerit', 1)
# ('prerepta', '->', 'praerepta', 1)
# ('presentibus', '->', 'praesentibus', 1)
# ('preuenit', '->', 'praeuenit', 1)
# ('prealtas', '->', 'praealtas', 1)
# ('prelia', '->', 'praelia', 1)
# ('prebete', '->', 'praebete', 1)
# ('prei', '->', 'praei', 1)
# ('predicator', '->', 'praedicator', 1)
# # prefix examples: subm- 421, summ- 6,977
# exact transform matches: 78
# ('summo', '->', 'submo', 958)
# ('summissa', '->', 'submissa', 38)
# ('summittere', '->', 'submittere', 29)
# ('summouit', '->', 'submouit', 28)
# ('summisso', '->', 'submisso', 25)
# ('summotis', '->', 'submotis', 24)
# ('summisse', '->', 'submisse', 21)
# ('summota', '->', 'submota', 19)
# ('summissis', '->', 'submissis', 18)
# ('summouet', '->', 'submouet', 18)
# ('summittit', '->', 'submittit', 16)
# ('summisit', '->', 'submisit', 16)
# ('summoueri', '->', 'submoueri', 13)
# ('summouere', '->', 'submouere', 13)
# ('summoto', '->', 'submoto', 12)
# ('summissus', '->', 'submissus', 11)
# ('summissum', '->', 'submissum', 10)
# ('summissi', '->', 'submissi', 9)
# ('summitteret', '->', 'submitteret', 9)
# ('summittitur', '->', 'submittitur', 9)
# ('summissius', '->', 'submissius', 8)
# ('summotus', '->', 'submotus', 8)
# ('summittat', '->', 'submittat', 6)
# ('summotos', '->', 'submotos', 6)
# ('summouenda', '->', 'submouenda', 5)
# ('summittunt', '->', 'submittunt', 5)
# ('summouent', '->', 'submouent', 5)
# ('summoueret', '->', 'submoueret', 5)
# ('summissae', '->', 'submissae', 4)
# ('summoueant', '->', 'submoueant', 4)
# ('summouetur', '->', 'submouetur', 4)
# ('summoueretur', '->', 'submoueretur', 4)
# ('summotum', '->', 'submotum', 4)
# ('summouentur', '->', 'submouentur', 3)
# ('summittebat', '->', 'submittebat', 3)
# ('summouerentur', '->', 'submouerentur', 3)
# ('summersa', '->', 'submersa', 3)
# ('summisere', '->', 'submisere', 3)
# ('summitti', '->', 'submitti', 3)
# ('summittuntur', '->', 'submittuntur', 3)
# ('summittantur', '->', 'submittantur', 3)
# ('summitte', '->', 'submitte', 3)
# ('summissas', '->', 'submissas', 3)
# ('summersi', '->', 'submersi', 2)
# ('summittant', '->', 'submittant', 2)
# ('summouerat', '->', 'submouerat', 2)
# ('summittens', '->', 'submittens', 2)
# ('summisi', '->', 'submisi', 2)
# ('summoueat', '->', 'submoueat', 2)
# ('summouerit', '->', 'submouerit', 2)
# ('summiserit', '->', 'submiserit', 2)
# ('summittebant', '->', 'submittebant', 1)
# ('summouebant', '->', 'submouebant', 1)
# ('summersam', '->', 'submersam', 1)
# ('sumministrat', '->', 'subministrat', 1)
# ('sumministrant', '->', 'subministrant', 1)
# ('summouendae', '->', 'submouendae', 1)
# ('summoues', '->', 'submoues', 1)
# ('summitterent', '->', 'submitterent', 1)
# ('summouerunt', '->', 'submouerunt', 1)
# ('summisisse', '->', 'submisisse', 1)
# ('summersos', '->', 'submersos', 1)
# ('summersum', '->', 'submersum', 1)
# ('summersis', '->', 'submersis', 1)
# ('summotae', '->', 'submotae', 1)
# ('summouimus', '->', 'submouimus', 1)
# ('summiserat', '->', 'submiserat', 1)
# ('summittentes', '->', 'submittentes', 1)
# ('summouerent', '->', 'submouerent', 1)
# ('sumministrabit', '->', 'subministrabit', 1)
# ('summittis', '->', 'submittis', 1)
# ('summouentem', '->', 'submouentem', 1)
# ('summittite', '->', 'submittite', 1)
# ('summittet', '->', 'submittet', 1)
# ('summissos', '->', 'submissos', 1)
# ('summissiore', '->', 'submissiore', 1)
# ('summersus', '->', 'submersus', 1)
# ('sumministrante', '->', 'subministrante', 1)
# # prefix examples: suff- 1,811, subf- 48
# exact transform matches: 18
# ('subfixa', '->', 'suffixa', 3)
# ('subfusis', '->', 'suffusis', 3)
# ('subferuefacta', '->', 'sufferuefacta', 3)
# ('subfossis', '->', 'suffossis', 2)
# ('subferuefactis', '->', 'sufferuefactis', 2)
# ('subferuefactum', '->', 'sufferuefactum', 2)
# ('subfragabatur', '->', 'suffragabatur', 1)
# ('subfodiat', '->', 'suffodiat', 1)
# ('subfusiones', '->', 'suffusiones', 1)
# ('subfusae', '->', 'suffusae', 1)
# ('subfusus', '->', 'suffusus', 1)
# ('subfundit', '->', 'suffundit', 1)
# ('subfodit', '->', 'suffodit', 1)
# ('subfundere', '->', 'suffundere', 1)
# ('subfuso', '->', 'suffuso', 1)
# ('subfodere', '->', 'suffodere', 1)
# ('subfundi', '->', 'suffundi', 1)
# ('subfragatio', '->', 'suffragatio', 1)
# # prefix examples: supp- 2,879, subp- 144
# exact transform matches: 53
# ('subplantat', '->', 'supplantat', 5)
# ('subposuit', '->', 'supposuit', 4)
# ('subposito', '->', 'supposito', 4)
# ('subponere', '->', 'supponere', 3)
# ('subpositis', '->', 'suppositis', 2)
# ('subpositae', '->', 'suppositae', 2)
# ('subpositas', '->', 'suppositas', 2)
# ('subprimere', '->', 'supprimere', 2)
# ('subpetit', '->', 'suppetit', 2)
# ('subpeditant', '->', 'suppeditant', 2)
# ('subplantauit', '->', 'supplantauit', 2)
# ('subposuerunt', '->', 'supposuerunt', 2)
# ('subplantare', '->', 'supplantare', 2)
# ('subpositus', '->', 'suppositus', 2)
# ('subpeditare', '->', 'suppeditare', 2)
# ('subposita', '->', 'supposita', 2)
# ('subpeditat', '->', 'suppeditat', 2)
# ('subpilo', '->', 'suppilo', 1)
# ('subpositi', '->', 'suppositi', 1)
# ('subportat', '->', 'supportat', 1)
# ('subportare', '->', 'supportare', 1)
# ('subportari', '->', 'supportari', 1)
# ('subpressum', '->', 'suppressum', 1)
# ('subprimendum', '->', 'supprimendum', 1)
# ('subpresso', '->', 'suppresso', 1)
# ('subprimatur', '->', 'supprimatur', 1)
# ('subprimi', '->', 'supprimi', 1)
# ('subprimitur', '->', 'supprimitur', 1)
# ('subponimus', '->', 'supponimus', 1)
# ('subponatur', '->', 'supponatur', 1)
# ('subpeditantur', '->', 'suppeditantur', 1)
# ('subprimebat', '->', 'supprimebat', 1)
# ('subpetat', '->', 'suppetat', 1)
# ('subpeditabat', '->', 'suppeditabat', 1)
# ('subplementa', '->', 'supplementa', 1)
# ('subpetierant', '->', 'suppetierant', 1)
# ('subputantur', '->', 'supputantur', 1)
# ('subponentur', '->', 'supponentur', 1)
# ('subponit', '->', 'supponit', 1)
# ('subplantationem', '->', 'supplantationem', 1)
# ('subpetebant', '->', 'suppetebant', 1)
# ('subpeditet', '->', 'suppeditet', 1)
# ('subpeditabatur', '->', 'suppeditabatur', 1)
# ('subpeditentur', '->', 'suppeditentur', 1)
# ('subpetunt', '->', 'suppetunt', 1)
# ('subposuisse', '->', 'supposuisse', 1)
# ('subpositum', '->', 'suppositum', 1)
# ('subpurationes', '->', 'suppurationes', 1)
# ('subpurata', '->', 'suppurata', 1)
# ('subputat', '->', 'supputat', 1)
# ('subplicio', '->', 'supplicio', 1)
# ('subpone', '->', 'suppone', 1)
# ('subprimenda', '->', 'supprimenda', 1)
# # prefix examples: trai- 581, transi- 2,208
# exact transform matches: 4
# ('transis', '->', 'trais', 6)
# ('transicit', '->', 'traicit', 1)
# ('transiecit', '->', 'traiecit', 1)
# ('transiecta', '->', 'traiecta', 1)
# total transformations proposed 25,224

# %%
# when coerce to lower: total transformations proposed 26,088

# %% [markdown]
# # Other regularizations worth considering: archaisms

# %%
word_counts.get('quom') # ~ cum
# Out:
# 471

# %% [markdown]
# # Perhaps transliterated words should appear in the original Greek?

# %%
word_counts.get('alla'), word_counts.get('allh'), word_counts.get('kai')
# Out:
# (147, 56, 1552)

# %% [markdown]
# # Phi5 Corpus: Proposed Spelling Regularizations

# %%
author_index = {val:key for key,val in PHI5_INDEX.items()}  

def get_phi5_author_files(author_name, author_index):
    stub = author_index[author_name]
    return glob(os.path.expanduser(f'~/cltk_data/latin/text/phi5/individual_works/{stub}*.txt'))

word_counts = Counter()
jv_replacer = JVReplacer()
aeoe_replacer = AEOEReplacer()
toker = WordTokenizer('latin')
sent_toker = SentenceTokenizer() 

for author in tqdm(author_index):
    files = get_phi5_author_files(author, author_index)
    for file in files:
        with open(file, 'rt') as fin:
            text = fin.read()
            text = text.replace("-\n", "") # Phi5 has some hyphenated line endings
            text = text.replace("\n", " ")
            text = aeoe_replacer.replace(jv_replacer.replace(text))
            for sent in sent_toker.tokenize(text):
                sent = dehyphenate(sent) # because it's Phi5
                sent = swallow_braces(sent)
                sent = swallow_square_brackets(sent)
                sent = disappear_round_brackets(sent)
                sent = swallow_obelized_words(sent)
                sent = disappear_angle_brackets(sent)            
                sent = drop_punct(sent)
                sent = normalize_accents(sent)            
                for word in toker.tokenize(sent):
                    if word.isnumeric():
                        continue
                    word_counts.update({word : 1}) 

print_regularizations(word_counts)
# Out:
# 100%|██████████| 362/362 [02:51<00:00,  2.12it/s]
# # prefix examples: adf- 5,232, aff- 964
# exact transform matches: 206
# ('affectus', '->', 'adfectus', 107)
# ('affectu', '->', 'adfectu', 58)
# ('affectum', '->', 'adfectum', 36)
# ('affert', '->', 'adfert', 33)
# ('affectio', '->', 'adfectio', 30)
# ('afferre', '->', 'adferre', 25)
# ('afferat', '->', 'adferat', 24)
# ('affectibus', '->', 'adfectibus', 20)
# ('affirmauit', '->', 'adfirmauit', 18)
# ('affectionem', '->', 'adfectionem', 17)
# ('afferri', '->', 'adferri', 16)
# ('affatim', '->', 'adfatim', 15)
# ('affectionis', '->', 'adfectionis', 14)
# ('afferunt', '->', 'adferunt', 13)
# ('affici', '->', 'adfici', 13)
# ('afferret', '->', 'adferret', 13)
# ('affecti', '->', 'adfecti', 12)
# ('affirmat', '->', 'adfirmat', 11)
# ('afflictis', '->', 'adflictis', 9)
# ('afflicti', '->', 'adflicti', 9)
# ('affuit', '->', 'adfuit', 8)
# ('affertur', '->', 'adfertur', 7)
# ('affirmant', '->', 'adfirmant', 7)
# ('afferet', '->', 'adferet', 7)
# ('affluens', '->', 'adfluens', 7)
# ('afflixit', '->', 'adflixit', 7)
# ('affero', '->', 'adfero', 7)
# ('affirmatio', '->', 'adfirmatio', 6)
# ('afferant', '->', 'adferant', 6)
# ('affectiones', '->', 'adfectiones', 6)
# ('affecit', '->', 'adfecit', 6)
# ('affinitatem', '->', 'adfinitatem', 6)
# ('affirmans', '->', 'adfirmans', 6)
# ('afflictae', '->', 'adflictae', 6)
# ('affines', '->', 'adfines', 5)
# ('affecta', '->', 'adfecta', 5)
# ('afficitur', '->', 'adficitur', 5)
# ('affectos', '->', 'adfectos', 5)
# ('afferetur', '->', 'adferetur', 5)
# ('afflictam', '->', 'adflictam', 5)
# ('affirmabat', '->', 'adfirmabat', 5)
# ('affluentiam', '->', 'adfluentiam', 5)
# ('afferuntur', '->', 'adferuntur', 4)
# ('affers', '->', 'adfers', 4)
# ('affirmo', '->', 'adfirmo', 4)
# ('affluentibus', '->', 'adfluentibus', 4)
# ('affectae', '->', 'adfectae', 4)
# ('affixa', '->', 'adfixa', 4)
# ('afferatur', '->', 'adferatur', 4)
# ('affectioni', '->', 'adfectioni', 4)
# ('afflauit', '->', 'adflauit', 4)
# ('affigi', '->', 'adfigi', 4)
# ('affectatae', '->', 'adfectatae', 4)
# ('affectauit', '->', 'adfectauit', 4)
# ('afflictum', '->', 'adflictum', 4)
# ('affectare', '->', 'adfectare', 4)
# ('afflatu', '->', 'adflatu', 4)
# ('afflatus', '->', 'adflatus', 4)
# ('affuisset', '->', 'adfuisset', 4)
# ('afficiantur', '->', 'adficiantur', 3)
# ('afficit', '->', 'adficit', 3)
# ('afficiuntur', '->', 'adficiuntur', 3)
# ('affluentius', '->', 'adfluentius', 3)
# ('afficiendum', '->', 'adficiendum', 3)
# ('affluentia', '->', 'adfluentia', 3)
# ('afflictos', '->', 'adflictos', 3)
# ('affatur', '->', 'adfatur', 3)
# ('affinis', '->', 'adfinis', 3)
# ('afflauerit', '->', 'adflauerit', 3)
# ('afflictas', '->', 'adflictas', 3)
# ('afflicta', '->', 'adflicta', 3)
# ('affectionibus', '->', 'adfectionibus', 3)
# ('affectata', '->', 'adfectata', 3)
# ('affectat', '->', 'adfectat', 3)
# ('afficeret', '->', 'adficeret', 3)
# ('affusa', '->', 'adfusa', 3)
# ('affinitate', '->', 'adfinitate', 3)
# ('afferebat', '->', 'adferebat', 3)
# ('affectis', '->', 'adfectis', 3)
# ('affinitatis', '->', 'adfinitatis', 3)
# ('affusus', '->', 'adfusus', 3)
# ('affinitatibus', '->', 'adfinitatibus', 2)
# ('afflueret', '->', 'adflueret', 2)
# ('afferrent', '->', 'adferrent', 2)
# ('afficiatur', '->', 'adficiatur', 2)
# ('afficiet', '->', 'adficiet', 2)
# ('affluenti', '->', 'adfluenti', 2)
# ('affari', '->', 'adfari', 2)
# ('affui', '->', 'adfui', 2)
# ('afficere', '->', 'adficere', 2)
# ('afficiunt', '->', 'adficiunt', 2)
# ('affatibus', '->', 'adfatibus', 2)
# ('affatu', '->', 'adfatu', 2)
# ('affligebat', '->', 'adfligebat', 2)
# ('affligit', '->', 'adfligit', 2)
# ('afferas', '->', 'adferas', 2)
# ('affini', '->', 'adfini', 2)
# ('affer', '->', 'adfer', 2)
# ('affigere', '->', 'adfigere', 2)
# ('affluentis', '->', 'adfluentis', 2)
# ('affluat', '->', 'adfluat', 2)
# ('affectati', '->', 'adfectati', 2)
# ('affectam', '->', 'adfectam', 2)
# ('afflabat', '->', 'adflabat', 2)
# ('afficeretur', '->', 'adficeretur', 2)
# ('affecisset', '->', 'adfecisset', 2)
# ('affabilis', '->', 'adfabilis', 2)
# ('affinem', '->', 'adfinem', 2)
# ('affectui', '->', 'adfectui', 2)
# ('affligat', '->', 'adfligat', 2)
# ('affore', '->', 'adfore', 2)
# ('affirmasse', '->', 'adfirmasse', 2)
# ('affuerit', '->', 'adfuerit', 2)
# ('affirmantem', '->', 'adfirmantem', 2)
# ('affirmasset', '->', 'adfirmasset', 2)
# ('affirmantibus', '->', 'adfirmantibus', 2)
# ('afflicto', '->', 'adflicto', 2)
# ('affirmarent', '->', 'adfirmarent', 2)
# ('affligi', '->', 'adfligi', 2)
# ('affirmaret', '->', 'adfirmaret', 2)
# ('afflata', '->', 'adflata', 2)
# ('affirmatis', '->', 'adfirmatis', 1)
# ('afferamus', '->', 'adferamus', 1)
# ('afferendum', '->', 'adferendum', 1)
# ('affinitates', '->', 'adfinitates', 1)
# ('affabilem', '->', 'adfabilem', 1)
# ('afficientur', '->', 'adficientur', 1)
# ('afferens', '->', 'adferens', 1)
# ('affingit', '->', 'adfingit', 1)
# ('affirment', '->', 'adfirment', 1)
# ('affirmabo', '->', 'adfirmabo', 1)
# ('affligere', '->', 'adfligere', 1)
# ('affecerit', '->', 'adfecerit', 1)
# ('affluit', '->', 'adfluit', 1)
# ('affirmet', '->', 'adfirmet', 1)
# ('affirmare', '->', 'adfirmare', 1)
# ('affirmatur', '->', 'adfirmatur', 1)
# ('afferemus', '->', 'adferemus', 1)
# ('affirmamus', '->', 'adfirmamus', 1)
# ('affirmetur', '->', 'adfirmetur', 1)
# ('affirmaui', '->', 'adfirmaui', 1)
# ('affabilitate', '->', 'adfabilitate', 1)
# ('affirma', '->', 'adfirma', 1)
# ('affulsisse', '->', 'adfulsisse', 1)
# ('afforet', '->', 'adforet', 1)
# ('affecerunt', '->', 'adfecerunt', 1)
# ('afflatibus', '->', 'adflatibus', 1)
# ('affata', '->', 'adfata', 1)
# ('affulsit', '->', 'adfulsit', 1)
# ('affirmes', '->', 'adfirmes', 1)
# ('affundit', '->', 'adfundit', 1)
# ('afficerentur', '->', 'adficerentur', 1)
# ('affectabat', '->', 'adfectabat', 1)
# ('afferantur', '->', 'adferantur', 1)
# ('affectans', '->', 'adfectans', 1)
# ('affectatorem', '->', 'adfectatorem', 1)
# ('affinibus', '->', 'adfinibus', 1)
# ('affluentem', '->', 'adfluentem', 1)
# ('affirmatum', '->', 'adfirmatum', 1)
# ('afflari', '->', 'adflari', 1)
# ('affluente', '->', 'adfluente', 1)
# ('affuturum', '->', 'adfuturum', 1)
# ('afflictarum', '->', 'adflictarum', 1)
# ('afflare', '->', 'adflare', 1)
# ('afficta', '->', 'adficta', 1)
# ('affixit', '->', 'adfixit', 1)
# ('affluxerit', '->', 'adfluxerit', 1)
# ('affectent', '->', 'adfectent', 1)
# ('afficietur', '->', 'adficietur', 1)
# ('affliguntur', '->', 'adfliguntur', 1)
# ('afficiebat', '->', 'adficiebat', 1)
# ('affulserat', '->', 'adfulserat', 1)
# ('affixus', '->', 'adfixus', 1)
# ('affluere', '->', 'adfluere', 1)
# ('affixis', '->', 'adfixis', 1)
# ('afferebantur', '->', 'adferebantur', 1)
# ('affuerunt', '->', 'adfuerunt', 1)
# ('affectauerunt', '->', 'adfectauerunt', 1)
# ('affuturos', '->', 'adfuturos', 1)
# ('affirmationi', '->', 'adfirmationi', 1)
# ('affligerentur', '->', 'adfligerentur', 1)
# ('affecerat', '->', 'adfecerat', 1)
# ('affirmantes', '->', 'adfirmantes', 1)
# ('afferent', '->', 'adferent', 1)
# ('affatus', '->', 'adfatus', 1)
# ('afferes', '->', 'adferes', 1)
# ('affectamus', '->', 'adfectamus', 1)
# ('affusum', '->', 'adfusum', 1)
# ('affricta', '->', 'adfricta', 1)
# ('afflat', '->', 'adflat', 1)
# ('affigitur', '->', 'adfigitur', 1)
# ('affrictu', '->', 'adfrictu', 1)
# ('affirmauerunt', '->', 'adfirmauerunt', 1)
# ('affirmemus', '->', 'adfirmemus', 1)
# ('afflatum', '->', 'adflatum', 1)
# ('affectantibus', '->', 'adfectantibus', 1)
# ('afferam', '->', 'adferam', 1)
# ('afficio', '->', 'adficio', 1)
# ('affectate', '->', 'adfectate', 1)
# ('affligitur', '->', 'adfligitur', 1)
# ('afflati', '->', 'adflati', 1)
# ('affectantes', '->', 'adfectantes', 1)
# ('affectauerit', '->', 'adfectauerit', 1)
# ('affectasse', '->', 'adfectasse', 1)
# ('affectanda', '->', 'adfectanda', 1)
# ('afficerent', '->', 'adficerent', 1)
# # prefix examples: agg- 521, adg- 1,052
# exact transform matches: 32
# ('adgressus', '->', 'aggressus', 121)
# ('adgreditur', '->', 'aggreditur', 74)
# ('adgredi', '->', 'aggredi', 72)
# ('adgressi', '->', 'aggressi', 54)
# ('adgrediar', '->', 'aggrediar', 33)
# ('adgrederetur', '->', 'aggrederetur', 28)
# ('adgrediuntur', '->', 'aggrediuntur', 19)
# ('adgrederentur', '->', 'aggrederentur', 19)
# ('adgredior', '->', 'aggredior', 14)
# ('adgressa', '->', 'aggressa', 9)
# ('adgressurus', '->', 'aggressurus', 9)
# ('adgredere', '->', 'aggredere', 8)
# ('adgredienda', '->', 'aggredienda', 8)
# ('adgredimur', '->', 'aggredimur', 7)
# ('adgesta', '->', 'aggesta', 4)
# ('adgressuros', '->', 'aggressuros', 3)
# ('adgressuri', '->', 'aggressuri', 3)
# ('adgemit', '->', 'aggemit', 2)
# ('adgerere', '->', 'aggerere', 2)
# ('adgestu', '->', 'aggestu', 2)
# ('adgredienti', '->', 'aggredienti', 2)
# ('adgerunt', '->', 'aggerunt', 2)
# ('adgrauant', '->', 'aggrauant', 2)
# ('adgrederis', '->', 'aggrederis', 1)
# ('adgerebant', '->', 'aggerebant', 1)
# ('adgressio', '->', 'aggressio', 1)
# ('adgressum', '->', 'aggressum', 1)
# ('adgerentem', '->', 'aggerentem', 1)
# ('adgeri', '->', 'aggeri', 1)
# ('adgerunda', '->', 'aggerunda', 1)
# ('adglutinant', '->', 'agglutinant', 1)
# ('adgrauet', '->', 'aggrauet', 1)
# # prefix examples: all- 921, adl- 981
# exact transform matches: 91
# ('adloquitur', '->', 'alloquitur', 78)
# ('adlatum', '->', 'allatum', 37)
# ('adlata', '->', 'allata', 32)
# ('adlatae', '->', 'allatae', 31)
# ('adluit', '->', 'alluit', 31)
# ('adluitur', '->', 'alluitur', 29)
# ('adloqui', '->', 'alloqui', 27)
# ('adlocutus', '->', 'allocutus', 23)
# ('adludit', '->', 'alludit', 22)
# ('adloquio', '->', 'alloquio', 18)
# ('adloquor', '->', 'alloquor', 17)
# ('adlusit', '->', 'allusit', 16)
# ('adlatis', '->', 'allatis', 13)
# ('adlato', '->', 'allato', 13)
# ('adlatura', '->', 'allatura', 12)
# ('adlatas', '->', 'allatas', 12)
# ('adlatus', '->', 'allatus', 12)
# ('adloquar', '->', 'alloquar', 12)
# ('adloquiis', '->', 'alloquiis', 11)
# ('adlatam', '->', 'allatam', 10)
# ('adlicere', '->', 'allicere', 9)
# ('adligat', '->', 'alligat', 8)
# ('adlocutio', '->', 'allocutio', 8)
# ('adleuare', '->', 'alleuare', 8)
# ('adloquendi', '->', 'alloquendi', 8)
# ('adlaturum', '->', 'allaturum', 7)
# ('adleuat', '->', 'alleuat', 6)
# ('adligatum', '->', 'alligatum', 6)
# ('adleuans', '->', 'alleuans', 6)
# ('adlaturus', '->', 'allaturus', 6)
# ('adlegit', '->', 'allegit', 6)
# ('adligato', '->', 'alligato', 6)
# ('adligari', '->', 'alligari', 5)
# ('adligauit', '->', 'alligauit', 5)
# ('adligatos', '->', 'alligatos', 5)
# ('adlocutiones', '->', 'allocutiones', 5)
# ('adlicit', '->', 'allicit', 5)
# ('adlegauit', '->', 'allegauit', 5)
# ('adligare', '->', 'alligare', 4)
# ('adleuatis', '->', 'alleuatis', 3)
# ('adliget', '->', 'alliget', 3)
# ('adlegat', '->', 'allegat', 3)
# ('adlici', '->', 'allici', 3)
# ('adlaturam', '->', 'allaturam', 3)
# ('adliciat', '->', 'alliciat', 3)
# ('adligati', '->', 'alligati', 3)
# ('adluens', '->', 'alluens', 3)
# ('adlecti', '->', 'allecti', 3)
# ('adloquebatur', '->', 'alloquebatur', 3)
# ('adleuatur', '->', 'alleuatur', 3)
# ('adligetur', '->', 'alligetur', 3)
# ('adlati', '->', 'allati', 2)
# ('adliciebat', '->', 'alliciebat', 2)
# ('adligatam', '->', 'alligatam', 2)
# ('adligata', '->', 'alligata', 2)
# ('adleget', '->', 'alleget', 2)
# ('adlegantes', '->', 'allegantes', 2)
# ('adloquerer', '->', 'alloquerer', 2)
# ('adliganda', '->', 'alliganda', 2)
# ('adleuauit', '->', 'alleuauit', 2)
# ('adliciendo', '->', 'alliciendo', 2)
# ('adliciendi', '->', 'alliciendi', 2)
# ('adlaturos', '->', 'allaturos', 2)
# ('adliceret', '->', 'alliceret', 2)
# ('adlegare', '->', 'allegare', 2)
# ('adligatis', '->', 'alligatis', 2)
# ('adlapsam', '->', 'allapsam', 1)
# ('adlegationibus', '->', 'allegationibus', 1)
# ('adliciant', '->', 'alliciant', 1)
# ('adligaretur', '->', 'alligaretur', 1)
# ('adlegato', '->', 'allegato', 1)
# ('adlegatio', '->', 'allegatio', 1)
# ('adlectum', '->', 'allectum', 1)
# ('adligatur', '->', 'alligatur', 1)
# ('adligauerit', '->', 'alligauerit', 1)
# ('adluuie', '->', 'alluuie', 1)
# ('adligatae', '->', 'alligatae', 1)
# ('adligantur', '->', 'alligantur', 1)
# ('adligaueris', '->', 'alligaueris', 1)
# ('adligatus', '->', 'alligatus', 1)
# ('adlaturi', '->', 'allaturi', 1)
# ('adlectus', '->', 'allectus', 1)
# ('adlegabat', '->', 'allegabat', 1)
# ('adlegemus', '->', 'allegemus', 1)
# ('adleuatio', '->', 'alleuatio', 1)
# ('adluuionem', '->', 'alluuionem', 1)
# ('adlegi', '->', 'allegi', 1)
# ('adligatura', '->', 'alligatura', 1)
# ('adligo', '->', 'alligo', 1)
# ('adlinit', '->', 'allinit', 1)
# ('adligans', '->', 'alligans', 1)
# # prefix examples: adm- 6,065, amm- 80
# exact transform matches: 18
# ('amminiculo', '->', 'adminiculo', 3)
# ('ammisso', '->', 'admisso', 2)
# ('ammonet', '->', 'admonet', 2)
# ('ammota', '->', 'admota', 2)
# ('ammoneant', '->', 'admoneant', 1)
# ('ammiratus', '->', 'admiratus', 1)
# ('ammonetis', '->', 'admonetis', 1)
# ('ammiscebis', '->', 'admiscebis', 1)
# ('ammiraretur', '->', 'admiraretur', 1)
# ('ammiratur', '->', 'admiratur', 1)
# ('ammonendum', '->', 'admonendum', 1)
# ('amministrat', '->', 'administrat', 1)
# ('amminicula', '->', 'adminicula', 1)
# ('amminister', '->', 'administer', 1)
# ('ammouere', '->', 'admouere', 1)
# ('ammissum', '->', 'admissum', 1)
# ('ammi', '->', 'admi', 1)
# ('ammorso', '->', 'admorso', 1)
# # prefix examples: adn- 746, ann- 8,140
# exact transform matches: 19
# ('annuo', '->', 'adnuo', 40)
# ('annuis', '->', 'adnuis', 37)
# ('annuas', '->', 'adnuas', 13)
# ('annuit', '->', 'adnuit', 5)
# ('annuat', '->', 'adnuat', 3)
# ('annexum', '->', 'adnexum', 3)
# ('annuntiabat', '->', 'adnuntiabat', 2)
# ('ann', '->', 'adn', 2)
# ('annuisset', '->', 'adnuisset', 2)
# ('annuerit', '->', 'adnuerit', 1)
# ('annuntiat', '->', 'adnuntiat', 1)
# ('annuerint', '->', 'adnuerint', 1)
# ('annotationibus', '->', 'adnotationibus', 1)
# ('annotauit', '->', 'adnotauit', 1)
# ('annotare', '->', 'adnotare', 1)
# ('anniti', '->', 'adniti', 1)
# ('annuntiari', '->', 'adnuntiari', 1)
# ('annuimus', '->', 'adnuimus', 1)
# ('annotandum', '->', 'adnotandum', 1)
# # prefix examples: app- 8,855, adp- 2,039
# exact transform matches: 279
# ('adposita', '->', 'apposita', 84)
# ('adpositum', '->', 'appositum', 43)
# ('adpropinquare', '->', 'appropinquare', 34)
# ('adprobare', '->', 'approbare', 33)
# ('adprime', '->', 'apprime', 29)
# ('adparet', '->', 'apparet', 28)
# ('adpetere', '->', 'appetere', 23)
# ('adprehendit', '->', 'apprehendit', 22)
# ('adpositis', '->', 'appositis', 22)
# ('adpetit', '->', 'appetit', 20)
# ('adprobantibus', '->', 'approbantibus', 20)
# ('adprobatio', '->', 'approbatio', 20)
# ('adprobauit', '->', 'approbauit', 20)
# ('adplicat', '->', 'applicat', 19)
# ('adpulit', '->', 'appulit', 18)
# ('adpositus', '->', 'appositus', 18)
# ('adpellant', '->', 'appellant', 18)
# ('adpulsa', '->', 'appulsa', 17)
# ('adposuit', '->', 'apposuit', 17)
# ('adprobatum', '->', 'approbatum', 17)
# ('adpetens', '->', 'appetens', 16)
# ('adposito', '->', 'apposito', 16)
# ('adplicant', '->', 'applicant', 15)
# ('adpetebat', '->', 'appetebat', 15)
# ('adpetitio', '->', 'appetitio', 15)
# ('adpetitus', '->', 'appetitus', 15)
# ('adprehendere', '->', 'apprehendere', 15)
# ('adprobari', '->', 'approbari', 14)
# ('adpetunt', '->', 'appetunt', 14)
# ('adparuit', '->', 'apparuit', 14)
# ('adprehensa', '->', 'apprehensa', 14)
# ('adplicuit', '->', 'applicuit', 13)
# ('adprobetur', '->', 'approbetur', 13)
# ('adprobat', '->', 'approbat', 12)
# ('adpareat', '->', 'appareat', 12)
# ('adpetant', '->', 'appetant', 12)
# ('adpulsus', '->', 'appulsus', 12)
# ('adprobata', '->', 'approbata', 12)
# ('adplicari', '->', 'applicari', 12)
# ('adpetisse', '->', 'appetisse', 11)
# ('adpropinquat', '->', 'appropinquat', 11)
# ('adpropinquante', '->', 'appropinquante', 11)
# ('adpropinquaret', '->', 'appropinquaret', 10)
# ('adpropinquabat', '->', 'appropinquabat', 10)
# ('adprobant', '->', 'approbant', 10)
# ('adpositi', '->', 'appositi', 10)
# ('adpetenda', '->', 'appetenda', 10)
# ('adparere', '->', 'apparere', 10)
# ('adpetitum', '->', 'appetitum', 9)
# ('adponi', '->', 'apponi', 9)
# ('adpeteret', '->', 'appeteret', 8)
# ('adparatum', '->', 'apparatum', 8)
# ('adplicata', '->', 'applicata', 8)
# ('adpellat', '->', 'appellat', 8)
# ('adplicantur', '->', 'applicantur', 8)
# ('adprobationem', '->', 'approbationem', 7)
# ('adpetendum', '->', 'appetendum', 7)
# ('adpropinquantem', '->', 'appropinquantem', 7)
# ('adplicet', '->', 'applicet', 7)
# ('adprobante', '->', 'approbante', 7)
# ('adparatu', '->', 'apparatu', 7)
# ('adpetuntur', '->', 'appetuntur', 7)
# ('adpeti', '->', 'appeti', 7)
# ('adpo', '->', 'appo', 7)
# ('adposui', '->', 'apposui', 7)
# ('adplicare', '->', 'applicare', 7)
# ('adpositu', '->', 'appositu', 7)
# ('adpositam', '->', 'appositam', 6)
# ('adponere', '->', 'apponere', 6)
# ('adponitur', '->', 'apponitur', 6)
# ('adponit', '->', 'apponit', 6)
# ('adpetentem', '->', 'appetentem', 6)
# ('adpetendi', '->', 'appetendi', 6)
# ('adprobet', '->', 'approbet', 6)
# ('adparatus', '->', 'apparatus', 6)
# ('adprehensum', '->', 'apprehensum', 6)
# ('adprobatur', '->', 'approbatur', 6)
# ('adpulsis', '->', 'appulsis', 5)
# ('adpulsas', '->', 'appulsas', 5)
# ('adpropinquarent', '->', 'appropinquarent', 5)
# ('adprobent', '->', 'approbent', 5)
# ('adprobauisset', '->', 'approbauisset', 5)
# ('adplicetur', '->', 'applicetur', 5)
# ('adpetis', '->', 'appetis', 5)
# ('adportat', '->', 'apportat', 5)
# ('adportet', '->', 'apportet', 5)
# ('adpellere', '->', 'appellere', 5)
# ('adpellare', '->', 'appellare', 5)
# ('adpetita', '->', 'appetita', 5)
# ('adporto', '->', 'apporto', 5)
# ('adparari', '->', 'apparari', 5)
# ('adplicatur', '->', 'applicatur', 5)
# ('adpulsum', '->', 'appulsum', 5)
# ('adparent', '->', 'apparent', 5)
# ('adpropinquantes', '->', 'appropinquantes', 5)
# ('adpropinquabant', '->', 'appropinquabant', 4)
# ('adplicauit', '->', 'applicauit', 4)
# ('adpropinquantis', '->', 'appropinquantis', 4)
# ('adpetitiones', '->', 'appetitiones', 4)
# ('adpetisset', '->', 'appetisset', 4)
# ('adpetat', '->', 'appetat', 4)
# ('adpellari', '->', 'appellari', 4)
# ('adponat', '->', 'apponat', 4)
# ('adponatur', '->', 'apponatur', 4)
# ('adplicitus', '->', 'applicitus', 4)
# ('adpetentes', '->', 'appetentes', 4)
# ('adposuisse', '->', 'apposuisse', 4)
# ('adprobaret', '->', 'approbaret', 4)
# ('adpellatio', '->', 'appellatio', 4)
# ('adparebat', '->', 'apparebat', 4)
# ('adpetitur', '->', 'appetitur', 4)
# ('adpropinquasset', '->', 'appropinquasset', 3)
# ('adplicito', '->', 'applicito', 3)
# ('adpetiuit', '->', 'appetiuit', 3)
# ('adpetitionem', '->', 'appetitionem', 3)
# ('adpropinquet', '->', 'appropinquet', 3)
# ('adpetentis', '->', 'appetentis', 3)
# ('adpetimus', '->', 'appetimus', 3)
# ('adpropinquans', '->', 'appropinquans', 3)
# ('adprobo', '->', 'approbo', 3)
# ('adportes', '->', 'apportes', 3)
# ('adpetendam', '->', 'appetendam', 3)
# ('adpones', '->', 'appones', 3)
# ('adpellantur', '->', 'appellantur', 3)
# ('adplicabat', '->', 'applicabat', 3)
# ('adpulerat', '->', 'appulerat', 3)
# ('adpetet', '->', 'appetet', 3)
# ('adpendit', '->', 'appendit', 3)
# ('adpareant', '->', 'appareant', 3)
# ('adprehenso', '->', 'apprehenso', 3)
# ('adpellationes', '->', 'appellationes', 3)
# ('adplicuisse', '->', 'applicuisse', 3)
# ('adprehendisset', '->', 'apprehendisset', 3)
# ('adponet', '->', 'apponet', 3)
# ('adpropinquantibus', '->', 'appropinquantibus', 3)
# ('adpetebant', '->', 'appetebant', 3)
# ('adportari', '->', 'apportari', 3)
# ('adprobabo', '->', 'approbabo', 3)
# ('adpellatus', '->', 'appellatus', 3)
# ('adpellatur', '->', 'appellatur', 3)
# ('adplicatae', '->', 'applicatae', 3)
# ('adprobaretur', '->', 'approbaretur', 3)
# ('adpetierit', '->', 'appetierit', 2)
# ('adpulissent', '->', 'appulissent', 2)
# ('adportata', '->', 'apportata', 2)
# ('adpulsi', '->', 'appulsi', 2)
# ('adponite', '->', 'apponite', 2)
# ('adprobato', '->', 'approbato', 2)
# ('adpetas', '->', 'appetas', 2)
# ('adprobaris', '->', 'approbaris', 2)
# ('adparata', '->', 'apparata', 2)
# ('adpendicem', '->', 'appendicem', 2)
# ('adpetitu', '->', 'appetitu', 2)
# ('adprehendentes', '->', 'apprehendentes', 2)
# ('adposite', '->', 'apposite', 2)
# ('adprobauerunt', '->', 'approbauerunt', 2)
# ('adproba', '->', 'approba', 2)
# ('adpellata', '->', 'appellata', 2)
# ('adpellati', '->', 'appellati', 2)
# ('adplicor', '->', 'applicor', 2)
# ('adpetiui', '->', 'appetiui', 2)
# ('adprobantes', '->', 'approbantes', 2)
# ('adpetiti', '->', 'appetiti', 2)
# ('adponeret', '->', 'apponeret', 2)
# ('adplicantes', '->', 'applicantes', 2)
# ('adparando', '->', 'apparando', 2)
# ('adparare', '->', 'apparare', 2)
# ('adpellans', '->', 'appellans', 2)
# ('adpellationem', '->', 'appellationem', 2)
# ('adpeterent', '->', 'appeterent', 2)
# ('adpellunt', '->', 'appellunt', 2)
# ('adplicita', '->', 'applicita', 2)
# ('adplicueris', '->', 'applicueris', 2)
# ('adplicentur', '->', 'applicentur', 2)
# ('adponunt', '->', 'apponunt', 2)
# ('adpellasset', '->', 'appellasset', 2)
# ('adpetes', '->', 'appetes', 2)
# ('adpulsam', '->', 'appulsam', 2)
# ('adpulerant', '->', 'appulerant', 2)
# ('adprobantium', '->', 'approbantium', 2)
# ('adpelli', '->', 'appelli', 2)
# ('adpellas', '->', 'appellas', 2)
# ('adprobarent', '->', 'approbarent', 2)
# ('adplicitum', '->', 'applicitum', 2)
# ('adprehendens', '->', 'apprehendens', 2)
# ('adplices', '->', 'applices', 2)
# ('adprobasse', '->', 'approbasse', 2)
# ('adpellationibus', '->', 'appellationibus', 2)
# ('adpellauit', '->', 'appellauit', 2)
# ('adpellabo', '->', 'appellabo', 2)
# ('adpellauimus', '->', 'appellauimus', 2)
# ('adparebit', '->', 'apparebit', 2)
# ('adproperate', '->', 'approperate', 2)
# ('adpensa', '->', 'appensa', 2)
# ('adpellebat', '->', 'appellebat', 1)
# ('adpropinquauit', '->', 'appropinquauit', 1)
# ('adpropinquarunt', '->', 'appropinquarunt', 1)
# ('adproperemus', '->', 'approperemus', 1)
# ('adparat', '->', 'apparat', 1)
# ('adpositos', '->', 'appositos', 1)
# ('adposuisset', '->', 'apposuisset', 1)
# ('adponebat', '->', 'apponebat', 1)
# ('adplicauerunt', '->', 'applicauerunt', 1)
# ('adprobationes', '->', 'approbationes', 1)
# ('adpetibiles', '->', 'appetibiles', 1)
# ('adprobationis', '->', 'approbationis', 1)
# ('adpendix', '->', 'appendix', 1)
# ('adpetebam', '->', 'appetebam', 1)
# ('adpellasse', '->', 'appellasse', 1)
# ('adpellantibus', '->', 'appellantibus', 1)
# ('adparatis', '->', 'apparatis', 1)
# ('adparentia', '->', 'apparentia', 1)
# ('adpellauere', '->', 'appellauere', 1)
# ('adpellent', '->', 'appellent', 1)
# ('adpellem', '->', 'appellem', 1)
# ('adpellandorum', '->', 'appellandorum', 1)
# ('adparente', '->', 'apparente', 1)
# ('adprobe', '->', 'approbe', 1)
# ('adpetieris', '->', 'appetieris', 1)
# ('adposuerunt', '->', 'apposuerunt', 1)
# ('adpetitam', '->', 'appetitam', 1)
# ('adponerentur', '->', 'apponerentur', 1)
# ('adparatur', '->', 'apparatur', 1)
# ('adparetur', '->', 'apparetur', 1)
# ('adparabantur', '->', 'apparabantur', 1)
# ('adpellaret', '->', 'appellaret', 1)
# ('adpositissimae', '->', 'appositissimae', 1)
# ('adprimet', '->', 'apprimet', 1)
# ('adposueris', '->', 'apposueris', 1)
# ('adparentur', '->', 'apparentur', 1)
# ('adplicato', '->', 'applicato', 1)
# ('adplicandum', '->', 'applicandum', 1)
# ('adplicatus', '->', 'applicatus', 1)
# ('adplicaret', '->', 'applicaret', 1)
# ('adparuisse', '->', 'apparuisse', 1)
# ('adplicatum', '->', 'applicatum', 1)
# ('adpetisti', '->', 'appetisti', 1)
# ('adpeto', '->', 'appeto', 1)
# ('adpetantur', '->', 'appetantur', 1)
# ('adpetam', '->', 'appetam', 1)
# ('adp', '->', 'app', 1)
# ('adplicarent', '->', 'applicarent', 1)
# ('adpulisti', '->', 'appulisti', 1)
# ('adpropinquanti', '->', 'appropinquanti', 1)
# ('adpareret', '->', 'appareret', 1)
# ('adpelle', '->', 'appelle', 1)
# ('adpellaretur', '->', 'appellaretur', 1)
# ('adprobauistis', '->', 'approbauistis', 1)
# ('adparuerit', '->', 'apparuerit', 1)
# ('adparuerint', '->', 'apparuerint', 1)
# ('adplicarentur', '->', 'applicarentur', 1)
# ('adpellarentur', '->', 'appellarentur', 1)
# ('adpellatum', '->', 'appellatum', 1)
# ('adpellarent', '->', 'appellarent', 1)
# ('adpetendis', '->', 'appetendis', 1)
# ('adprobando', '->', 'approbando', 1)
# ('adpulisset', '->', 'appulisset', 1)
# ('adplicamus', '->', 'applicamus', 1)
# ('adprehendas', '->', 'apprehendas', 1)
# ('adprenso', '->', 'apprenso', 1)
# ('adponas', '->', 'apponas', 1)
# ('adpellabatur', '->', 'appellabatur', 1)
# ('adpetitis', '->', 'appetitis', 1)
# ('adpello', '->', 'appello', 1)
# ('adpellando', '->', 'appellando', 1)
# ('adpella', '->', 'appella', 1)
# ('adplicemus', '->', 'applicemus', 1)
# ('adprobaui', '->', 'approbaui', 1)
# ('adpetitionis', '->', 'appetitionis', 1)
# ('adpetendo', '->', 'appetendo', 1)
# ('adpetiit', '->', 'appetiit', 1)
# ('adpetentius', '->', 'appetentius', 1)
# ('adprehenderat', '->', 'apprehenderat', 1)
# ('adparuisset', '->', 'apparuisset', 1)
# ('adplicati', '->', 'applicati', 1)
# ('adplicuerant', '->', 'applicuerant', 1)
# ('adponam', '->', 'apponam', 1)
# ('adponebatur', '->', 'apponebatur', 1)
# ('adplicuerat', '->', 'applicuerat', 1)
# # prefix examples: arr- 425, adr- 506
# exact transform matches: 46
# ('adrogantia', '->', 'arrogantia', 35)
# ('adrogantiam', '->', 'arrogantiam', 28)
# ('adrogans', '->', 'arrogans', 27)
# ('adrogantiae', '->', 'arrogantiae', 19)
# ('adridens', '->', 'arridens', 15)
# ('adroganter', '->', 'arroganter', 14)
# ('adrogatio', '->', 'arrogatio', 14)
# ('adrepto', '->', 'arrepto', 10)
# ('adrogantius', '->', 'arrogantius', 10)
# ('adrogare', '->', 'arrogare', 8)
# ('adrogantem', '->', 'arrogantem', 7)
# ('adrepta', '->', 'arrepta', 6)
# ('adripere', '->', 'arripere', 5)
# ('adripuit', '->', 'arripuit', 5)
# ('adreptum', '->', 'arreptum', 5)
# ('adroget', '->', 'arroget', 5)
# ('adrogo', '->', 'arrogo', 4)
# ('adrogantis', '->', 'arrogantis', 4)
# ('adrisit', '->', 'arrisit', 4)
# ('adridere', '->', 'arridere', 4)
# ('adridet', '->', 'arridet', 3)
# ('adrisisset', '->', 'arrisisset', 3)
# ('adrexit', '->', 'arrexit', 3)
# ('adrectis', '->', 'arrectis', 3)
# ('adrogat', '->', 'arrogat', 3)
# ('adripiunt', '->', 'arripiunt', 2)
# ('adripi', '->', 'arripi', 2)
# ('adripit', '->', 'arripit', 2)
# ('adreptam', '->', 'arreptam', 2)
# ('adripuisset', '->', 'arripuisset', 2)
# ('adrectae', '->', 'arrectae', 2)
# ('adripuisse', '->', 'arripuisse', 1)
# ('adripe', '->', 'arripe', 1)
# ('adripui', '->', 'arripui', 1)
# ('adripitur', '->', 'arripitur', 1)
# ('adreptus', '->', 'arreptus', 1)
# ('adripuimus', '->', 'arripuimus', 1)
# ('adripio', '->', 'arripio', 1)
# ('adripiente', '->', 'arripiente', 1)
# ('adriperet', '->', 'arriperet', 1)
# ('adrigere', '->', 'arrigere', 1)
# ('adreptis', '->', 'arreptis', 1)
# ('adrectos', '->', 'arrectos', 1)
# ('adrectus', '->', 'arrectus', 1)
# ('adriserit', '->', 'arriserit', 1)
# ('adrosit', '->', 'arrosit', 1)
# # prefix examples: ass- 1,317, ads- 5,893
# exact transform matches: 219
# ('adsequi', '->', 'assequi', 136)
# ('adsit', '->', 'assit', 130)
# ('adsentior', '->', 'assentior', 106)
# ('adsidua', '->', 'assidua', 78)
# ('adsensu', '->', 'assensu', 74)
# ('adsiduis', '->', 'assiduis', 72)
# ('adsiduo', '->', 'assiduo', 71)
# ('adsecutus', '->', 'assecutus', 63)
# ('adsumere', '->', 'assumere', 57)
# ('adsum', '->', 'assum', 48)
# ('adsensus', '->', 'assensus', 47)
# ('adsiduus', '->', 'assiduus', 45)
# ('adserunt', '->', 'asserunt', 39)
# ('adsueti', '->', 'assueti', 38)
# ('adsueta', '->', 'assueta', 38)
# ('adsumpta', '->', 'assumpta', 38)
# ('adsolet', '->', 'assolet', 37)
# ('adsumitur', '->', 'assumitur', 34)
# ('adsint', '->', 'assint', 32)
# ('adsuetum', '->', 'assuetum', 31)
# ('adsiduitate', '->', 'assiduitate', 30)
# ('adsecuti', '->', 'assecuti', 29)
# ('adsuetus', '->', 'assuetus', 28)
# ('adserit', '->', 'asserit', 28)
# ('adsis', '->', 'assis', 27)
# ('adsignat', '->', 'assignat', 27)
# ('adsignare', '->', 'assignare', 27)
# ('adsignatus', '->', 'assignatus', 27)
# ('adsumpsit', '->', 'assumpsit', 25)
# ('adsignari', '->', 'assignari', 25)
# ('adsumptis', '->', 'assumptis', 25)
# ('adsensio', '->', 'assensio', 24)
# ('adsignata', '->', 'assignata', 23)
# ('adsurgit', '->', 'assurgit', 23)
# ('adsidere', '->', 'assidere', 22)
# ('adsignatum', '->', 'assignatum', 22)
# ('adsuetos', '->', 'assuetos', 21)
# ('adsuetis', '->', 'assuetis', 21)
# ('adseuerat', '->', 'asseuerat', 21)
# ('adsumpto', '->', 'assumpto', 20)
# ('adsentatio', '->', 'assentatio', 20)
# ('adsentiar', '->', 'assentiar', 20)
# ('adsensum', '->', 'assensum', 20)
# ('adsentiri', '->', 'assentiri', 20)
# ('adserere', '->', 'asserere', 20)
# ('adsidet', '->', 'assidet', 18)
# ('adseueratio', '->', 'asseueratio', 18)
# ('adsignant', '->', 'assignant', 18)
# ('adsiduum', '->', 'assiduum', 17)
# ('adsumptio', '->', 'assumptio', 17)
# ('adsistere', '->', 'assistere', 16)
# ('adsignatio', '->', 'assignatio', 16)
# ('adsignauit', '->', 'assignauit', 16)
# ('adsensi', '->', 'assensi', 16)
# ('adsiduos', '->', 'assiduos', 15)
# ('adsueto', '->', 'assueto', 15)
# ('adsedit', '->', 'assedit', 15)
# ('adsurgere', '->', 'assurgere', 15)
# ('adsuetas', '->', 'assuetas', 14)
# ('adsidens', '->', 'assidens', 14)
# ('adsumunt', '->', 'assumunt', 14)
# ('adsueuit', '->', 'assueuit', 14)
# ('adsignatur', '->', 'assignatur', 14)
# ('adsiduae', '->', 'assiduae', 13)
# ('adsiduam', '->', 'assiduam', 13)
# ('adsumit', '->', 'assumit', 13)
# ('adsueui', '->', 'assueui', 13)
# ('adsistit', '->', 'assistit', 13)
# ('adsertor', '->', 'assertor', 13)
# ('adsuetae', '->', 'assuetae', 12)
# ('adsiduitas', '->', 'assiduitas', 12)
# ('adsignati', '->', 'assignati', 12)
# ('adsiduas', '->', 'assiduas', 12)
# ('adsumi', '->', 'assumi', 12)
# ('adseuerauit', '->', 'asseuerauit', 12)
# ('adsignet', '->', 'assignet', 12)
# ('adsistens', '->', 'assistens', 12)
# ('adsensere', '->', 'assensere', 11)
# ('adsuetam', '->', 'assuetam', 11)
# ('adsequar', '->', 'assequar', 11)
# ('adsensionem', '->', 'assensionem', 11)
# ('adsentiuntur', '->', 'assentiuntur', 10)
# ('adsumus', '->', 'assumus', 10)
# ('adsumptum', '->', 'assumptum', 10)
# ('adsolent', '->', 'assolent', 10)
# ('adsuerat', '->', 'assuerat', 9)
# ('adsidui', '->', 'assidui', 9)
# ('adsiduitatem', '->', 'assiduitatem', 9)
# ('adsentiendum', '->', 'assentiendum', 9)
# ('adserat', '->', 'asserat', 9)
# ('adseruit', '->', 'asseruit', 9)
# ('adsimulata', '->', 'assimulata', 9)
# ('adsumpserat', '->', 'assumpserat', 9)
# ('adsignatis', '->', 'assignatis', 9)
# ('adsignationem', '->', 'assignationem', 9)
# ('adseuerabat', '->', 'asseuerabat', 8)
# ('adsimilis', '->', 'assimilis', 8)
# ('adsumuntur', '->', 'assumuntur', 8)
# ('adsentio', '->', 'assentio', 8)
# ('adsumimus', '->', 'assumimus', 8)
# ('adsignabimus', '->', 'assignabimus', 8)
# ('adsumo', '->', 'assumo', 7)
# ('adsident', '->', 'assident', 7)
# ('adsequebatur', '->', 'assequebatur', 7)
# ('adsequatur', '->', 'assequatur', 7)
# ('adsiste', '->', 'assiste', 7)
# ('adsensit', '->', 'assensit', 7)
# ('adsentatores', '->', 'assentatores', 7)
# ('adsequetur', '->', 'assequetur', 7)
# ('adsentator', '->', 'assentator', 7)
# ('adsignantur', '->', 'assignantur', 7)
# ('adsueuerant', '->', 'assueuerant', 7)
# ('adsilit', '->', 'assilit', 6)
# ('adsignationis', '->', 'assignationis', 6)
# ('adsequamur', '->', 'assequamur', 6)
# ('adsecuta', '->', 'assecuta', 6)
# ('adsumptionem', '->', 'assumptionem', 6)
# ('adsertorem', '->', 'assertorem', 6)
# ('adsedi', '->', 'assedi', 6)
# ('adsuescerent', '->', 'assuescerent', 6)
# ('adsidente', '->', 'assidente', 6)
# ('adsequuntur', '->', 'assequuntur', 5)
# ('adsurrexit', '->', 'assurrexit', 5)
# ('adsidue', '->', 'assidue', 5)
# ('adsere', '->', 'assere', 5)
# ('adsertores', '->', 'assertores', 5)
# ('adsereret', '->', 'assereret', 5)
# ('adsurgeret', '->', 'assurgeret', 5)
# ('adsignarentur', '->', 'assignarentur', 5)
# ('adsultat', '->', 'assultat', 4)
# ('adsiduitatis', '->', 'assiduitatis', 4)
# ('adsequimur', '->', 'assequimur', 4)
# ('adsentiamur', '->', 'assentiamur', 4)
# ('adsentationem', '->', 'assentationem', 4)
# ('adsensionibus', '->', 'assensionibus', 4)
# ('adsumant', '->', 'assumant', 4)
# ('adsignato', '->', 'assignato', 4)
# ('adsecula', '->', 'assecula', 4)
# ('adsidebat', '->', 'assidebat', 4)
# ('adsimulant', '->', 'assimulant', 4)
# ('adserenda', '->', 'asserenda', 4)
# ('adsumendus', '->', 'assumendus', 4)
# ('adsistentibus', '->', 'assistentibus', 4)
# ('adsuesceret', '->', 'assuesceret', 4)
# ('adsentiebatur', '->', 'assentiebatur', 4)
# ('adsertio', '->', 'assertio', 4)
# ('adsedisset', '->', 'assedisset', 4)
# ('adsedimus', '->', 'assedimus', 3)
# ('adsumptiua', '->', 'assumptiua', 3)
# ('adsimulatio', '->', 'assimulatio', 3)
# ('adsuesce', '->', 'assuesce', 3)
# ('adsuerant', '->', 'assuerant', 3)
# ('adsignauerunt', '->', 'assignauerunt', 3)
# ('adserebant', '->', 'asserebant', 3)
# ('adsimulo', '->', 'assimulo', 3)
# ('adsumenda', '->', 'assumenda', 3)
# ('adsignificant', '->', 'assignificant', 3)
# ('adsecutis', '->', 'assecutis', 3)
# ('adsidendo', '->', 'assidendo', 3)
# ('adsentire', '->', 'assentire', 3)
# ('adserua', '->', 'asserua', 3)
# ('adsidenti', '->', 'assidenti', 2)
# ('adsequebantur', '->', 'assequebantur', 2)
# ('adsignationum', '->', 'assignationum', 2)
# ('adsignationes', '->', 'assignationes', 2)
# ('adsigna', '->', 'assigna', 2)
# ('adsentatoribus', '->', 'assentatoribus', 2)
# ('adsequemur', '->', 'assequemur', 2)
# ('adsensionis', '->', 'assensionis', 2)
# ('adsentatorem', '->', 'assentatorem', 2)
# ('adsumptionis', '->', 'assumptionis', 2)
# ('adsumet', '->', 'assumet', 2)
# ('adsidat', '->', 'assidat', 2)
# ('adsistendi', '->', 'assistendi', 2)
# ('adsimularet', '->', 'assimularet', 2)
# ('adsurrexisse', '->', 'assurrexisse', 2)
# ('adserto', '->', 'asserto', 2)
# ('adside', '->', 'asside', 2)
# ('adserente', '->', 'asserente', 2)
# ('adserentes', '->', 'asserentes', 2)
# ('adsumptae', '->', 'assumptae', 2)
# ('adsignatas', '->', 'assignatas', 2)
# ('adsignasse', '->', 'assignasse', 2)
# ('adsimulabat', '->', 'assimulabat', 2)
# ('adsistebat', '->', 'assistebat', 2)
# ('adsumptas', '->', 'assumptas', 2)
# ('adseritur', '->', 'asseritur', 2)
# ('adsignatorum', '->', 'assignatorum', 2)
# ('adsignationi', '->', 'assignationi', 2)
# ('adsidentem', '->', 'assidentem', 2)
# ('adseruanda', '->', 'asseruanda', 1)
# ('adsequebar', '->', 'assequebar', 1)
# ('adsignasti', '->', 'assignasti', 1)
# ('adseuerate', '->', 'asseuerate', 1)
# ('adsideo', '->', 'assideo', 1)
# ('adsertionibus', '->', 'assertionibus', 1)
# ('adserentibus', '->', 'asserentibus', 1)
# ('adsumantur', '->', 'assumantur', 1)
# ('adsueuerit', '->', 'assueuerit', 1)
# ('adseuerante', '->', 'asseuerante', 1)
# ('adsurrectum', '->', 'assurrectum', 1)
# ('adsueram', '->', 'assueram', 1)
# ('adsignabatur', '->', 'assignabatur', 1)
# ('adsistebant', '->', 'assistebant', 1)
# ('adsuescent', '->', 'assuescent', 1)
# ('adsecuntur', '->', 'assecuntur', 1)
# ('adsentatur', '->', 'assentatur', 1)
# ('adserendo', '->', 'asserendo', 1)
# ('adsidentium', '->', 'assidentium', 1)
# ('adsides', '->', 'assides', 1)
# ('adsentatorum', '->', 'assentatorum', 1)
# ('adsentientem', '->', 'assentientem', 1)
# ('adsideant', '->', 'assideant', 1)
# ('adsigno', '->', 'assigno', 1)
# ('adsecuto', '->', 'assecuto', 1)
# ('adsi', '->', 'assi', 1)
# ('adsuefaceret', '->', 'assuefaceret', 1)
# ('adseres', '->', 'asseres', 1)
# ('adsidite', '->', 'assidite', 1)
# # prefix examples: adst- 472, asstan- 0
# exact transform matches: 0
# # prefix examples: att- 3,357, adt- 631
# exact transform matches: 169
# ('adtinet', '->', 'attinet', 25)
# ('adtulit', '->', 'attulit', 24)
# ('adtributa', '->', 'attributa', 22)
# ('adtribuit', '->', 'attribuit', 18)
# ('adtingere', '->', 'attingere', 16)
# ('adtingit', '->', 'attingit', 16)
# ('adtendere', '->', 'attendere', 15)
# ('adtributae', '->', 'attributae', 10)
# ('adtulerat', '->', 'attulerat', 8)
# ('adtributum', '->', 'attributum', 8)
# ('adtritu', '->', 'attritu', 8)
# ('adtingat', '->', 'attingat', 8)
# ('adtrahere', '->', 'attrahere', 8)
# ('adtritis', '->', 'attritis', 8)
# ('adtende', '->', 'attende', 8)
# ('adtulisse', '->', 'attulisse', 7)
# ('adtulerit', '->', 'attulerit', 6)
# ('adtemptare', '->', 'attemptare', 6)
# ('adtulerunt', '->', 'attulerunt', 5)
# ('adtinent', '->', 'attinent', 5)
# ('adtributas', '->', 'attributas', 5)
# ('adtingunt', '->', 'attingunt', 5)
# ('adtulisset', '->', 'attulisset', 5)
# ('adtributi', '->', 'attributi', 5)
# ('adtrita', '->', 'attrita', 5)
# ('adtriuit', '->', 'attriuit', 5)
# ('adtendas', '->', 'attendas', 5)
# ('adtenuata', '->', 'attenuata', 4)
# ('adtinere', '->', 'attinere', 4)
# ('adtigit', '->', 'attigit', 4)
# ('adtendendum', '->', 'attendendum', 4)
# ('adtribui', '->', 'attribui', 4)
# ('adtingi', '->', 'attingi', 4)
# ('adtonita', '->', 'attonita', 4)
# ('adtollit', '->', 'attollit', 4)
# ('adtingens', '->', 'attingens', 4)
# ('adtendat', '->', 'attendat', 4)
# ('adtigerit', '->', 'attigerit', 4)
# ('adtrahitur', '->', 'attrahitur', 4)
# ('adtribuunt', '->', 'attribuunt', 3)
# ('adtente', '->', 'attente', 3)
# ('adtentius', '->', 'attentius', 3)
# ('adtentum', '->', 'attentum', 3)
# ('adtingant', '->', 'attingant', 3)
# ('adtenti', '->', 'attenti', 3)
# ('adtingam', '->', 'attingam', 3)
# ('adtollens', '->', 'attollens', 3)
# ('adtriuerant', '->', 'attriuerant', 3)
# ('adtollitur', '->', 'attollitur', 3)
# ('adtoniti', '->', 'attoniti', 3)
# ('adtulissent', '->', 'attulissent', 3)
# ('adtonitus', '->', 'attonitus', 3)
# ('adtendite', '->', 'attendite', 3)
# ('adtollere', '->', 'attollere', 3)
# ('adtollunt', '->', 'attollunt', 3)
# ('adtritae', '->', 'attritae', 3)
# ('adtribuatur', '->', 'attribuatur', 3)
# ('adtrectare', '->', 'attrectare', 3)
# ('adtritus', '->', 'attritus', 3)
# ('adtentos', '->', 'attentos', 2)
# ('adtribuas', '->', 'attribuas', 2)
# ('adtulisti', '->', 'attulisti', 2)
# ('adtribuitur', '->', 'attribuitur', 2)
# ('adtigi', '->', 'attigi', 2)
# ('adtendimus', '->', 'attendimus', 2)
# ('adtendis', '->', 'attendis', 2)
# ('adtributionibus', '->', 'attributionibus', 2)
# ('adtinuisse', '->', 'attinuisse', 2)
# ('adtributio', '->', 'attributio', 2)
# ('adtollentes', '->', 'attollentes', 2)
# ('adtrahi', '->', 'attrahi', 2)
# ('adtigerunt', '->', 'attigerunt', 2)
# ('adtingimus', '->', 'attingimus', 2)
# ('adtribuerent', '->', 'attribuerent', 2)
# ('adtentus', '->', 'attentus', 2)
# ('adtrahatur', '->', 'attrahatur', 2)
# ('adtonitas', '->', 'attonitas', 2)
# ('adtinebat', '->', 'attinebat', 2)
# ('adtinuit', '->', 'attinuit', 2)
# ('adterit', '->', 'atterit', 2)
# ('adtuleris', '->', 'attuleris', 2)
# ('adtulere', '->', 'attulere', 2)
# ('adtineat', '->', 'attineat', 2)
# ('adtendemus', '->', 'attendemus', 2)
# ('adtemptat', '->', 'attemptat', 2)
# ('adtendit', '->', 'attendit', 2)
# ('adteri', '->', 'atteri', 2)
# ('adtuli', '->', 'attuli', 2)
# ('adtribuerat', '->', 'attribuerat', 1)
# ('adtulimus', '->', 'attulimus', 1)
# ('adtinebant', '->', 'attinebant', 1)
# ('adtenuatio', '->', 'attenuatio', 1)
# ('adtribueretur', '->', 'attribueretur', 1)
# ('adtenuatum', '->', 'attenuatum', 1)
# ('adtribuendum', '->', 'attribuendum', 1)
# ('adtenuatur', '->', 'attenuatur', 1)
# ('adtributam', '->', 'attributam', 1)
# ('adtribuere', '->', 'attribuere', 1)
# ('adtinuerit', '->', 'attinuerit', 1)
# ('adtingantur', '->', 'attingantur', 1)
# ('adtactu', '->', 'attactu', 1)
# ('adtraxit', '->', 'attraxit', 1)
# ('adtento', '->', 'attento', 1)
# ('adtrahens', '->', 'attrahens', 1)
# ('adtractis', '->', 'attractis', 1)
# ('adtollant', '->', 'attollant', 1)
# ('adtolli', '->', 'attolli', 1)
# ('adtigeris', '->', 'attigeris', 1)
# ('adtenuatus', '->', 'attenuatus', 1)
# ('adtribuantur', '->', 'attribuantur', 1)
# ('adterere', '->', 'atterere', 1)
# ('adtonitis', '->', 'attonitis', 1)
# ('adtritio', '->', 'attritio', 1)
# ('adtendunt', '->', 'attendunt', 1)
# ('adtritum', '->', 'attritum', 1)
# ('adtrahit', '->', 'attrahit', 1)
# ('adtractus', '->', 'attractus', 1)
# ('adtollendus', '->', 'attollendus', 1)
# ('adtractum', '->', 'attractum', 1)
# ('adtribuerunt', '->', 'attribuerunt', 1)
# ('adtestata', '->', 'attestata', 1)
# ('adtonitos', '->', 'attonitos', 1)
# ('adtingendae', '->', 'attingendae', 1)
# ('adterunt', '->', 'atterunt', 1)
# ('adteruntur', '->', 'atteruntur', 1)
# ('adtollendum', '->', 'attollendum', 1)
# ('adterantur', '->', 'atterantur', 1)
# ('adtenderit', '->', 'attenderit', 1)
# ('adtentiore', '->', 'attentiore', 1)
# ('adtentissima', '->', 'attentissima', 1)
# ('adtingendus', '->', 'attingendus', 1)
# ('adtonitum', '->', 'attonitum', 1)
# ('adtriti', '->', 'attriti', 1)
# ('adtrectari', '->', 'attrectari', 1)
# ('adtollet', '->', 'attollet', 1)
# ('adtemptas', '->', 'attemptas', 1)
# ('adtendens', '->', 'attendens', 1)
# ('adtineret', '->', 'attineret', 1)
# ('adtribuerentur', '->', 'attribuerentur', 1)
# ('adtigerant', '->', 'attigerant', 1)
# ('adtenuari', '->', 'attenuari', 1)
# ('adtinerent', '->', 'attinerent', 1)
# ('adtendentem', '->', 'attendentem', 1)
# ('adtrahat', '->', 'attrahat', 1)
# ('adtrahas', '->', 'attrahas', 1)
# ('adtollimur', '->', 'attollimur', 1)
# ('adtolleret', '->', 'attolleret', 1)
# ('adtentior', '->', 'attentior', 1)
# ('adtenderis', '->', 'attenderis', 1)
# ('adtingas', '->', 'attingas', 1)
# ('adtuleram', '->', 'attuleram', 1)
# ('adtribuuntur', '->', 'attribuuntur', 1)
# ('adtribuant', '->', 'attribuant', 1)
# ('adtendentibus', '->', 'attendentibus', 1)
# ('adtollente', '->', 'attollente', 1)
# ('adtolle', '->', 'attolle', 1)
# ('adtollentia', '->', 'attollentia', 1)
# ('adtigerint', '->', 'attigerint', 1)
# ('adtritas', '->', 'attritas', 1)
# ('adtines', '->', 'attines', 1)
# ('adtributus', '->', 'attributus', 1)
# ('adtenuat', '->', 'attenuat', 1)
# ('adtritam', '->', 'attritam', 1)
# ('adtribuat', '->', 'attribuat', 1)
# ('adtribuentur', '->', 'attribuentur', 1)
# ('adtollat', '->', 'attollat', 1)
# ('adtemptata', '->', 'attemptata', 1)
# ('adtemptantem', '->', 'attemptantem', 1)
# ('adtribuetur', '->', 'attribuetur', 1)
# # prefix examples: afu- 265, affu- 33
# exact transform matches: 8
# ('affuit', '->', 'afuit', 8)
# ('affuisset', '->', 'afuisset', 4)
# ('affui', '->', 'afui', 2)
# ('affuerit', '->', 'afuerit', 2)
# ('affuturum', '->', 'afuturum', 1)
# ('affueram', '->', 'afueram', 1)
# ('affuerunt', '->', 'afuerunt', 1)
# ('affuturos', '->', 'afuturos', 1)
# # prefix examples: afu- 265, abfu- 12
# exact transform matches: 4
# ('abfuit', '->', 'afuit', 6)
# ('abfuisse', '->', 'afuisse', 1)
# ('abfuisset', '->', 'afuisset', 1)
# ('abfuturam', '->', 'afuturam', 1)
# # prefix examples: conic- 190, coic- 112
# exact transform matches: 24
# ('coiciuntur', '->', 'coniciuntur', 15)
# ('coicito', '->', 'conicito', 14)
# ('coicere', '->', 'conicere', 9)
# ('coici', '->', 'conici', 8)
# ('coicitur', '->', 'conicitur', 8)
# ('coicienda', '->', 'conicienda', 8)
# ('coiciendum', '->', 'coniciendum', 7)
# ('coiciunt', '->', 'coniciunt', 6)
# ('coiciantur', '->', 'coniciantur', 6)
# ('coiciebant', '->', 'coniciebant', 4)
# ('coiciatur', '->', 'coniciatur', 4)
# ('coiceretur', '->', 'coniceretur', 2)
# ('coicit', '->', 'conicit', 2)
# ('coice', '->', 'conice', 2)
# ('coiciebantur', '->', 'coniciebantur', 1)
# ('coicerentur', '->', 'conicerentur', 1)
# ('coicientes', '->', 'conicientes', 1)
# ('coiciendi', '->', 'coniciendi', 1)
# ('coiciebat', '->', 'coniciebat', 1)
# ('coiceret', '->', 'coniceret', 1)
# ('coicies', '->', 'conicies', 1)
# ('coicerent', '->', 'conicerent', 1)
# ('coicias', '->', 'conicias', 1)
# ('coiciendus', '->', 'coniciendus', 1)
# # prefix examples: conic- 190, conit- 22
# exact transform matches: 4
# ('conititur', '->', 'conicitur', 3)
# ('coniti', '->', 'conici', 3)
# ('coniterentur', '->', 'conicerentur', 2)
# ('conitere', '->', 'conicere', 1)
# # prefix examples: coll- 4,660, conl- 2,296
# exact transform matches: 223
# ('conloquium', '->', 'colloquium', 93)
# ('conlocauit', '->', 'collocauit', 85)
# ('conlatis', '->', 'collatis', 82)
# ('conlata', '->', 'collata', 66)
# ('conlocata', '->', 'collocata', 64)
# ('conloquio', '->', 'colloquio', 56)
# ('conlega', '->', 'collega', 53)
# ('conloquia', '->', 'colloquia', 50)
# ('conlocatum', '->', 'collocatum', 44)
# ('conloqui', '->', 'colloqui', 43)
# ('conlegam', '->', 'collegam', 34)
# ('conlocatis', '->', 'collocatis', 33)
# ('conlocatus', '->', 'collocatus', 32)
# ('conlocentur', '->', 'collocentur', 31)
# ('conlapsa', '->', 'collapsa', 29)
# ('conlocare', '->', 'collocare', 29)
# ('conlegae', '->', 'collegae', 28)
# ('conlocari', '->', 'collocari', 27)
# ('conlatio', '->', 'collatio', 27)
# ('conlocat', '->', 'collocat', 25)
# ('conlocati', '->', 'collocati', 23)
# ('conloquiis', '->', 'colloquiis', 23)
# ('conlocetur', '->', 'collocetur', 23)
# ('conlocantur', '->', 'collocantur', 22)
# ('conlocatur', '->', 'collocatur', 22)
# ('conlocatae', '->', 'collocatae', 21)
# ('conlegium', '->', 'collegium', 21)
# ('conlegio', '->', 'collegio', 19)
# ('conlocatio', '->', 'collocatio', 19)
# ('conlatum', '->', 'collatum', 17)
# ('conlato', '->', 'collato', 16)
# ('conlecta', '->', 'collecta', 15)
# ('conlocant', '->', 'collocant', 14)
# ('conlocatam', '->', 'collocatam', 14)
# ('conlocauerat', '->', 'collocauerat', 14)
# ('conlocutus', '->', 'collocutus', 14)
# ('conlaudat', '->', 'collaudat', 13)
# ('conlocuti', '->', 'collocuti', 13)
# ('conlocaret', '->', 'collocaret', 13)
# ('conluuio', '->', 'colluuio', 13)
# ('conlationem', '->', 'collationem', 12)
# ('conlocationem', '->', 'collocationem', 12)
# ('conlocanda', '->', 'collocanda', 12)
# ('conlucent', '->', 'collucent', 12)
# ('conloquendi', '->', 'colloquendi', 10)
# ('conloquii', '->', 'colloquii', 10)
# ('conlocasse', '->', 'collocasse', 10)
# ('conlaudatis', '->', 'collaudatis', 10)
# ('conlectis', '->', 'collectis', 10)
# ('conlocandis', '->', 'collocandis', 9)
# ('conlapsum', '->', 'collapsum', 9)
# ('conlocandi', '->', 'collocandi', 9)
# ('conlegas', '->', 'collegas', 9)
# ('conlocarunt', '->', 'collocarunt', 9)
# ('conlocandum', '->', 'collocandum', 9)
# ('conligi', '->', 'colligi', 9)
# ('conlatae', '->', 'collatae', 8)
# ('conlegis', '->', 'collegis', 8)
# ('conlocato', '->', 'collocato', 8)
# ('conlocauerunt', '->', 'collocauerunt', 8)
# ('conlocandus', '->', 'collocandus', 8)
# ('conloquar', '->', 'colloquar', 8)
# ('conlisio', '->', 'collisio', 8)
# ('conlaudato', '->', 'collaudato', 8)
# ('conlaturus', '->', 'collaturus', 7)
# ('conligere', '->', 'colligere', 7)
# ('conlectam', '->', 'collectam', 7)
# ('conligit', '->', 'colligit', 7)
# ('conlocaui', '->', 'collocaui', 7)
# ('conlaudauit', '->', 'collaudauit', 7)
# ('conlatus', '->', 'collatus', 7)
# ('conlocabat', '->', 'collocabat', 6)
# ('conligatis', '->', 'colligatis', 6)
# ('conlocarat', '->', 'collocarat', 6)
# ('conlocatas', '->', 'collocatas', 6)
# ('conlegi', '->', 'collegi', 6)
# ('conludere', '->', 'colludere', 6)
# ('conlocandae', '->', 'collocandae', 6)
# ('conlibitum', '->', 'collibitum', 6)
# ('conlocarent', '->', 'collocarent', 5)
# ('conlisa', '->', 'collisa', 5)
# ('conlegia', '->', 'collegia', 5)
# ('conlusio', '->', 'collusio', 5)
# ('conlegerat', '->', 'collegerat', 5)
# ('conligauit', '->', 'colligauit', 5)
# ('conlatas', '->', 'collatas', 5)
# ('conlegiorum', '->', 'collegiorum', 5)
# ('conlaudatus', '->', 'collaudatus', 5)
# ('conliberto', '->', 'colliberto', 5)
# ('conluctatio', '->', 'colluctatio', 5)
# ('conloquitur', '->', 'colloquitur', 4)
# ('conlatam', '->', 'collatam', 4)
# ('conligeret', '->', 'colligeret', 4)
# ('conlocabuntur', '->', 'collocabuntur', 4)
# ('conlocasset', '->', 'collocasset', 4)
# ('conlocemus', '->', 'collocemus', 4)
# ('conlectum', '->', 'collectum', 4)
# ('conlocaretur', '->', 'collocaretur', 4)
# ('conlocet', '->', 'collocet', 4)
# ('conligunt', '->', 'colligunt', 4)
# ('conlegisset', '->', 'collegisset', 4)
# ('conlocando', '->', 'collocando', 4)
# ('conligatae', '->', 'colligatae', 4)
# ('conloca', '->', 'colloca', 4)
# ('conlecti', '->', 'collecti', 4)
# ('conluuie', '->', 'colluuie', 4)
# ('conligata', '->', 'colligata', 4)
# ('conlecto', '->', 'collecto', 4)
# ('conlisum', '->', 'collisum', 4)
# ('conlabi', '->', 'collabi', 4)
# ('conligato', '->', 'colligato', 4)
# ('conlocabant', '->', 'collocabant', 3)
# ('conlisis', '->', 'collisis', 3)
# ('conligo', '->', 'colligo', 3)
# ('conliga', '->', 'colliga', 3)
# ('conligatio', '->', 'colligatio', 3)
# ('conlidi', '->', 'collidi', 3)
# ('conlusorem', '->', 'collusorem', 3)
# ('conlaudare', '->', 'collaudare', 3)
# ('conlectus', '->', 'collectus', 3)
# ('conlegit', '->', 'collegit', 3)
# ('conligari', '->', 'colligari', 3)
# ('conlaticia', '->', 'collaticia', 3)
# ('conlationes', '->', 'collationes', 3)
# ('conlocandos', '->', 'collocandos', 3)
# ('conligantur', '->', 'colligantur', 3)
# ('conligatum', '->', 'colligatum', 3)
# ('conligatur', '->', 'colligatur', 3)
# ('conluantur', '->', 'colluantur', 3)
# ('conlo', '->', 'collo', 2)
# ('conloquebantur', '->', 'colloquebantur', 2)
# ('conlocandorum', '->', 'collocandorum', 2)
# ('conlectos', '->', 'collectos', 2)
# ('conlocutio', '->', 'collocutio', 2)
# ('conligant', '->', 'colligant', 2)
# ('conligati', '->', 'colligati', 2)
# ('conlectionem', '->', 'collectionem', 2)
# ('conlationibus', '->', 'collationibus', 2)
# ('conlegisti', '->', 'collegisti', 2)
# ('conliguntur', '->', 'colliguntur', 2)
# ('conlocaris', '->', 'collocaris', 2)
# ('conlectio', '->', 'collectio', 2)
# ('conligam', '->', 'colligam', 2)
# ('conluuionem', '->', 'colluuionem', 2)
# ('conloquatur', '->', 'colloquatur', 2)
# ('conlocasti', '->', 'collocasti', 2)
# ('conlocassem', '->', 'collocassem', 2)
# ('conlidit', '->', 'collidit', 2)
# ('conlectae', '->', 'collectae', 2)
# ('conlectas', '->', 'collectas', 2)
# ('conlationis', '->', 'collationis', 2)
# ('conligetur', '->', 'colligetur', 2)
# ('conlocauerit', '->', 'collocauerit', 2)
# ('conlocabitur', '->', 'collocabitur', 2)
# ('conlocaueris', '->', 'collocaueris', 2)
# ('conligitur', '->', 'colligitur', 2)
# ('conluctari', '->', 'colluctari', 2)
# ('conlibuisset', '->', 'collibuisset', 2)
# ('conluuiem', '->', 'colluuiem', 2)
# ('conluuies', '->', 'colluuies', 2)
# ('conlaturos', '->', 'collaturos', 2)
# ('conligerent', '->', 'colligerent', 2)
# ('conlaudata', '->', 'collaudata', 2)
# ('conligat', '->', 'colligat', 2)
# ('conlocationis', '->', 'collocationis', 2)
# ...
# ('inridentibus', '->', 'irridentibus', 3)
# ('inrumpentis', '->', 'irrumpentis', 3)
# ('inritamentis', '->', 'irritamentis', 3)
# ('inriguo', '->', 'irriguo', 3)
# ('inrisorie', '->', 'irrisorie', 3)
# ('inrigationes', '->', 'irrigationes', 2)
# ('inridenda', '->', 'irridenda', 2)
# ('inrepat', '->', 'irrepat', 2)
# ('inroget', '->', 'irroget', 2)
# ('inriguum', '->', 'irriguum', 2)
# ('inritans', '->', 'irritans', 2)
# ('inritatior', '->', 'irritatior', 2)
# ('inreperet', '->', 'irreperet', 2)
# ('inrigandum', '->', 'irrigandum', 2)
# ('inrigatum', '->', 'irrigatum', 2)
# ('inrogatam', '->', 'irrogatam', 2)
# ('inritarentur', '->', 'irritarentur', 2)
# ('inreuocabilem', '->', 'irreuocabilem', 2)
# ('inreuerenter', '->', 'irreuerenter', 2)
# ('inrogatur', '->', 'irrogatur', 2)
# ('inriga', '->', 'irriga', 2)
# ('inriges', '->', 'irriges', 2)
# ('inreuocabiles', '->', 'irreuocabiles', 2)
# ('inrogant', '->', 'irrogant', 2)
# ('inrideas', '->', 'irrideas', 2)
# ('inridebat', '->', 'irridebat', 1)
# ('inridebunt', '->', 'irridebunt', 1)
# ('inrogatio', '->', 'irrogatio', 1)
# ('inrigauit', '->', 'irrigauit', 1)
# ('inridebas', '->', 'irridebas', 1)
# ('inriderent', '->', 'irriderent', 1)
# ('inrogatis', '->', 'irrogatis', 1)
# ('inruebat', '->', 'irruebat', 1)
# ('inrigans', '->', 'irrigans', 1)
# ('inrigant', '->', 'irrigant', 1)
# ('inrideret', '->', 'irrideret', 1)
# ('inrisam', '->', 'irrisam', 1)
# ('inrigantur', '->', 'irrigantur', 1)
# ('inrisis', '->', 'irrisis', 1)
# ('inriguus', '->', 'irriguus', 1)
# ('inrigarentur', '->', 'irrigarentur', 1)
# ('inruenti', '->', 'irruenti', 1)
# ('inritando', '->', 'irritando', 1)
# ('inrigatus', '->', 'irrigatus', 1)
# ('inritatam', '->', 'irritatam', 1)
# ('inridendam', '->', 'irridendam', 1)
# ('inrogandum', '->', 'irrogandum', 1)
# ('inrequietum', '->', 'irrequietum', 1)
# ('inrigiua', '->', 'irrigiua', 1)
# ('inriguos', '->', 'irriguos', 1)
# ('inrogauerit', '->', 'irrogauerit', 1)
# ('inritarent', '->', 'irritarent', 1)
# ('inrigatur', '->', 'irrigatur', 1)
# ('inroganda', '->', 'irroganda', 1)
# ('inroga', '->', 'irroga', 1)
# ('inrogat', '->', 'irrogat', 1)
# ('inridebit', '->', 'irridebit', 1)
# ('inritaueris', '->', 'irritaueris', 1)
# # prefix examples: obt- 1,922, opt- 5,719
# exact transform matches: 122
# ('optinuit', '->', 'obtinuit', 67)
# ('optinere', '->', 'obtinere', 61)
# ('optulit', '->', 'obtulit', 55)
# ('optinet', '->', 'obtinet', 52)
# ('optinent', '->', 'obtinent', 44)
# ('optigit', '->', 'obtigit', 27)
# ('optem', '->', 'obtem', 26)
# ('optinuerit', '->', 'obtinuerit', 22)
# ('optulerit', '->', 'obtulerit', 19)
# ('optineat', '->', 'obtineat', 17)
# ('optinendum', '->', 'obtinendum', 15)
# ('optineri', '->', 'obtineri', 13)
# ('optinebat', '->', 'obtinebat', 11)
# ('optineret', '->', 'obtineret', 11)
# ('optinente', '->', 'obtinente', 10)
# ('optingere', '->', 'obtingere', 9)
# ('optigerit', '->', 'obtigerit', 9)
# ('optinebit', '->', 'obtinebit', 9)
# ('optinuerat', '->', 'obtinuerat', 8)
# ('optemperare', '->', 'obtemperare', 8)
# ('optulisse', '->', 'obtulisse', 8)
# ('optutu', '->', 'obtutu', 7)
# ('optulisset', '->', 'obtulisset', 7)
# ('optines', '->', 'obtines', 6)
# ('optinens', '->', 'obtinens', 6)
# ('optutum', '->', 'obtutum', 6)
# ('optentu', '->', 'obtentu', 6)
# ('optulerat', '->', 'obtulerat', 6)
# ('optinuisset', '->', 'obtinuisset', 6)
# ('opti', '->', 'obti', 5)
# ('optulerunt', '->', 'obtulerunt', 5)
# ('optigerat', '->', 'obtigerat', 5)
# ('optineant', '->', 'obtineant', 5)
# ('optinuere', '->', 'obtinuere', 5)
# ('optinenda', '->', 'obtinenda', 4)
# ('opturato', '->', 'obturato', 4)
# ('optinendi', '->', 'obtinendi', 4)
# ('optuli', '->', 'obtuli', 4)
# ('optingat', '->', 'obtingat', 4)
# ('optinendae', '->', 'obtinendae', 3)
# ('optinendas', '->', 'obtinendas', 3)
# ('optinendam', '->', 'obtinendam', 3)
# ('optutus', '->', 'obtutus', 3)
# ('optinuisse', '->', 'obtinuisse', 3)
# ('optineo', '->', 'obtineo', 3)
# ('optinerent', '->', 'obtinerent', 3)
# ('optinuerunt', '->', 'obtinuerunt', 3)
# ('optinenti', '->', 'obtinenti', 3)
# ('optestor', '->', 'obtestor', 3)
# ('optigerunt', '->', 'obtigerunt', 3)
# ('optulisti', '->', 'obtulisti', 3)
# ('optorto', '->', 'obtorto', 3)
# ('optingit', '->', 'obtingit', 3)
# ('opteri', '->', 'obteri', 2)
# ('optunsae', '->', 'obtunsae', 2)
# ('optundere', '->', 'obtundere', 2)
# ('optinebatur', '->', 'obtinebatur', 2)
# ('opteritur', '->', 'obteritur', 2)
# ('optinemus', '->', 'obtinemus', 2)
# ('optemperasse', '->', 'obtemperasse', 2)
# ('optigisse', '->', 'obtigisse', 2)
# ('optentum', '->', 'obtentum', 2)
# ('optegere', '->', 'obtegere', 2)
# ('optinentem', '->', 'obtinentem', 2)
# ('optusa', '->', 'obtusa', 2)
# ('optinentibus', '->', 'obtinentibus', 2)
# ('optundi', '->', 'obtundi', 2)
# ('optulerim', '->', 'obtulerim', 2)
# ('opterit', '->', 'obterit', 2)
# ('optinentur', '->', 'obtinentur', 2)
# ('opturatis', '->', 'obturatis', 2)
# ('optentis', '->', 'obtentis', 1)
# ('optinendos', '->', 'obtinendos', 1)
# ('optineatur', '->', 'obtineatur', 1)
# ('optundat', '->', 'obtundat', 1)
# ('optorpui', '->', 'obtorpui', 1)
# ('optinetur', '->', 'obtinetur', 1)
# ('optinuerimus', '->', 'obtinuerimus', 1)
# ('optinebunt', '->', 'obtinebunt', 1)
# ('optemperari', '->', 'obtemperari', 1)
# ('optemperatum', '->', 'obtemperatum', 1)
# ('optruncat', '->', 'obtruncat', 1)
# ('optunso', '->', 'obtunso', 1)
# ('optui', '->', 'obtui', 1)
# ('opterunt', '->', 'obterunt', 1)
# ('optinuimus', '->', 'obtinuimus', 1)
# ('optemperans', '->', 'obtemperans', 1)
# ('optemperaret', '->', 'obtemperaret', 1)
# ('optudit', '->', 'obtudit', 1)
# ('opturant', '->', 'obturant', 1)
# ('optrectatores', '->', 'obtrectatores', 1)
# ('optegatur', '->', 'obtegatur', 1)
# ('optinuerant', '->', 'obtinuerant', 1)
# ('optemperauit', '->', 'obtemperauit', 1)
# ('optrectatoribus', '->', 'obtrectatoribus', 1)
# ('optinebant', '->', 'obtinebant', 1)
# ('opticuit', '->', 'obticuit', 1)
# ('optinuerint', '->', 'obtinuerint', 1)
# ('optusae', '->', 'obtusae', 1)
# ('optineres', '->', 'obtineres', 1)
# ('optineantur', '->', 'obtineantur', 1)
# ('optusus', '->', 'obtusus', 1)
# ('opturet', '->', 'obturet', 1)
# ('optineamus', '->', 'obtineamus', 1)
# ('optorpuisse', '->', 'obtorpuisse', 1)
# ('optemperat', '->', 'obtemperat', 1)
# ('opturata', '->', 'obturata', 1)
# ('opturamentis', '->', 'obturamentis', 1)
# ('opturatum', '->', 'obturatum', 1)
# ('optinentes', '->', 'obtinentes', 1)
# ('optentus', '->', 'obtentus', 1)
# ('optruncauit', '->', 'obtruncauit', 1)
# ('optinget', '->', 'obtinget', 1)
# ('optundit', '->', 'obtundit', 1)
# ('optinebis', '->', 'obtinebis', 1)
# ('optemperas', '->', 'obtemperas', 1)
# ('opticuisti', '->', 'obticuisti', 1)
# ('optinui', '->', 'obtinui', 1)
# ('optigisset', '->', 'obtigisset', 1)
# ('optulerint', '->', 'obtulerint', 1)
# ('optinebitur', '->', 'obtinebitur', 1)
# ('optemperent', '->', 'obtemperent', 1)
# # prefix examples: opp- 6,050, obp- 134
# exact transform matches: 59
# ('obprobrium', '->', 'opprobrium', 14)
# ('obprobrio', '->', 'opprobrio', 6)
# ('obpugnationem', '->', 'oppugnationem', 6)
# ('obpugnatio', '->', 'oppugnatio', 5)
# ('obpressus', '->', 'oppressus', 5)
# ('obpugnare', '->', 'oppugnare', 4)
# ('obposuit', '->', 'opposuit', 4)
# ('obprimere', '->', 'opprimere', 4)
# ('obpugnaret', '->', 'oppugnaret', 3)
# ('obpugnanda', '->', 'oppugnanda', 2)
# ('obpugnari', '->', 'oppugnari', 2)
# ('obpressi', '->', 'oppressi', 2)
# ('obpugnabat', '->', 'oppugnabat', 2)
# ('obpugnatum', '->', 'oppugnatum', 2)
# ('obprobria', '->', 'opprobria', 2)
# ('obposita', '->', 'opposita', 2)
# ('obpugnatoribus', '->', 'oppugnatoribus', 2)
# ('obpositam', '->', 'oppositam', 2)
# ('obpugnatores', '->', 'oppugnatores', 2)
# ('obpugnantium', '->', 'oppugnantium', 2)
# ('obpugnabant', '->', 'oppugnabant', 2)
# ('obpugnauerunt', '->', 'oppugnauerunt', 2)
# ('obpugnabimus', '->', 'oppugnabimus', 1)
# ('obpugnatur', '->', 'oppugnatur', 1)
# ('obpugna', '->', 'oppugna', 1)
# ('obpugnauit', '->', 'oppugnauit', 1)
# ('obpugnans', '->', 'oppugnans', 1)
# ('obpositi', '->', 'oppositi', 1)
# ('obpugnant', '->', 'oppugnant', 1)
# ('obpeteret', '->', 'oppeteret', 1)
# ('obpressum', '->', 'oppressum', 1)
# ('obpugnauerit', '->', 'oppugnauerit', 1)
# ('obpugnandos', '->', 'oppugnandos', 1)
# ('obponat', '->', 'opponat', 1)
# ('obpressit', '->', 'oppressit', 1)
# ('obpetam', '->', 'oppetam', 1)
# ('obpugnationes', '->', 'oppugnationes', 1)
# ('obpugnationis', '->', 'oppugnationis', 1)
# ('obpositae', '->', 'oppositae', 1)
# ('obpugnantibus', '->', 'oppugnantibus', 1)
# ('obpugnandum', '->', 'oppugnandum', 1)
# ('obpugnaretur', '->', 'oppugnaretur', 1)
# ('obpressa', '->', 'oppressa', 1)
# ('obprimenda', '->', 'opprimenda', 1)
# ('obpositus', '->', 'oppositus', 1)
# ('obponito', '->', 'opponito', 1)
# ('obpositas', '->', 'oppositas', 1)
# ('obpo', '->', 'oppo', 1)
# ('obponendo', '->', 'opponendo', 1)
# ('obprimi', '->', 'opprimi', 1)
# ('obpositis', '->', 'oppositis', 1)
# ('obponunt', '->', 'opponunt', 1)
# ('obprimit', '->', 'opprimit', 1)
# ('obponitur', '->', 'opponitur', 1)
# ('obpugnationibus', '->', 'oppugnationibus', 1)
# ('obpugnantem', '->', 'oppugnantem', 1)
# ('obpugnat', '->', 'oppugnat', 1)
# ('obprimantur', '->', 'opprimantur', 1)
# ('obpugnata', '->', 'oppugnata', 1)
# # prefix examples: prae- 45,325, pre- 6,849
# exact transform matches: 17
# ('premi', '->', 'praemi', 50)
# ('premis', '->', 'praemis', 23)
# ('prela', '->', 'praela', 11)
# ('prelis', '->', 'praelis', 9)
# ('pre', '->', 'prae', 7)
# ('prelum', '->', 'praelum', 6)
# ('prenderit', '->', 'praenderit', 4)
# ('preci', '->', 'praeci', 2)
# ('pretor', '->', 'praetor', 2)
# ('preciae', '->', 'praeciae', 2)
# ('preuaricatorem', '->', 'praeuaricatorem', 1)
# ('preueniet', '->', 'praeueniet', 1)
# ('preda', '->', 'praeda', 1)
# ('predas', '->', 'praedas', 1)
# ('premium', '->', 'praemium', 1)
# ('presenti', '->', 'praesenti', 1)
# ('precedentibus', '->', 'praecedentibus', 1)
# # prefix examples: subm- 405, summ- 7,546
# exact transform matches: 88
# ('summo', '->', 'submo', 951)
# ('summoueri', '->', 'submoueri', 71)
# ('summittere', '->', 'submittere', 48)
# ('summissa', '->', 'submissa', 38)
# ('summotis', '->', 'submotis', 27)
# ('summouit', '->', 'submouit', 27)
# ('summouetur', '->', 'submouetur', 26)
# ('summouet', '->', 'submouet', 25)
# ('summotus', '->', 'submotus', 25)
# ('summouere', '->', 'submouere', 25)
# ('summouebitur', '->', 'submouebitur', 25)
# ('summota', '->', 'submota', 24)
# ('summissis', '->', 'submissis', 19)
# ('summisso', '->', 'submisso', 19)
# ('summisit', '->', 'submisit', 17)
# ('summittit', '->', 'submittit', 16)
# ('summouendum', '->', 'submouendum', 14)
# ('summouendus', '->', 'submouendus', 14)
# ('summittitur', '->', 'submittitur', 13)
# ('summisse', '->', 'submisse', 12)
# ('summissus', '->', 'submissus', 11)
# ('summoto', '->', 'submoto', 11)
# ('summoueretur', '->', 'submoueretur', 11)
# ('summoueret', '->', 'submoueret', 10)
# ('summouentur', '->', 'submouentur', 10)
# ('summoueat', '->', 'submoueat', 9)
# ('summissum', '->', 'submissum', 8)
# ('summersa', '->', 'submersa', 8)
# ('summitti', '->', 'submitti', 8)
# ('summouenda', '->', 'submouenda', 8)
# ('summittat', '->', 'submittat', 7)
# ('summitteret', '->', 'submitteret', 7)
# ('summittuntur', '->', 'submittuntur', 7)
# ('summittunt', '->', 'submittunt', 6)
# ('summotum', '->', 'submotum', 6)
# ('summouent', '->', 'submouent', 6)
# ('summittantur', '->', 'submittantur', 6)
# ('summitte', '->', 'submitte', 5)
# ('summissius', '->', 'submissius', 5)
# ('summisisse', '->', 'submisisse', 5)
# ('summittenda', '->', 'submittenda', 5)
# ('summoueatur', '->', 'submoueatur', 5)
# ('summouerentur', '->', 'submouerentur', 4)
# ('summersum', '->', 'submersum', 4)
# ('summisere', '->', 'submisere', 3)
# ('summouerit', '->', 'submouerit', 3)
# ('summittito', '->', 'submittito', 3)
# ('summittimus', '->', 'submittimus', 3)
# ('summissae', '->', 'submissae', 3)
# ('summoueantur', '->', 'submoueantur', 3)
# ('summisi', '->', 'submisi', 3)
# ('summoueris', '->', 'submoueris', 3)
# ('summissas', '->', 'submissas', 2)
# ('summissos', '->', 'submissos', 2)
# ('summersus', '->', 'submersus', 2)
# ('summersi', '->', 'submersi', 2)
# ('sumministrauit', '->', 'subministrauit', 2)
# ('summouendo', '->', 'submouendo', 2)
# ('summouisse', '->', 'submouisse', 2)
# ('summoues', '->', 'submoues', 2)
# ('summissior', '->', 'submissior', 2)
# ('summittens', '->', 'submittens', 2)
# ('summergitur', '->', 'submergitur', 1)
# ('sumministra', '->', 'subministra', 1)
# ('summerso', '->', 'submerso', 1)
# ('summittas', '->', 'submittas', 1)
# ('summotas', '->', 'submotas', 1)
# ('summergere', '->', 'submergere', 1)
# ('summersis', '->', 'submersis', 1)
# ('summouebantur', '->', 'submouebantur', 1)
# ('summittendus', '->', 'submittendus', 1)
# ('sumministrat', '->', 'subministrat', 1)
# ('summouebimus', '->', 'submouebimus', 1)
# ('summittebat', '->', 'submittebat', 1)
# ('sumministrante', '->', 'subministrante', 1)
# ('summitterent', '->', 'submitterent', 1)
# ('summouentes', '->', 'submouentes', 1)
# ('summouentem', '->', 'submouentem', 1)
# ('summouerent', '->', 'submouerent', 1)
# ('summonente', '->', 'submonente', 1)
# ('sumministrarent', '->', 'subministrarent', 1)
# ('summitterentur', '->', 'submitterentur', 1)
# ('summouerat', '->', 'submouerat', 1)
# ('summissiores', '->', 'submissiores', 1)
# ('summissiora', '->', 'submissiora', 1)
# ('summouens', '->', 'submouens', 1)
# ('sumministrabit', '->', 'subministrabit', 1)
# ('summiserat', '->', 'submiserat', 1)
# # prefix examples: suff- 2,186, subf- 47
# exact transform matches: 18
# ('subferuefactis', '->', 'sufferuefactis', 3)
# ('subfusis', '->', 'suffusis', 3)
# ('subferuefacta', '->', 'sufferuefacta', 3)
# ('subfossis', '->', 'suffossis', 2)
# ('subferre', '->', 'sufferre', 2)
# ('subferuefactum', '->', 'sufferuefactum', 2)
# ('subfossa', '->', 'suffossa', 1)
# ('subfragabatur', '->', 'suffragabatur', 1)
# ('subfragiis', '->', 'suffragiis', 1)
# ('subfarcinatam', '->', 'suffarcinatam', 1)
# ('subfragatio', '->', 'suffragatio', 1)
# ('subfugere', '->', 'suffugere', 1)
# ('subfusus', '->', 'suffusus', 1)
# ('subfodere', '->', 'suffodere', 1)
# ('subfundatur', '->', 'suffundatur', 1)
# ('subfodiat', '->', 'suffodiat', 1)
# ('subfusiones', '->', 'suffusiones', 1)
# ('subfundit', '->', 'suffundit', 1)
# # prefix examples: supp- 3,088, subp- 126
# exact transform matches: 48
# ('subposuisse', '->', 'supposuisse', 10)
# ('subponere', '->', 'supponere', 4)
# ('subpositum', '->', 'suppositum', 4)
# ('subportari', '->', 'supportari', 3)
# ('subposuit', '->', 'supposuit', 3)
# ('subpetit', '->', 'suppetit', 3)
# ('subposita', '->', 'supposita', 3)
# ('subposito', '->', 'supposito', 3)
# ('subprimere', '->', 'supprimere', 3)
# ('subpositis', '->', 'suppositis', 2)
# ('subponunt', '->', 'supponunt', 2)
# ('subpositus', '->', 'suppositus', 2)
# ('subpresso', '->', 'suppresso', 2)
# ('subprimit', '->', 'supprimit', 2)
# ('subponi', '->', 'supponi', 2)
# ('subpressit', '->', 'suppressit', 2)
# ('subpetebat', '->', 'suppetebat', 1)
# ('subportare', '->', 'supportare', 1)
# ('subpeditaret', '->', 'suppeditaret', 1)
# ('subplicii', '->', 'supplicii', 1)
# ('subpeditantur', '->', 'suppeditantur', 1)
# ('subponimus', '->', 'supponimus', 1)
# ('subponatur', '->', 'supponatur', 1)
# ('subpositurus', '->', 'suppositurus', 1)
# ('subprimat', '->', 'supprimat', 1)
# ('subputat', '->', 'supputat', 1)
# ('subpetat', '->', 'suppetat', 1)
# ('subpetierant', '->', 'suppetierant', 1)
# ('subpeditabat', '->', 'suppeditabat', 1)
# ('subpressum', '->', 'suppressum', 1)
# ('subprimendum', '->', 'supprimendum', 1)
# ('subprimendi', '->', 'supprimendi', 1)
# ('subprimatur', '->', 'supprimatur', 1)
# ('subprimi', '->', 'supprimi', 1)
# ('subprimitur', '->', 'supprimitur', 1)
# ('subplementum', '->', 'supplementum', 1)
# ('subpares', '->', 'suppares', 1)
# ('subprimenda', '->', 'supprimenda', 1)
# ('subplantare', '->', 'supplantare', 1)
# ('subpone', '->', 'suppone', 1)
# ('subpeditet', '->', 'suppeditet', 1)
# ('subpeditare', '->', 'suppeditare', 1)
# ('subpeditabatur', '->', 'suppeditabatur', 1)
# ('subpressis', '->', 'suppressis', 1)
# ('subparum', '->', 'supparum', 1)
# ('subpositas', '->', 'suppositas', 1)
# ('subpressae', '->', 'suppressae', 1)
# ('subplantat', '->', 'supplantat', 1)
# # prefix examples: trai- 680, transi- 2,085
# exact transform matches: 7
# ('transi', '->', 'trai', 12)
# ('transiectio', '->', 'traiectio', 2)
# ('transicit', '->', 'traicit', 1)
# ('transiecit', '->', 'traiecit', 1)
# ('transiectionem', '->', 'traiectionem', 1)
# ('transiectos', '->', 'traiectos', 1)
# ('transiecti', '->', 'traiecti', 1)
# total transformations proposed 25,020

# %%
# Other regularizations possible, such as:
word_counts.get('quom') # archaic form of 'cum'
# Out:
# 731
