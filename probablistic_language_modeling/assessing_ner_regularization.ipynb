# %% [markdown]
# ### Assessing NER regularization of Latin corpus texts
# In Cythia Damon's masterful edition of Julius Caesar's _Bellum Civile_ she provides rules for the spelling regularizations she performed in an Appendix Orthographica. This notebook tries to quantify the quality and scope of these suggested regularizations when applied to a larger Latin corpus, specifically using her NER regularization rules.
#
# Applying these rules to a corpus could help boost the values of embeddings, especially for limited resource language.

# %%
import os.path
from collections import Counter
import inspect
import os
import sys
from glob import glob
from typing import List, Dict, Tuple

from cltk.corpus.readers import get_corpus_reader
from cltk.stem.latin.j_v import JVReplacer
from cltk.tokenize.latin.sentence import SentenceTokenizer
from cltk.tokenize.word import WordTokenizer
from cltk.corpus.latin.phi5_index import PHI5_INDEX
from tqdm import tqdm

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)
 
from mlyoucanuse.aeoe_replacer import AEOEReplacer
from mlyoucanuse.text_cleaners import ( normalize_accents, disappear_angle_brackets,
                                        drop_punct, disappear_round_brackets,
                                         dehyphenate, accept_editorial,
                                        swallow_braces, swallow_obelized_words,
                                        swallow_square_brackets)

# %% [markdown]
# # Latin Proper Name Prefix Regularizations
# Adapted from the Appendix Orthographica of Cythia Damon _C. Iuli Caesaris commentarii de bello civili_ (Bellum civile, or Civil War) (Oxford Classical Texts), pp. 168-172

# %%
# The first string in the tuple is the preferred prefix
# The second string in the tuple is the anomaly to be regularized
# we will title case after construction, lower cased here for readability

regularizations =[
                    ('acarnan', 'acharnan'),
                    ('achillam', 'achillan'), 
                    ('achillam', 'achila'), 
                    ('aeginium', 'eginium'), 
                    ('aeginium', 'eginum'), 
                    ('aegypt', 'aegipt'),
                    ('aegypt', 'agipt'),
                    ('aegypt', 'egypt'), 
                    ('aegypt', 'egipt'),
                    ('aetoli', 'aetholi'),
                    ('aetoli', 'etoli'),
                    ('aetoli', 'etholi'), 
                    ('afrani', 'affrani'),
                    ('afric', 'affric'),
                    ('albic', 'albicc'),
                    ('alexandri', 'alexandre'),
                    ('amantini', 'amatthini'),
                    ('amantini', 'amatini'),                  
                    ('ambraci', 'ambrachi'),
                    ('ambraci', 'abrachi'),
                    ('amphiloc', 'amfiloc'),
                    ('androsthen', 'androsten'),
                    ('antoni', 'anthoni'),
                    ('antioch', 'anthioch'),
                    ('antioch', 'antioc'),
                    ('antoni', 'anthoni'),
                    ('apollonia', 'appollon'),
                    ('apollonia', 'apollin'),
                    ('arelate', 'arelatae'),
                    ('arimin', 'harimin'),
                    ('arretium', 'aretium'),
                    ('arretium', 'aretiuum'),
                    ('asia', 'asya'),
                    ('aspara', 'aspera'),
                    ('aspara', 'haspara'),
                    ('atti', 'ati'),
                    ('atti', 'acti'),                               
                    ('bess', 'beiss'),
                    ('bithyni', 'bithini'),
                    ('boeoti', 'boeti'),
                    ('brundisi', 'brundusi'),
                    ('bylli', 'bibly'),
                    ('bylli', 'bibli'),
                    ('byllidens', 'billidens'),
                    ('caeli', 'coeli'),                  
                    ('claudi', 'clodi'),
                    ('caesa', 'cesa'),
                    ('caesa', 'cessa'),# problematic with cesso, cessare
                    ('caesa', 'caessa'), # problematic with cesso, cessare
                    ('calydo', 'calido'),
                    ('cappadoci','capodoci'),
                    ('cassi', 'casi'),                  
                    ('cilici', 'ciliti'),
                    ('clipe', 'clippe'),
                    ('clipe', 'clupe'),
                    # ('cn.','cnei'),
                    ('commagen', 'commagin'),
                    ('corcyr', 'corcir'),
                    ('cott', 'coct'),
                    ('cott', 'coty'),
                    ('cyclad', 'ciclad'),
                    ('cypr', 'cipr'),
                    ('cyren', 'ciren'),
                    ('domiti', 'domici'),
                    ('dyrrachi', 'dyrachi'),
                    ('dyrrachi', 'dirrachi'),
                    ('dyrrachi', 'dirachy'),                  
                    ('dyrrachi', 'dirachi'),
                    ('eli', 'aeli'),
                    ('ephes', 'aephes'),
                    ('epir', 'epyr'),
                    ('epir', 'aepyr'),
                    ('fauoni', 'faboni'),
                    ('flegmat', 'flecmat'),
                    ('fufi', 'fufei'),
                    ('gabini', 'gauini'),
                    ('gallia', 'galia'),
                    ('gallograeci', 'gallogreci'),
                    ('gerg', 'gorg'),
                    ('gomph', 'gonph'),
                    ('gomph', 'gonf'),
                    ('gomph', 'gimph'),
                    ('gomph', 'gymph'),
                    ('graec', 'grec'),
                    ('hadriatic', 'adriatic'),
                    ('hadrumet', 'hadrument'),
                    ('hadrumet', 'adrumet'),
                    ('haliacm', 'aliacm'),
                    ('hegesaret', 'haegesaret'),
                    ('hegesaret', 'egesaret'),
                    ('hirr', 'hyrr'),
                    ('hispan', 'hyspan'),
                    ('hispan', 'ispan'),
                    ('ilerd', 'ylerd'),
                    ('illyric', 'illiric'),
                    ('illyric', 'illic'),
                    ('illyric', 'ylliric'),
                    ('issa', 'hissa'),
                    ('itali', 'ithali'),
                    ('lacedaemon', 'lacedemon'),
                    ('lacedaemon', 'lacaedemon'),
                    ('laeli', 'leli'),
                    ('larisa', 'larissa'),
                    ('liss', 'lys'),
                    ('luccei', 'lucei'),
                    ('macedon', 'machedon'),
                    ('marrucin', 'marrutin'),
                    ('massilien', 'massalien'),
                    ('massilien', 'massillien'),
                    ('massilien', 'masilien'),
                    ('maure', 'mauri'),
                    ('minuci', 'minuti'),
                    ('mitylen', 'mytilen'),
                    ('nymphae', 'nymphe'),
                    ('oric', 'oryc'),
                    ('oric', 'orig'),
                    ('otacili', 'octacili'),
                    ('otoges', 'octoges'),
                    ('otoges', 'otogens'),
                    ('otoges', 'octogens'),
                    ('paelign', 'pelign'),
                    ('parthin', 'partin'),
                    ('parthin', 'parthyn'),
                    ('parthin', 'partyn'),
                    ('parthin', 'parthyin'),
                    ('pharu', 'faru'),
                    ('pharu', 'pharo'),
                    #('philipp', 'philip'), # need to match with regex
                    ('philipp', 'phylipp'),
                    ('phoenic', 'faenic'),
                    ('phoenic', 'phenic'),
                    ('placenti', 'placenci'),
                    ('ploti', 'plochi'),
                    ('pompe', 'pope'),
                    ('pothin', 'phothin'),
                    ('ptolome', 'ptholome'),
                    ('ptolome', 'ptholomae'),
                    ('ptolome', 'tholome'),
                    ('ptolome', 'tholomae'),
                    ('pyrenae', 'pyrene'),
                    ('pyrenae', 'pirene'),
                    ('rhascypoli', 'rascipoli'),
                    ('rhascypoli', 'rascipolu'),
                    ('roucill', 'rogill'),
                    ('roucill', 'rouic'),
                    ('rutili', 'rutuli'),
                    ('scipi', 'scypi'),
                    ('sicili', 'sycili'),
                    ('sicor', 'sycor'),
                    ('sicor', 'siccor'),
                    ('spinth', 'spint'),
                    ('spinth', 'sphint'),
                    ('sull', 'syll'),
                    ('sull', 'sill'),
                    ('sulpici', 'sulpiti'),
                    ('syri', 'siri'),
                    ('syri', 'syrri'),
                    ('tarraci', 'tarrachi'),
                    ('tarracon', 'tarraconn'),
                    ('therm','term'),                  
                    ("thessali", "tessali"),
                    ("thessali", "thesali"),
                    ("thessali", "tessalli"),
                    ("thraci", "traci"),
                    ("thur", "tur"),
                    ("tiburti", "tiburci"),
                    ("tiburti", "tyburti"),
                    # ("uar", "uarr" ), # bar ? # fails for: Marcus Terentius Varro
                    ("uespill", "uispill"),   
                    ("uespill", "bispill"),
                    ("uespill", "bispull"),
                    ("uetto", "uecto"),    
                    ("uetto", "ueto"),  
                    ("uetto", "betto"),  
                    ("uetto", "beto"),
                    ("uibi", "biui"),
                    ("uibull", "uibul"),   
                    ("uibull", "uibell"),   
                    ("uibull", "bibul"),
                    ("uibull", "bibull"),
                    ("uolca", "uolga"),
                    ("uolca", "uulga"),
                    ("uolcaci", "uolcati")
                 ]
regularizations = [(tmp.title(), tmp2.title()) for tmp, tmp2 in regularizations]

# %%
# Some useful common functions

### In the following sections, we will show Damon's preferred prefix first

def get_matches(prefix:str, word_counts:Dict[str,int])->Tuple[int, List[str]]:
    egs = [(key, val) for key,val in word_counts.items() if key.startswith(prefix)]
    if len(egs) == 0:
        return 0, []
    vals, counts = zip(*egs)
    egs = sorted(egs, key=lambda x:x[1], reverse=True)
    return sum(counts), egs

def print_proposed_regularizations(word_counts):
    """show the proposed regularizations"""
    total_transformations = 0
    for prefix_one, prefix_two in regularizations:
        prefix_one_num, prefix_one_egs = get_matches(prefix_one, word_counts) 
        prefix_two_num, prefix_two_egs = get_matches(prefix_two, word_counts) 
        if prefix_two_num == 0:
            continue
        print(f"# prefix examples: {prefix_one}- {prefix_one_num:,}, {prefix_two}- {prefix_two_num:,}")
        common_transforms = []
        for word, count in prefix_two_egs:
            transformed = word.replace(prefix_two, prefix_one)
            if transformed in word_counts:
                common_transforms.append((word, '->', transformed, count))
                total_transformations += count
        if common_transforms:
            print(f'exact transform matches: {len(common_transforms)}')                        
            for item in common_transforms:
                print(item)
        else:
            print("top 5 unmatched candidates", prefix_two_egs[:5])
    print(f"total transformations proposed {total_transformations:,}")

# %% [markdown]
# # Tesserae Corpus: Proposed NER regularizatons

# %%
tesserae = get_corpus_reader(corpus_name='latin_text_tesserae', language='latin')
word_counts = Counter()
jv_replacer = JVReplacer()
aeoe_replacer = AEOEReplacer()
toker = WordTokenizer('latin')
sent_toker = SentenceTokenizer() 

for file in tqdm(tesserae.fileids(), total=len(tesserae.fileids())):
    for sent in tesserae.sents(file):
        sent = aeoe_replacer.replace(jv_replacer.replace(drop_punct(sent)))
        sent = normalize_accents(sent)
        sent = accept_editorial(sent)
        for token in toker.tokenize(sent):
            word_counts.update({token : 1})

print("Proposed regularizations for Tesserae")
print_proposed_regularizations(word_counts)
# Out:
# 100%|██████████| 762/762 [03:39<00:00,  3.48it/s]
# Proposed regularizations for Tesserae
# # prefix examples: Achillam- 6, Achila- 3
# top 5 unmatched candidates [('Achilae', 3)]
# # prefix examples: Alexandri- 426, Alexandre- 73
# exact transform matches: 4
# ('Alexandream', '->', 'Alexandriam', 39)
# ('Alexandrea', '->', 'Alexandria', 18)
# ('Alexandreae', '->', 'Alexandriae', 15)
# ('Alexandre', '->', 'Alexandri', 1)
# # prefix examples: Antioch- 799, Antioc- 799
# top 5 unmatched candidates [('Antiocho', 180), ('Antiochus', 164), ('Antiochum', 159), ('Antiochi', 112), ('Antiochiam', 64)]
# # prefix examples: Apollonia- 73, Apollin- 433
# exact transform matches: 1
# ('Apolline', '->', 'Apolloniae', 36)
# # prefix examples: Aspara- 4, Aspera- 25
# top 5 unmatched candidates [('Aspera', 23), ('Asperat', 2)]
# # prefix examples: Atti- 635, Ati- 227
# exact transform matches: 6
# ('Atia', '->', 'Attia', 4)
# ('Atius', '->', 'Attius', 3)
# ('Atinas', '->', 'Attinas', 3)
# ('Atium', '->', 'Attium', 1)
# ('Atio', '->', 'Attio', 1)
# ('Atii', '->', 'Attii', 1)
# # prefix examples: Atti- 635, Acti- 87
# exact transform matches: 6
# ('Actium', '->', 'Attium', 12)
# ('Actio', '->', 'Attio', 10)
# ('Actia', '->', 'Attia', 10)
# ('Actius', '->', 'Attius', 2)
# ('Actis', '->', 'Attis', 1)
# ('Acti', '->', 'Atti', 1)
# # prefix examples: Boeoti- 119, Boeti- 1
# exact transform matches: 1
# ('Boeti', '->', 'Boeoti', 1)
# # prefix examples: Brundisi- 236, Brundusi- 3
# exact transform matches: 2
# ('Brundusii', '->', 'Brundisii', 2)
# ('Brundusium', '->', 'Brundisium', 1)
# # prefix examples: Bylli- 3, Bibli- 5
# top 5 unmatched candidates [('Bibliothecas', 1), ('Bibliotheca', 1), ('Biblii', 1), ('Bibli', 1), ('Bibliopolas', 1)]
# # prefix examples: Caeli- 267, Coeli- 56
# exact transform matches: 7
# ('Coelius', '->', 'Caelius', 26)
# ('Coelium', '->', 'Caelium', 9)
# ('Coelio', '->', 'Caelio', 9)
# ('Coeli', '->', 'Caeli', 6)
# ('Coelianum', '->', 'Caelianum', 2)
# ('Coelimontana', '->', 'Caelimontana', 1)
# ('Coelicolum', '->', 'Caelicolum', 1)
# # prefix examples: Claudi- 937, Clodi- 401
# exact transform matches: 14
# ('Clodius', '->', 'Claudius', 96)
# ('Clodium', '->', 'Claudium', 78)
# ('Clodio', '->', 'Claudio', 74)
# ('Clodi', '->', 'Claudi', 62)
# ('Clodia', '->', 'Claudia', 21)
# ('Clodiae', '->', 'Claudiae', 11)
# ('Clodii', '->', 'Claudii', 10)
# ('Clodiam', '->', 'Claudiam', 9)
# ('Clodianis', '->', 'Claudianis', 7)
# ('Clodianae', '->', 'Claudianae', 5)
# ('Clodiis', '->', 'Claudiis', 3)
# ('Clodios', '->', 'Claudios', 3)
# ('Clodiana', '->', 'Claudiana', 2)
# ('Clodianus', '->', 'Claudianus', 1)
# # prefix examples: Caesa- 4,211, Cessa- 18
# top 5 unmatched candidates [('Cessas', 6), ('Cessat', 4), ('Cessatum', 2), ('Cessator', 1), ('Cessante', 1)]
# # prefix examples: Calydo- 57, Calido- 9
# exact transform matches: 1
# ('Calido', '->', 'Calydo', 1)
# # prefix examples: Cassi- 528, Casi- 124
# exact transform matches: 10
# ('Casibus', '->', 'Cassibus', 9)
# ('Casio', '->', 'Cassio', 7)
# ('Casini', '->', 'Cassini', 4)
# ('Casii', '->', 'Cassii', 4)
# ('Casinas', '->', 'Cassinas', 2)
# ('Casius', '->', 'Cassius', 2)
# ('Casium', '->', 'Cassium', 1)
# ('Casia', '->', 'Cassia', 1)
# ('Casiis', '->', 'Cassiis', 1)
# ('Casinus', '->', 'Cassinus', 1)
# # prefix examples: Clipe- 4, Clupe- 6
# exact transform matches: 1
# ('Clupea', '->', 'Clipea', 1)
# # prefix examples: Cott- 254, Coct- 3
# exact transform matches: 1
# ('Cocta', '->', 'Cotta', 1)
# # prefix examples: Cott- 254, Coty- 47
# exact transform matches: 1
# ('Cotyi', '->', 'Cotti', 5)
# # prefix examples: Eli- 295, Aeli- 205
# exact transform matches: 8
# ('Aelius', '->', 'Elius', 87)
# ('Aelium', '->', 'Elium', 28)
# ('Aelia', '->', 'Elia', 15)
# ('Aelii', '->', 'Elii', 11)
# ('Aeli', '->', 'Eli', 8)
# ('Aeliorum', '->', 'Eliorum', 2)
# ('Aelim', '->', 'Elim', 1)
# ('Aelias', '->', 'Elias', 1)
# # prefix examples: Epir- 211, Epyr- 1
# exact transform matches: 1
# ('Epyri', '->', 'Epiri', 1)
# # prefix examples: Gabini- 161, Gauini- 2
# exact transform matches: 2
# ('Gauiniano', '->', 'Gabiniano', 1)
# ('Gauinio', '->', 'Gabinio', 1)
# # prefix examples: Gerg- 24, Gorg- 157
# top 5 unmatched candidates [('Gorgias', 31), ('Gorgone', 17), ('Gorgia', 14), ('Gorgonis', 14), ('Gorgo', 11)]
# # prefix examples: Graec- 3,386, Grec- 15
# exact transform matches: 8
# ('Grecam', '->', 'Graecam', 5)
# ('Grecorum', '->', 'Graecorum', 2)
# ('Greca', '->', 'Graeca', 2)
# ('Greco', '->', 'Graeco', 2)
# ('Greciam', '->', 'Graeciam', 1)
# ('Grecae', '->', 'Graecae', 1)
# ('Grece', '->', 'Graece', 1)
# ('Grecis', '->', 'Graecis', 1)
# # prefix examples: Hadriatic- 17, Adriatic- 7
# exact transform matches: 3
# ('Adriaticum', '->', 'Hadriaticum', 4)
# ('Adriatico', '->', 'Hadriatico', 2)
# ('Adriatici', '->', 'Hadriatici', 1)
# # prefix examples: Hadrumet- 15, Adrumet- 3
# exact transform matches: 1
# ('Adrumetum', '->', 'Hadrumetum', 1)
# # prefix examples: Illyric- 244, Illic- 159
# exact transform matches: 1
# ('Illico', '->', 'Illyrico', 2)
# # prefix examples: Lacedaemon- 447, Lacedemon- 1
# top 5 unmatched candidates [('Lacedemonas', 1)]
# # prefix examples: Larisa- 56, Larissa- 10
# exact transform matches: 3
# ('Larissa', '->', 'Larisa', 5)
# ('Larissam', '->', 'Larisam', 2)
# ('Larissaeus', '->', 'Larisaeus', 2)
# # prefix examples: Liss- 13, Lys- 229
# exact transform matches: 1
# ('Lyso', '->', 'Lisso', 9)
# # prefix examples: Maure- 29, Mauri- 118
# exact transform matches: 3
# ('Mauritaniae', '->', 'Mauretaniae', 8)
# ('Mauritania', '->', 'Mauretania', 5)
# ('Mauritaniam', '->', 'Mauretaniam', 3)
# # prefix examples: Mitylen- 12, Mytilen- 30
# exact transform matches: 6
# ('Mytilenis', '->', 'Mitylenis', 6)
# ('Mytilene', '->', 'Mitylene', 4)
# ('Mytilenaeum', '->', 'Mitylenaeum', 3)
# ('Mytilenaeorum', '->', 'Mitylenaeorum', 1)
# ('Mytilenaeis', '->', 'Mitylenaeis', 1)
# ('Mytilenaei', '->', 'Mitylenaei', 1)
# # prefix examples: Oric- 38, Orig- 224
# exact transform matches: 1
# ('Origo', '->', 'Orico', 5)
# # prefix examples: Otoges- 3, Octoges- 7
# top 5 unmatched candidates [('Octogesimo', 7)]
# # prefix examples: Paelign- 51, Pelign- 3
# exact transform matches: 3
# ('Peligni', '->', 'Paeligni', 1)
# ('Pelignum', '->', 'Paelignum', 1)
# ('Pelignos', '->', 'Paelignos', 1)
# # prefix examples: Pharu- 5, Faru- 1
# top 5 unmatched candidates [('Farurim', 1)]
# # prefix examples: Pharu- 5, Pharo- 35
# exact transform matches: 1
# ('Pharos', '->', 'Pharus', 18)
# # prefix examples: Pyrenae- 44, Pyrene- 39
# top 5 unmatched candidates [('Pyrenes', 19), ('Pyrene', 17), ('Pyreneus', 2), ('Pyrenem', 1)]
# # prefix examples: Pyrenae- 44, Pirene- 3
# exact transform matches: 1
# ('Pireneum', '->', 'Pyrenaeum', 2)
# # prefix examples: Rutili- 105, Rutuli- 60
# exact transform matches: 1
# ('Rutuli', '->', 'Rutili', 43)
# # prefix examples: Spinth- 13, Spint- 13
# top 5 unmatched candidates [('Spinther', 6), ('Spintherem', 3), ('Spintheri', 2), ('Spintharo', 1), ('Spintheris', 1)]
# # prefix examples: Sull- 557, Syll- 30
# exact transform matches: 5
# ('Syllae', '->', 'Sullae', 9)
# ('Sylla', '->', 'Sulla', 9)
# ('Syllam', '->', 'Sullam', 2)
# ('Syllana', '->', 'Sullana', 2)
# ('Syllanam', '->', 'Sullanam', 1)
# # prefix examples: Sull- 557, Sill- 2
# top 5 unmatched candidates [('Sillim', 1), ('Sille', 1)]
# # prefix examples: Syri- 655, Siri- 36
# exact transform matches: 3
# ('Sirius', '->', 'Syrius', 33)
# ('Siris', '->', 'Syris', 2)
# ('Siria', '->', 'Syria', 1)
# # prefix examples: Therm- 146, Term- 37
# exact transform matches: 1
# ('Termi', '->', 'Thermi', 5)
# # prefix examples: Thraci- 238, Traci- 1
# exact transform matches: 1
# ('Tracia', '->', 'Thracia', 1)
# # prefix examples: Thur- 40, Tur- 537
# exact transform matches: 5
# ('Tura', '->', 'Thura', 5)
# ('Turini', '->', 'Thurini', 1)
# ('Turi', '->', 'Thuri', 1)
# ('Turinum', '->', 'Thurinum', 1)
# ('Turino', '->', 'Thurino', 1)
# # prefix examples: Uespill- 1, Uispill- 1
# exact transform matches: 1
# ('Uispillo', '->', 'Uespillo', 1)
# # prefix examples: Uetto- 13, Uecto- 4
# top 5 unmatched candidates [('Uectores', 1), ('Uectoris', 1), ('Uectorem', 1), ('Uectorum', 1)]
# # prefix examples: Uetto- 13, Ueto- 1
# exact transform matches: 1
# ('Ueto', '->', 'Uetto', 1)
# # prefix examples: Uetto- 13, Beto- 1
# top 5 unmatched candidates [('Betonobes', 1)]
# # prefix examples: Uibi- 60, Biui- 1
# exact transform matches: 1
# ('Biuium', '->', 'Uibium', 1)
# # prefix examples: Uibull- 23, Uibul- 40
# top 5 unmatched candidates [('Uibullius', 9), ('Uibullium', 8), ('Uibulanus', 8), ('Uibulli', 5), ('Uibulano', 3)]
# # prefix examples: Uibull- 23, Uibell- 8
# exact transform matches: 3
# ('Uibellius', '->', 'Uibullius', 3)
# ('Uibellio', '->', 'Uibullio', 2)
# ('Uibellium', '->', 'Uibullium', 2)
# # prefix examples: Uibull- 23, Bibul- 123
# exact transform matches: 1
# ('Bibuli', '->', 'Uibulli', 28)
# # prefix examples: Uolca- 93, Uolga- 1
# top 5 unmatched candidates [('Uolgares', 1)]
# # prefix examples: Uolca- 93, Uulga- 11
# top 5 unmatched candidates [('Uulgari', 2), ('Uulgatum', 1), ('Uulgatissimum', 1), ('Uulgaribus', 1), ('Uulgarem', 1)]
# # prefix examples: Uolcaci- 17, Uolcati- 18
# exact transform matches: 3
# ('Uolcatio', '->', 'Uolcacio', 9)
# ('Uolcatium', '->', 'Uolcacium', 5)
# ('Uolcatius', '->', 'Uolcacius', 4)
# total transformations proposed 1,070

# %% [markdown]
# # Phi5 Proposed NER regularizatons

# %%
author_index = {val:key for key,val in PHI5_INDEX.items()}  

def get_phi5_author_files(author_name, author_index):
    stub = author_index[author_name]
    return glob(os.path.expanduser(f'~/cltk_data/latin/text/phi5/individual_works/{stub}*.txt'))

word_counts = Counter()
jv_replacer = JVReplacer()
aeoe_replacer = AEOEReplacer()
toker = WordTokenizer('latin')
sent_toker = SentenceTokenizer() 

for author in tqdm(author_index):
    files = get_phi5_author_files(author, author_index)
    for file in files:
        with open(file, 'rt') as fin:
            text = fin.read()
            text = text.replace("-\n", "") # Phi5 has some hyphenated line endings
            text = text.replace("\n", " ")
            text = aeoe_replacer.replace(jv_replacer.replace(text))
            for sent in sent_toker.tokenize(text):
                sent = dehyphenate(sent) # because it's Phi5
                sent = swallow_braces(sent)
                sent = swallow_square_brackets(sent)
                sent = disappear_round_brackets(sent)
                sent = swallow_obelized_words(sent)
                sent = disappear_angle_brackets(sent)            
                sent = drop_punct(sent)
                sent = normalize_accents(sent)            
                for word in toker.tokenize(sent):
                    if word.isnumeric():
                        continue
                    word_counts.update({word : 1}) 

print('Phi5 Proposed regularizatons:')
print_proposed_regularizations(word_counts)
# Out:
# 100%|██████████| 362/362 [03:14<00:00,  1.86it/s]
# Phi5 Proposed regularizatons:
# # prefix examples: Aegypt- 1,073, Egypt- 1
# exact transform matches: 1
# ('Egyptiaci', '->', 'Aegyptiaci', 1)
# # prefix examples: Alexandri- 610, Alexandre- 72
# exact transform matches: 3
# ('Alexandream', '->', 'Alexandriam', 39)
# ('Alexandreae', '->', 'Alexandriae', 18)
# ('Alexandrea', '->', 'Alexandria', 15)
# # prefix examples: Antioch- 769, Antioc- 769
# top 5 unmatched candidates [('Antiocho', 224), ('Antiochum', 161), ('Antiochus', 147), ('Antiochi', 120), ('Antiochiam', 29)]
# # prefix examples: Apollonia- 106, Apollin- 729
# exact transform matches: 1
# ('Apolline', '->', 'Apolloniae', 81)
# # prefix examples: Aspara- 7, Aspera- 8
# top 5 unmatched candidates [('Aspera', 7), ('Asperat', 1)]
# # prefix examples: Atti- 893, Ati- 323
# exact transform matches: 9
# ('Atiae', '->', 'Attiae', 6)
# ('Atia', '->', 'Attia', 4)
# ('Atius', '->', 'Attius', 3)
# ('Atinas', '->', 'Attinas', 2)
# ('Ati', '->', 'Atti', 1)
# ('Atium', '->', 'Attium', 1)
# ('Atii', '->', 'Attii', 1)
# ('Atio', '->', 'Attio', 1)
# ('Atianos', '->', 'Attianos', 1)
# # prefix examples: Atti- 893, Acti- 136
# exact transform matches: 7
# ('Actio', '->', 'Attio', 24)
# ('Actium', '->', 'Attium', 22)
# ('Actia', '->', 'Attia', 9)
# ('Actiaco', '->', 'Attiaco', 8)
# ('Actis', '->', 'Attis', 6)
# ('Actius', '->', 'Attius', 3)
# ('Actii', '->', 'Attii', 1)
# # prefix examples: Boeoti- 184, Boeti- 3
# exact transform matches: 2
# ('Boetiae', '->', 'Boeotiae', 2)
# ('Boetia', '->', 'Boeotia', 1)
# # prefix examples: Brundisi- 281, Brundusi- 8
# exact transform matches: 4
# ('Brundusii', '->', 'Brundisii', 3)
# ('Brundusium', '->', 'Brundisium', 3)
# ('Brundusinam', '->', 'Brundisinam', 1)
# ('Brundusi', '->', 'Brundisi', 1)
# # prefix examples: Bylli- 3, Bibli- 2
# top 5 unmatched candidates [('Bibliothecam', 1), ('Bibliopolas', 1)]
# # prefix examples: Caeli- 343, Coeli- 62
# exact transform matches: 4
# ('Coelius', '->', 'Caelius', 39)
# ('Coelio', '->', 'Caelio', 11)
# ('Coelium', '->', 'Caelium', 9)
# ('Coelianum', '->', 'Caelianum', 2)
# # prefix examples: Claudi- 1,315, Clodi- 549
# exact transform matches: 18
# ('Clodius', '->', 'Claudius', 152)
# ('Clodi', '->', 'Claudi', 97)
# ('Clodium', '->', 'Claudium', 96)
# ('Clodio', '->', 'Claudio', 92)
# ('Clodia', '->', 'Claudia', 27)
# ('Clodii', '->', 'Claudii', 13)
# ('Clodiae', '->', 'Claudiae', 11)
# ('Clodiam', '->', 'Claudiam', 9)
# ('Clodianis', '->', 'Claudianis', 7)
# ('Clodianae', '->', 'Claudianae', 7)
# ('Clodianum', '->', 'Claudianum', 7)
# ('Clodiani', '->', 'Claudiani', 6)
# ('Clodiano', '->', 'Claudiano', 5)
# ('Clodiana', '->', 'Claudiana', 4)
# ('Clodios', '->', 'Claudios', 3)
# ('Clodiis', '->', 'Claudiis', 3)
# ('Clodianorum', '->', 'Claudianorum', 3)
# ('Clodianus', '->', 'Claudianus', 2)
# # prefix examples: Caesa- 5,311, Cesa- 2
# exact transform matches: 1
# ('Cesar', '->', 'Caesar', 1)
# # prefix examples: Caesa- 5,311, Cessa- 16
# top 5 unmatched candidates [('Cessat', 6), ('Cessatis', 2), ('Cessantem', 2), ('Cessate', 1), ('Cessas', 1)]
# # prefix examples: Calydo- 75, Calido- 14
# exact transform matches: 3
# ('Calidoniam', '->', 'Calydoniam', 2)
# ('Calidonia', '->', 'Calydonia', 1)
# ('Calidoniae', '->', 'Calydoniae', 1)
# # prefix examples: Cassi- 978, Casi- 148
# exact transform matches: 7
# ('Casio', '->', 'Cassio', 8)
# ('Casium', '->', 'Cassium', 4)
# ('Casinas', '->', 'Cassinas', 3)
# ('Casius', '->', 'Cassius', 2)
# ('Casii', '->', 'Cassii', 2)
# ('Casiis', '->', 'Cassiis', 1)
# ('Casia', '->', 'Cassia', 1)
# # prefix examples: Clipe- 9, Clupe- 13
# exact transform matches: 3
# ('Clupea', '->', 'Clipea', 5)
# ('Clupeam', '->', 'Clipeam', 4)
# ('Clupeum', '->', 'Clipeum', 1)
# # prefix examples: Cott- 311, Coct- 4
# exact transform matches: 2
# ('Cocto', '->', 'Cotto', 1)
# ('Coctum', '->', 'Cottum', 1)
# # prefix examples: Cott- 311, Coty- 52
# exact transform matches: 1
# ('Cotyi', '->', 'Cotti', 5)
# # prefix examples: Cypr- 295, Cipr- 1
# exact transform matches: 1
# ('Ciprius', '->', 'Cyprius', 1)
# # prefix examples: Domiti- 590, Domici- 2
# top 5 unmatched candidates [('Domicilium', 2)]
# # prefix examples: Eli- 167, Aeli- 399
# exact transform matches: 9
# ('Aelius', '->', 'Elius', 173)
# ('Aelia', '->', 'Elia', 54)
# ('Aelium', '->', 'Elium', 43)
# ('Aelio', '->', 'Elio', 41)
# ('Aeliam', '->', 'Eliam', 33)
# ('Aelii', '->', 'Elii', 19)
# ('Aeli', '->', 'Eli', 14)
# ('Aeliorum', '->', 'Eliorum', 4)
# ('Aeliae', '->', 'Eliae', 3)
# # prefix examples: Gerg- 19, Gorg- 172
# top 5 unmatched candidates [('Gorgias', 31), ('Gorgonis', 22), ('Gorgone', 14), ('Gorgia', 13), ('Gorgo', 12)]
# # prefix examples: Graec- 4,646, Grec- 1
# exact transform matches: 1
# ('Greci', '->', 'Graeci', 1)
# # prefix examples: Hadriatic- 46, Adriatic- 16
# exact transform matches: 3
# ('Adriaticum', '->', 'Hadriaticum', 11)
# ('Adriatico', '->', 'Hadriatico', 4)
# ('Adriatici', '->', 'Hadriatici', 1)
# # prefix examples: Hadrumet- 33, Adrumet- 4
# exact transform matches: 2
# ('Adrumeto', '->', 'Hadrumeto', 2)
# ('Adrumetinus', '->', 'Hadrumetinus', 1)
# # prefix examples: Haliacm- 7, Aliacm- 1
# exact transform matches: 1
# ('Aliacmonem', '->', 'Haliacmonem', 1)
# # prefix examples: Illyric- 277, Illiric- 2
# exact transform matches: 1
# ('Illirico', '->', 'Illyrico', 2)
# # prefix examples: Illyric- 277, Illic- 80
# top 5 unmatched candidates [('Illic', 74), ('Illicere', 1), ('Illicine', 1), ('Illicitas', 1), ('Illicita', 1)]
# # prefix examples: Laeli- 364, Leli- 1
# top 5 unmatched candidates [('Leliano', 1)]
# # prefix examples: Larisa- 74, Larissa- 11
# exact transform matches: 4
# ('Larissa', '->', 'Larisa', 5)
# ('Larissam', '->', 'Larisam', 3)
# ('Larissaeus', '->', 'Larisaeus', 2)
# ('Larissaea', '->', 'Larisaea', 1)
# # prefix examples: Liss- 17, Lys- 264
# exact transform matches: 1
# ('Lyso', '->', 'Lisso', 10)
# # prefix examples: Macedon- 1,374, Machedon- 1
# exact transform matches: 1
# ('Machedonia', '->', 'Macedonia', 1)
# # prefix examples: Maure- 77, Mauri- 94
# exact transform matches: 2
# ('Mauritania', '->', 'Mauretania', 6)
# ('Mauritaniae', '->', 'Mauretaniae', 1)
# # prefix examples: Mitylen- 24, Mytilen- 41
# exact transform matches: 8
# ('Mytilenis', '->', 'Mitylenis', 10)
# ('Mytilene', '->', 'Mitylene', 5)
# ('Mytilenaeum', '->', 'Mitylenaeum', 4)
# ('Mytilenae', '->', 'Mitylenae', 3)
# ('Mytilenaeorum', '->', 'Mitylenaeorum', 2)
# ('Mytilenaeis', '->', 'Mitylenaeis', 2)
# ('Mytilenaei', '->', 'Mitylenaei', 1)
# ('Mytilenaeas', '->', 'Mitylenaeas', 1)
# # prefix examples: Nymphae- 55, Nymphe- 1
# exact transform matches: 1
# ('Nymphe', '->', 'Nymphae', 1)
# # prefix examples: Oric- 46, Orig- 47
# exact transform matches: 1
# ('Origo', '->', 'Orico', 12)
# # prefix examples: Paelign- 72, Pelign- 4
# exact transform matches: 3
# ('Peligni', '->', 'Paeligni', 1)
# ('Peligna', '->', 'Paeligna', 1)
# ('Pelignus', '->', 'Paelignus', 1)
# # prefix examples: Pharu- 12, Pharo- 40
# exact transform matches: 1
# ('Pharos', '->', 'Pharus', 10)
# # prefix examples: Pompe- 2,472, Pope- 1
# top 5 unmatched candidates [('Popedius', 1)]
# # prefix examples: Pyrenae- 80, Pyrene- 31
# exact transform matches: 1
# ('Pyreneus', '->', 'Pyrenaeus', 2)
# # prefix examples: Pyrenae- 80, Pirene- 4
# top 5 unmatched candidates [('Pirene', 4)]
# # prefix examples: Rutili- 151, Rutuli- 80
# exact transform matches: 1
# ('Rutuli', '->', 'Rutili', 53)
# # prefix examples: Spinth- 23, Spint- 25
# top 5 unmatched candidates [('Spinther', 14), ('Spintherem', 3), ('Spintheri', 2), ('Spintharo', 1), ('Spintyrnix', 1)]
# # prefix examples: Sull- 707, Syll- 83
# exact transform matches: 8
# ('Sylla', '->', 'Sulla', 32)
# ('Syllae', '->', 'Sullae', 19)
# ('Syllam', '->', 'Sullam', 12)
# ('Syllanorum', '->', 'Sullanorum', 1)
# ('Syllani', '->', 'Sullani', 1)
# ('Syllanis', '->', 'Sullanis', 1)
# ('Syllanarum', '->', 'Sullanarum', 1)
# ('Syllano', '->', 'Sullano', 1)
# # prefix examples: Sull- 707, Sill- 4
# top 5 unmatched candidates [('Sillio', 1), ('Sillii', 1), ('Sillim', 1), ('Sillybum', 1)]
# # prefix examples: Syri- 752, Siri- 38
# exact transform matches: 3
# ('Sirius', '->', 'Syrius', 28)
# ('Sirio', '->', 'Syrio', 4)
# ('Siris', '->', 'Syris', 1)
# # prefix examples: Therm- 177, Term- 46
# exact transform matches: 1
# ('Termi', '->', 'Thermi', 5)
# # prefix examples: Thur- 57, Tur- 777
# exact transform matches: 7
# ('Turium', '->', 'Thurium', 5)
# ('Turio', '->', 'Thurio', 5)
# ('Turinus', '->', 'Thurinus', 3)
# ('Turi', '->', 'Thuri', 2)
# ('Turinum', '->', 'Thurinum', 2)
# ('Turino', '->', 'Thurino', 1)
# ('Turri', '->', 'Thurri', 1)
# # prefix examples: Uespill- 1, Uispill- 1
# exact transform matches: 1
# ('Uispillo', '->', 'Uespillo', 1)
# # prefix examples: Uetto- 63, Uecto- 2
# exact transform matches: 2
# ('Uectonicam', '->', 'Uettonicam', 1)
# ('Uectonicae', '->', 'Uettonicae', 1)
# # prefix examples: Uetto- 63, Ueto- 1
# exact transform matches: 1
# ('Ueto', '->', 'Uetto', 1)
# # prefix examples: Uibi- 91, Biui- 1
# exact transform matches: 1
# ('Biuium', '->', 'Uibium', 1)
# # prefix examples: Uibull- 23, Uibul- 40
# top 5 unmatched candidates [('Uibullius', 9), ('Uibullium', 8), ('Uibulanus', 7), ('Uibulli', 5), ('Uibulenus', 3)]
# # prefix examples: Uibull- 23, Uibell- 9
# exact transform matches: 3
# ('Uibellio', '->', 'Uibullio', 3)
# ('Uibellius', '->', 'Uibullius', 3)
# ('Uibellium', '->', 'Uibullium', 2)
# # prefix examples: Uibull- 23, Bibul- 133
# exact transform matches: 1
# ('Bibuli', '->', 'Uibulli', 33)
# # prefix examples: Uolca- 148, Uolga- 3
# top 5 unmatched candidates [('Uolgaria', 1), ('Uolgari', 1), ('Uolgaris', 1)]
# # prefix examples: Uolca- 148, Uulga- 8
# top 5 unmatched candidates [('Uulgares', 2), ('Uulgaris', 2), ('Uulgatissimum', 1), ('Uulgare', 1), ('Uulgabatur', 1)]
# # prefix examples: Uolcaci- 19, Uolcati- 22
# exact transform matches: 3
# ('Uolcatio', '->', 'Uolcacio', 10)
# ('Uolcatius', '->', 'Uolcacius', 8)
# ('Uolcatium', '->', 'Uolcacium', 4)
# total transformations proposed 1,645
